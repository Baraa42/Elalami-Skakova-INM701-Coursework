# %% [markdown]
# ## Content:
# - [Part 1](#part1)- Importing the libraries, packages
# - [Part 2](#part2)- Feature Engineering
# - [Part 3](#part3) - Label Encoded Data
# - [Part 4](#part4) -  Hot encoded Data
# - [Part 5](#part5) -  Scaling Data
# - [Part 6](#part6) -  Lasso regression
# - [Part 7](#part7) -  ANN 1 hidden layer label encoded data
# - [Part 8](#part8) -  ANN L1 regularizer
# - [Part 9](#part9) -  ANN L2 hidden layers
# - [Part 10](#part10) -  ANN 2 hidden layers

# %% [markdown]
# [Back to top](#Content:)
#
#
#
# <a id='part1'></a>
#
# ### Part 1 -   Importing the libraries, packages

# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# random.seed(0)

# %%
## loading the file
health_care = pd.read_csv('../healthcare/train_data.csv', na_values=['NA', 'NaN', '?'])

# %%
health_care.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
# Dropping na values for 
health_care = health_care.dropna()

# %% [markdown]
# # Objectif :
#
# Predict length of stay of the patient. We use regression and classification.
#
# ### Regression
#
# Prediction directly the length of stay.
#
# ### Classifiation
#
# Predicting the class of length of stay e.g 30-40 days

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part2'></a>
#
# ## Feature engineering
#
# We will add 2 features :
# - Visit number
# - New Patient

# %%
n = health_care.shape[0]
visits = []
patientid = np.array(health_care['patientid'])
for i in range(n) :
    count = (patientid[:i+1] == patientid[i]).sum()
    visits.append(count)
    
health_care['Visit Number'] = visits
health_care['New Patient'] = (health_care['Visit Number']==1).astype('int32')

# %%
health_care.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay  Visit Number  New Patient
# 0             4911.0   0-10             1            1
# 1             5954.0  41-50             2            0
# 2             4745.0  31-40             3            0
# 3             7272.0  41-50             4            0
# 4             5558.0  41-50             5            0

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part3'></a>
# ## Label Encoded Data

# %%
## Columns to be label encoded

string_columns = ['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type', 'Ward_Facility_Code',  'Type of Admission', 'Severity of Illness', 'Age' ]
encoder = LabelEncoder()


## label_encoded data
X_le = health_care.drop(['Stay', 'case_id'], axis=1)
y_le = health_care['Stay']

# Transofrming length of stay
y_le = encoder.fit_transform(y_le)
y_le = 10*y_le + 5

for column in string_columns :
    X_le[column] = encoder.fit(X_le[column]).transform(X_le[column])

# %% [markdown]
# ### Adding target for classification

# %%
import keras.utils
y_cat = encoder.fit_transform(health_care['Stay'])
y_cat_targ = keras.utils.to_categorical(encoder.fit_transform(health_care['Stay']))

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4'></a>
# ## Hot encoded Data

# %%
# Function to hot encode the column with name : name for dataframe df
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = f"{name}-{x}"
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True) ## inplace to make changed on the original df

# %%
## Pre processing these columns

le_string_columns = [  'Severity of Illness', 'Age' ]
dummies_string_columns = ['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type', 'Ward_Facility_Code',  'Type of Admission']
encoder = LabelEncoder()
#ohEncoder = OneHotEncoder()

## label_encoded data
Xe = health_care.drop(['Stay', 'case_id'], axis=1)
Xe['Severity of Illness']= Xe['Severity of Illness'].map({'Minor': 0,  'Moderate': 1,'Extreme': 2})
Xe['Age'] = encoder.fit_transform(Xe['Age'])

ye = health_care['Stay']
ye = encoder.fit_transform(ye)
ye = 10*ye + 5
ye

for column in dummies_string_columns :
    encode_text_dummy(Xe, column)

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5'></a>
# ## Scaling Label Encoded Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = X_le.values
y = y_le
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
for i in range(X_train.shape[1]) :
    X_train[:,i]= scaler.fit_transform(X_train[:,i].reshape(-1, 1))[:,0]
    X_test[:,i] = scaler.transform(X_test[:,i].reshape(-1, 1))[:,0]

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part6'></a>
# ## Lasso for preliminar feature selection

# %%
# Function to plot Lasso coef
def report_coef(names,coef,intercept):
    r = pd.DataFrame( { 'coef': coef, 'positive': np.abs(coef)  }, index = names )
    r = r.sort_values(by=['positive'], ascending=True)
    display(r)
    print("Intercept: {}".format(intercept))
    plt.xlabel('covariate coefficient')
    r['coef'].plot(kind='barh')

# %%
import sklearn
from sklearn.linear_model import Lasso
from sklearn import metrics

# Create linear regression
regressor = Lasso(alpha=0.1)

# Fit/train LASSO
regressor.fit(X_train,y_train)
# Predict
X_pred = regressor.predict(X_test)

a= regressor.coef_
b = regressor.intercept_
c = np.sqrt(metrics.mean_squared_error(X_pred,y_test))

print('RMSE : %.2f' % c)
print('score : %.2f' % regressor.score(X_train,y_train))
# Out:
# RMSE : 17.01
# score : 0.37

# %%
names = list(X_le.columns.values)
report_coef(
  names,
  regressor.coef_,
  regressor.intercept_)
# Out:
#                                         coef   positive
# patientid                          -0.000000   0.000000
# City_Code_Patient                  -0.056820   0.056820
# Admission_Deposit                   0.087787   0.087787
# Visit Number                       -0.200844   0.200844
# Hospital_region_code                0.246487   0.246487
# Severity of Illness                -0.253918   0.253918
# Hospital_type_code                  0.439190   0.439190
# Department                          0.486087   0.486087
# Ward_Facility_Code                  0.507510   0.507510
# Hospital_code                       0.519537   0.519537
# City_Code_Hospital                 -0.633438   0.633438
# New Patient                         0.699002   0.699002
# Age                                 0.842015   0.842015
# Bed Grade                          -0.878296   0.878296
# Available Extra Rooms in Hospital  -1.823557   1.823557
# Type of Admission                   1.860052   1.860052
# Ward_Type                           4.217088   4.217088
# Visitors with Patient              12.237536  12.237536
# Intercept: 31.985858997892446

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part7'></a>
# # ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### First Model

# %%
model = Sequential()
model.add(Dense(64, input_dim=X.shape[1], activation='relu'))
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-2, patience=5, verbose=1, mode='auto')
r = model.fit(X_train,y_train,verbose=1,epochs=100)
pred = model.predict(X_test)
# Out:
# Train on 235344 samples
# Epoch 1/100
# 235344/235344 [==============================] - 6s 26us/sample - loss: 325.7933
# Epoch 2/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 262.0113
# Epoch 3/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 256.5576
# Epoch 4/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 253.7319
# Epoch 5/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 252.0407
# Epoch 6/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 250.6949
# Epoch 7/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 249.7415
# Epoch 8/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 248.7331
# Epoch 9/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 247.8135
# Epoch 10/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 247.1515
# Epoch 11/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 246.6131
# Epoch 12/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 246.0635
# Epoch 13/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 245.7368
# Epoch 14/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 245.3632
# Epoch 15/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 245.1874
# Epoch 16/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 244.9272
# Epoch 17/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 244.6867
# Epoch 18/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 244.5307
# Epoch 19/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 244.3913
# Epoch 20/100
# 235344/235344 [==============================] - 7s 30us/sample - loss: 244.2475
# Epoch 21/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 244.1316
# Epoch 22/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 243.9733
# Epoch 23/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 243.8925
# Epoch 24/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 243.9006
# Epoch 25/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 243.6488
# Epoch 26/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 243.6148
# Epoch 27/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 243.5349
# Epoch 28/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 243.5003
# Epoch 29/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 243.3595
# Epoch 30/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 243.1979
# Epoch 31/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 243.2362
# Epoch 32/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 243.0597
# Epoch 33/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 243.0035
# Epoch 34/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.9166
# Epoch 35/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.8099
# Epoch 36/100
# 235344/235344 [==============================] - 6s 26us/sample - loss: 242.7614
# Epoch 37/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.6829
# Epoch 38/100
# 235344/235344 [==============================] - 6s 26us/sample - loss: 242.6542
# Epoch 39/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.6161
# Epoch 40/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.5479
# Epoch 41/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.4926
# Epoch 42/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.3657
# Epoch 43/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.4406
# Epoch 44/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.2817
# Epoch 45/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.2481
# Epoch 46/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.2591
# Epoch 47/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 242.1553
# Epoch 48/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.1002
# Epoch 49/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.0646
# Epoch 50/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 242.0677
# Epoch 51/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 241.9250
# Epoch 52/100
# 235344/235344 [==============================] - 6s 26us/sample - loss: 241.8992
# Epoch 53/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 241.8955
# Epoch 54/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 241.67140s - loss: 24
# Epoch 55/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.6166
# Epoch 56/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.5859
# Epoch 57/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.4900
# Epoch 58/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.4394
# Epoch 59/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.2847
# Epoch 60/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.1428
# Epoch 61/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 241.1962
# Epoch 62/100
# 235344/235344 [==============================] - 6s 26us/sample - loss: 241.07780s - los
# Epoch 63/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.9711
# Epoch 64/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.93580s - loss: 240
# Epoch 65/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.90020s - lo
# Epoch 66/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.7854
# Epoch 67/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.6160
# Epoch 68/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.5656
# Epoch 69/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.4738
# Epoch 70/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.4087
# Epoch 71/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.2924
# Epoch 72/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 240.1836
# Epoch 73/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.9850
# Epoch 74/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.8890
# Epoch 75/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.7147
# Epoch 76/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.71690s - loss: 239.
# Epoch 77/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.5609
# Epoch 78/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.5450
# Epoch 79/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.4216
# Epoch 80/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.3936
# Epoch 81/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.2413
# Epoch 82/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.2857
# Epoch 83/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.1905
# Epoch 84/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.1085
# Epoch 85/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.1961
# Epoch 86/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 239.0647
# Epoch 87/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 239.04480s - loss: 2
# Epoch 88/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 239.02490s  - ETA: 0s - loss: 239.173
# Epoch 89/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.9871
# Epoch 90/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.91580s - loss: 238.96
# Epoch 91/100
# 235344/235344 [==============================] - 6s 25us/sample - loss: 238.8074
# Epoch 92/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.8742
# Epoch 93/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.7956
# Epoch 94/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.6616
# Epoch 95/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.6737
# Epoch 96/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.6757
# Epoch 97/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.6208
# Epoch 98/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.5411
# Epoch 99/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.5054
# Epoch 100/100
# 235344/235344 [==============================] - 6s 24us/sample - loss: 238.4807

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)
train_score = np.sqrt(metrics.mean_squared_error(train_pred,y_train))
test_score = np.sqrt(metrics.mean_squared_error(test_pred,y_test))

print("Train score (RMSE): {}".format(train_score))
print("Test score (RMSE): {}".format(test_score))

## plot the loss on the training data, and also the validation data
plt.figure(figsize=(10,10))

plt.plot(r.history['loss'])

plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# Train score (RMSE): 15.427693744302918
# Test score (RMSE): 15.423764239997213

# %%
def stay_cat(x):
    
    return np.floor((x-5)/10).astype(int)

# %%
y_pred_train = stay_cat(train_pred)
y_compare_train = encoder.fit_transform(y_train)
y_pred_test = stay_cat(test_pred)
y_compare_test = encoder.fit_transform(y_test)

train_accuracy =  metrics.accuracy_score(y_pred_train, y_compare_train)
print("Train accuracy score: {}".format(train_accuracy))
test_accuracy =   metrics.accuracy_score(y_pred_test, y_compare_test)
print("Train accuracy score: {}".format(test_accuracy))
# Out:
# Train accuracy score: 0.3337837378475763
# Train accuracy score: 0.33589975652971993

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part8'></a>
# ### Model with L1 regularizer

# %%
from tensorflow.keras import regularizers
model = Sequential()
model.add(Dense(64, input_dim=X.shape[1], activation='relu',kernel_regularizer=regularizers.l1(0.01)))
#model.add(Dense(64, input_dim=x.shape[1], activation='relu',activity_regularizer=regularizers.l2(0.01)))
#model.add(Dense(64, input_dim=x.shape[1], activation='relu',
#                kernel_regularizer=regularizers.l2(0.01),
#                activity_regularizer=regularizers.l1(0.01),activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-1, patience=5, verbose=1, mode='auto')

r = model.fit(X_train,y_train,callbacks=[monitor],validation_split=0.25,verbose=1,epochs=1000)
# Out:
# Train on 176508 samples, validate on 58836 samples
# Epoch 1/1000
# 176508/176508 [==============================] - 6s 36us/sample - loss: 350.9501 - val_loss: 274.2862
# Epoch 2/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 271.7047 - val_loss: 266.3572
# Epoch 3/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 266.6812 - val_loss: 262.2606
# Epoch 4/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 263.3019 - val_loss: 260.2548
# Epoch 5/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 260.9678 - val_loss: 258.3157
# Epoch 6/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 259.0017 - val_loss: 256.2462
# Epoch 7/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 257.1169 - val_loss: 254.5957
# Epoch 8/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 255.7523 - val_loss: 254.2643
# Epoch 9/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 254.6271 - val_loss: 253.3886
# Epoch 10/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 253.5702 - val_loss: 252.4477
# Epoch 11/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 252.6692 - val_loss: 250.7853
# Epoch 12/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 251.8737 - val_loss: 250.8343
# Epoch 13/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 251.2561 - val_loss: 250.2954
# Epoch 14/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 250.6900 - val_loss: 250.0012
# Epoch 15/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 250.2185 - val_loss: 249.0747
# Epoch 16/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 249.8696 - val_loss: 248.4536
# Epoch 17/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 249.4732 - val_loss: 248.3807
# Epoch 18/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 249.1272 - val_loss: 248.6124
# Epoch 19/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 248.8252 - val_loss: 248.7787
# Epoch 20/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 248.5959 - val_loss: 248.3983
# Epoch 21/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 248.4658 - val_loss: 247.0677
# Epoch 22/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 248.2069 - val_loss: 247.4763
# Epoch 23/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.9899 - val_loss: 247.4371
# Epoch 24/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.7843 - val_loss: 247.6256
# Epoch 25/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.6054 - val_loss: 246.7070
# Epoch 26/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.4001 - val_loss: 246.7817
# Epoch 27/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.1528 - val_loss: 247.0300
# Epoch 28/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.0837 - val_loss: 246.8429
# Epoch 29/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 247.0488 - val_loss: 246.4690
# Epoch 30/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 246.8230 - val_loss: 245.8151
# Epoch 31/1000
# 176508/176508 [==============================] - 6s 35us/sample - loss: 246.6444 - val_loss: 245.8636
# Epoch 32/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 246.6544 - val_loss: 246.0246
# Epoch 33/1000
# 176508/176508 [==============================] - 6s 34us/sample - loss: 246.5118 - val_loss: 246.0495
# Epoch 34/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 246.3038 - val_loss: 245.4251
# Epoch 35/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 246.3430 - val_loss: 246.1867
# Epoch 36/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 246.1918 - val_loss: 245.2347
# Epoch 37/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 246.0913 - val_loss: 245.2923
# Epoch 38/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 245.9346 - val_loss: 246.2944
# Epoch 39/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 246.0008 - val_loss: 245.6671
# Epoch 40/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 245
1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.7742 - val_loss: 241.7990
# Epoch 93/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.7665 - val_loss: 241.3739
# Epoch 94/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.6570 - val_loss: 241.8489
# Epoch 95/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.7399 - val_loss: 241.6547
# Epoch 96/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.6872 - val_loss: 241.6780
# Epoch 97/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.5542 - val_loss: 240.9490
# Epoch 98/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.7050 - val_loss: 241.7899
# Epoch 99/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.5917 - val_loss: 241.6575
# Epoch 100/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.6386 - val_loss: 242.0434
# Epoch 101/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.6179 - val_loss: 241.3822
# Epoch 102/1000
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.5511 - val_loss: 241.5862
# Epoch 00102: early stopping

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)
train_score = np.sqrt(metrics.mean_squared_error(train_pred,y_train))
test_score = np.sqrt(metrics.mean_squared_error(test_pred,y_test))

print("Train score (RMSE): {}".format(train_score))
print("Test score (RMSE): {}".format(test_score))


## plot the loss on the training data, and also the validation data
plt.figure(figsize=(10,10))

plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# Train score (RMSE): 15.435978288318658
# Test score (RMSE): 15.433729568293245

# %%
y_pred_train = stay_cat(train_pred)
y_pred_test = stay_cat(test_pred)

train_accuracy =  metrics.accuracy_score(y_pred_train, y_compare_train)
print("Train accuracy score: {}".format(train_accuracy))
test_accuracy =   metrics.accuracy_score(y_pred_test, y_compare_test)
print("Train accuracy score: {}".format(test_accuracy))
# Out:
# Train accuracy score: 0.3395965055408253
# Train accuracy score: 0.34124080612882257

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part9'></a>
# ### Model with L2 regularizer

# %%
model = Sequential()
#model.add(Dense(64, input_dim=X.shape[1], activation='relu',kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(64, input_dim=X.shape[1], activation='relu',activity_regularizer=regularizers.l2(0.01)))
#model.add(Dense(64, input_dim=x.shape[1], activation='relu',
#                kernel_regularizer=regularizers.l2(0.01),
#                activity_regularizer=regularizers.l1(0.01),activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-1, patience=5, verbose=1, mode='auto')

r = model.fit(X_train,y_train,callbacks=[monitor],validation_split=0.25,verbose=0,epochs=50)

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)
train_score = np.sqrt(metrics.mean_squared_error(train_pred,y_train))
test_score = np.sqrt(metrics.mean_squared_error(test_pred,y_test))

print("Train score (RMSE): {}".format(train_score))
print("Test score (RMSE): {}".format(test_score))


## plot the loss on the training data, and also the validation data
plt.figure(figsize=(10,10))

plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# Train score (RMSE): 15.581470539508667
# Test score (RMSE): 15.564769840649074

# %%
y_pred_train = stay_cat(train_pred)
y_pred_test = stay_cat(test_pred)

train_accuracy =  metrics.accuracy_score(y_pred_train, y_compare_train)
print("Train accuracy score: {}".format(train_accuracy))
test_accuracy =   metrics.accuracy_score(y_pred_test, y_compare_test)
print("Train accuracy score: {}".format(test_accuracy))
# Out:
# Train accuracy score: 0.33427238425453804
# Train accuracy score: 0.3356575609631735

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part10'></a>
# ### Model with 2 hidden layers

# %%
from tensorflow.keras.layers import Dropout
model = Sequential()
#model.add(Dropout(0.1, input_shape=(X.shape[1],)))
model.add(Dense(64, input_dim=X.shape[1], activation='relu'))
#model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
#model.add(Dropout(0.1))
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='lo
200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 229.2584
# Epoch 65/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 229.2122s - loss: 229
# Epoch 66/200
# 235344/235344 [==============================] - 13s 55us/sample - loss: 229.0711
# Epoch 67/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 228.9326
# Epoch 68/200
# 235344/235344 [==============================] - 13s 56us/sample - loss: 228.8707
# Epoch 69/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.8659
# Epoch 70/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.7110
# Epoch 71/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.5392
# Epoch 72/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.6530
# Epoch 73/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.4251
# Epoch 74/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.2625
# Epoch 75/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 228.3118
# Epoch 76/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.1684
# Epoch 77/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.1922
# Epoch 78/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.0296
# Epoch 79/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 228.0025
# Epoch 80/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 227.8169
# Epoch 81/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 227.8942
# Epoch 82/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 227.7150
# Epoch 83/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.6525
# Epoch 84/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.5849s - - ETA: 2s
# Epoch 85/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.4728s - loss: 227.495
# Epoch 86/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.5937
# Epoch 87/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.3900
# Epoch 88/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 227.3831s -
# Epoch 89/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 227.4604
# Epoch 90/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 227.1998
# Epoch 91/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.2426s
# Epoch 92/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.0993
# Epoch 93/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 227.0306s - loss: 225.  - E
# Epoch 94/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 227.0299s - los
# Epoch 95/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.8528
# Epoch 96/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 226.8345
# Epoch 97/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.9274
# Epoch 98/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.7525s - loss: 226.6
# Epoch 99/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 226.8180
# Epoch 100/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.6926s - loss: 226.7
# Epoch 101/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 226.6980
# Epoch 102/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 226.7271
# Epoch 103/200
# 235344/235344 [==============================] - 12s 53us/sample - loss: 226.4794
# Epoch 104/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.5699
# Epoch 105/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.4722
# Epoch 106/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.4070
# Epoch 107/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.2708
# Epoch 108/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.2956s - loss:
# Epoch 109/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.2295
# Epoch 110/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 226.1678
# Epoch 111/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 226.1885
# Epoch 112/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.1552
# Epoch 113/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 226.0198
# Epoch 114/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 226.0513
# Epoch 115/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 226.0241
# Epoch 116/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.9572
# Epoch 117/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.8267
# Epoch 118/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.7348s - loss: 225.7
# Epoch 119/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.6635
# Epoch 120/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.7484
# Epoch 121/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.6372
# Epoch 122/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.5674s - loss
# Epoch 123/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.7009
# Epoch 124/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.5498
# Epoch 125/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.5502
# Epoch 126/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.4352
# Epoch 127/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.5259
# Epoch 128/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.3320
# Epoch 129/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.3867
# Epoch 130/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.3235
# Epoch 131/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.2909
# Epoch 132/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.3173
# Epoch 133/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.1863
# Epoch 134/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.1967
# Epoch 135/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 224.9928
# Epoch 136/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.0847s - loss: 225.077
# Epoch 137/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 225.0492
# Epoch 138/200
# 235344/235344 [==============================] - 13s 54us/sample - loss: 225.1114
# Epoch 139/200
# 235344/235344 [==============================] - 13s 55us/sample - loss: 225.0805
# Epoch 140/200
# 235344/235344 [==============================] - 13s 53us/sample - loss: 224.9332
# Epoch 00140: early stopping

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)
train_score = np.sqrt(metrics.mean_squared_error(train_pred,y_train))
test_score = np.sqrt(metrics.mean_squared_error(test_pred,y_test))

print("Train score (RMSE): {}".format(train_score))
print("Test score (RMSE): {}".format(test_score))


## plot the loss on the training data, and also the validation data
plt.figure(figsize=(10,10))

plt.plot(r.history['loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()
# Out:
# Train score (RMSE): 14.92628430029035
# Test score (RMSE): 15.368111812061327

# %%
y_pred_train = stay_cat(train_pred)
y_pred_test = stay_cat(test_pred)

train_accuracy =  metrics.accuracy_score(y_pred_train, y_compare_train)
print("Train accuracy score: {}".format(train_accuracy))
test_accuracy =   metrics.accuracy_score(y_pred_test, y_compare_test)
print("Train accuracy score: {}".format(test_accuracy))
# Out:
# Train accuracy score: 0.34616986198925825
# Train accuracy score: 0.34158497877602007

# %% [markdown]
# ## Model with 2 hidden layers

# %%
model = Sequential()
model.add(Dense(64, input_dim=X.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
r = model.fit(X_train,y_train,validation_split=0.25, verbose=1,epochs=100)
# Out:
# Train on 176508 samples, validate on 58836 samples
# Epoch 1/100
# 176508/176508 [==============================] - 7s 37us/sample - loss: 305.4965 - val_loss: 262.0628
# Epoch 2/100
# 176508/176508 [==============================] - 6s 35us/sample - loss: 260.5634 - val_loss: 254.3679
# Epoch 3/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 254.5249 - val_loss: 249.6191
# Epoch 4/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 250.7322 - val_loss: 248.2976
# Epoch 5/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 248.6800 - val_loss: 247.3066
# Epoch 6/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 247.1417 - val_loss: 243.8407
# Epoch 7/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 245.9309 - val_loss: 245.7655
# Epoch 8/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 244.9701 - val_loss: 242.7311
# Epoch 9/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 244.0677 - val_loss: 242.0211
# Epoch 10/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 243.4485 - val_loss: 245.0464
# Epoch 11/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 242.7804 - val_loss: 241.7404
# Epoch 12/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 242.1742 - val_loss: 241.3801
# Epoch 13/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 241.5903 - val_loss: 243.4328
# Epoch 14/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 240.9657 - val_loss: 239.6150
# Epoch 15/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 240.4187 - val_loss: 239.4121
# Epoch 16/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 240.0688 - val_loss: 239.1380
# Epoch 17/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 239.6270 - val_loss: 240.1573
# Epoch 18/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 239.4212 - val_loss: 238.9476
# Epoch 19/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 238.9762 - val_loss: 240.2479
# Epoch 20/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 238.8441 - val_loss: 238.5429
# Epoch 21/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 238.5653 - val_loss: 240.9350
# Epoch 22/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 238.3768 - val_loss: 239.4364
# Epoch 23/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 238.1942 - val_loss: 239.4451
# Epoch 24/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 237.9347 - val_loss: 239.9575
# Epoch 25/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 237.7883 - val_loss: 238.7170
# Epoch 26/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 237.5616 - val_loss: 240.7031
# Epoch 27/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 237.4751 - val_loss: 241.4666
# Epoch 28/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 237.3359 - val_loss: 238.8803
# Epoch 29/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 237.0752 - val_loss: 238.4871
# Epoch 30/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 237.0227 - val_loss: 239.2626
# Epoch 31/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 236.5505 - val_loss: 238.5573
# Epoch 32/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 236.5971 - val_loss: 237.5858
# Epoch 33/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 236.5291 - val_loss: 238.5608
# Epoch 34/100
# 176508/176508 [==============================] - 6s 34us/sample - loss: 236.3642 - val_loss: 238.3621
# Epoch 35/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 236.2360 - val_loss: 237.7344
# Epoch 36/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 236.0148 - val_loss: 238.2446
# Epoch 37/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.8638 - val_loss: 237.8825
# Epoch 38/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.6986 - val_loss: 238.3833
# Epoch 39/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.5936 - val_loss: 237.5382
# Epoch 40/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.5669 - val_loss: 237.4603
# Epoch 41/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.3878 - val_loss: 238.2407
# Epoch 42/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.1460 - val_loss: 239.6766
# Epoch 43/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 235.2393 - val_loss: 237.0066
# Epoch 44/100
# 176508/176508 [==============================] - 6s 33us/sample - loss: 234