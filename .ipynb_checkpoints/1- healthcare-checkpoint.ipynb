# %% [markdown]
# # Health Care Dataset - INM701 Coursework
# Postgraduate students:
# - Tamila Skakova
# - Elbaraa Elalami

# %% [markdown]
# ## Content:
# - **[Part 1](#part1)- Importing the data set, packages used**
# - **[Part 2](#part2)- Exploratory data analysis**
# - [Part 2.1](#part2.1)- Analysis of the features
# - [Part 2.2](#part2.2)- Analysis of the Target
# - [Part 2.3](#part2.3)- Statistical analysis of the dataset
# - **[Part 3](#part3) -  Preparing our data**
# - [Part 3.1](#part3.1) -  Missing Values
# - [Part 3.2](#part3.2) -  Enconding, Shuffling, Scaling
# - [Part 3.3](#part3.3) -  PCA
# - [Part 3.4](#part3.4) -  SMOTE Analysis
# - **[Part 4/1](#part4/1) -  Models**
# - [Part 4.1.1](#part4.1.1) -  Score method
# - [Part 4.1.2](#part4.1.2) -  KNN
# - [Part 4.1.3](#part4.1.3) -  Decision tree model
# - [Part 4.1.4](#part4.1.4) -  Random Forest
# - [Part 4.1.5](#part4.1.5) -  Naive Bayes
# - [Part 4.1.6](#part4.1.6) -  ANN
# - **[Part 4/2](#part4/2) -  Models with SMOTE**
# - [Part 4.2.1](#part4.2.1) -  KNN
# - [Part 4.2.2](#part4.2.2) -  Decision tree model
# - [Part 4.2.3](#part4.2.3) -  Random Forest
# - [Part 4.2.4](#part4.2.4) -  Naive Bayes
# - [Part 4.2.5](#part4.2.5) -  ANN
# - **[Part 5](#part5) -  Additional Models**
# - [Part 5.1](#part5.1) -  Gradient Boost Classifier
# - [Part 5.2](#part5.2) -  CatBoost Classifier
# - [Part 5.2](#part5.2) -  XGB BOOST Classifier

# %% [markdown]
# ## Description of features in the dataframe:
#
# - `Column`	Description
# - `case_id`	Case_ID registered in Hospital
# - `Hospital_code`	Unique code for the Hospital
# - `Hospital_type_code`	Unique code for the type of Hospital
# - `City_Code_Hospital` City Code of the Hospital
# - `Hospital_region_code`	Region Code of the Hospital
# - `Available Extra Rooms in Hospital`	Number of Extra rooms available in the Hospital
# - `Department`	Department overlooking the case
# - `Ward_Type`	Code for the Ward type
# - `Ward_Facility_Code`	Code for the Ward Facility
# - `Bed Grade`	Condition of Bed in the Ward
# - `patientid`	Unique Patient Id
# - `City_Code_Patient`	City Code for the patient
# - `Type of Admission`	Admission Type registered by the Hospital
# - `Severity of Illness`	Severity of the illness recorded at the time of admission
# - `Visitors with Patient`	Number of Visitors with the patient
# - `Age`	Age of the patient
# - `Admission_Deposit`	Deposit at the Admission Time
# - `Stay`	Stay Days by the patient, the length of stay - 11 different classes ranging from 0-10 days to more than 100 days.

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part1'></a>
#
# ## Part 1 -  Importing the data set, packages used

# %%
import os
import pandas as pd
import numpy as np
import sklearn as sk
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
import io
import time
import requests
# %matplotlib inline

# %%
path = "healthcare"

filename_read = os.path.join(path, "train_data.csv")
health_care = pd.read_csv(filename_read, na_values=['NA', '?'])

# print(health_care.shape)
# print(health_care.columns)

# %%
health_care.head(10)
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
# 5        6             23                  a                   6
# 6        7             32                  f                   9
# 7        8             23                  a                   6
# 8        9              1                  d                  10
# 9       10             10                  e                   1
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
# 5                    X                                  2    anesthesia
# 6                    Y                                  1  radiotherapy
# 7                    X                                  4  radiotherapy
# 8                    Y                                  2    gynecology
# 9                    X                                  2    gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
# 5         S                  F        2.0      31397                7.0
# 6         S                  B        3.0      31397                7.0
# 7         Q                  F        3.0      31397                7.0
# 8         R                  B        4.0      31397                7.0
# 9         S                  E        3.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
# 5            Trauma             Extreme                      2  51-60
# 6         Emergency             Extreme                      2  51-60
# 7            Trauma             Extreme                      2  51-60
# 8            Trauma             Extreme                      2  51-60
# 9            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50
# 5             4449.0  11-20
# 6             6167.0   0-10
# 7             5571.0  41-50
# 8             7223.0  51-60
# 9             6056.0  31-40

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2'></a>
# ## Part 2- Exploratory data analysis (EDA)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2.1'></a>
# ### Analysis of the features

# %%
#sorting by Stay for better representation in the visualisations
health_care = health_care.sort_values(by = "Stay", ascending = True)
# To make sure we consider all the correct features to make an accurate prediction, it may be useful to create some plots to have a better understanding of our data and relationship between them and the output feature. For that we have used Python data visualisation library seaborn. We begin by visualising the length of stays by age of patients admitted to hospitals, type of admissions, severity of illness, available extra rooms in hospitals,  etc., by using a countplot(), that shows the counts of observations in each categorical bin using bars.

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Age", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Age", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Hospital_region_code", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Hospital_region_code", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (20,4))
#plot title
plt.title("Available Extra Rooms in Hospital", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Available Extra Rooms in Hospital", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Type of Admission", fontdict = {'fontsize': 15})
ax = sns.countplot(x = "Type of Admission", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Severity of Illness", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Severity of Illness", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,8))
#plot title
plt.title("Department", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Department", hue = 'Stay', data = health_care)

# %%
#using LabelEncoder to change and transform the object format of 
corr_data = health_care.copy()
le = LabelEncoder()
for col in ['Hospital_type_code', 'Ward_Type', 'Department', 'Age', 'Stay']:
    corr_data[col]= corr_data[col].astype('str')
    corr_data[col]= le.fit_transform(corr_data[col])
print (corr_data.dtypes)
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                     int32
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                             int32
# Ward_Type                              int32
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                    int32
# Admission_Deposit                    float64
# Stay                                   int32
# dtype: object

# %%
# Heatmap
fig, ax = plt.subplots(figsize=(12,12))        
sns.heatmap(corr_data.corr(), annot=True, linewidths=1, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2.2'></a>
# ### Analysis of the Target

# %%
## Checking target
#creating a copy of df to have an original for further manipulation
health_care_copy = health_care.copy()

# %%
#number of unique element for each feature
encoder = LabelEncoder()
health_care_copy['Stay_cat'] = encoder.fit_transform(health_care_copy['Stay'])
n = len(health_care_copy['Stay_cat'])
l = []
for i in range(len(np.unique(health_care_copy['Stay_cat']))):
    k = len(health_care[health_care_copy['Stay_cat']==i])
    #print(f'N {10*i} and {10*(i+1)} is : {k}')
    print(f'{i}- {k}  : {100*k/n:.2f}%')
# Out:
# 0- 23604  : 7.41%
# 1- 78139  : 24.54%
# 2- 87491  : 27.48%
# 3- 55159  : 17.32%
# 4- 11743  : 3.69%
# 5- 35018  : 11.00%
# 6- 2744  : 0.86%
# 7- 10254  : 3.22%
# 8- 4838  : 1.52%
# 9- 2765  : 0.87%
# 10- 6683  : 2.10%

# %%
#Visualisation of Target categories
fig, ax1 = plt.subplots()
labels = np.unique(health_care['Stay'])
labels[-1] = '100+'

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:6]
plt.pie(health_care.groupby('Stay').size(), labels = labels,colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(20, 15.5)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.title('Percentage of occurence of each category')
plt.show()

# %%
#Histogram plot
h = health_care['Stay'].sort_values()
h[h=='More than 100 Days'] = '100+'
plt.figure(figsize = (8,8))
plt.hist(h, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)

plt.xlabel('LOS')
plt.ylabel('Occurence')
plt.title('Histogram of LOS')

plt.grid(True)
plt.show()

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2.3'></a>
# ### Statistical analysis of the dataset

# %%
#statistical analysis of each feature
df_copy = health_care.copy()
new_df_copy = df_copy.drop(columns = ["case_id", "Hospital_code", "City_Code_Hospital", "Bed Grade", "patientid", "City_Code_Patient"])
new_df_copy = new_df_copy.select_dtypes(include=["int","float"])
headers = list(new_df_copy.columns.values)
fields = []
for field in headers:
    fields.append({
        "name":field,
        "mean":health_care[field].mean(),
        "var":health_care[field].var(),
        "sdev":health_care[field].std()
    })
for field in fields:
    print(field)
# Out:
# {'name': 'Available Extra Rooms in Hospital', 'mean': 3.1976271676119055, 'var': 1.3646244848651312, 'sdev': 1.1681714278585704}
# {'name': 'Visitors with Patient', 'mean': 3.2840992595104854, 'var': 3.11191258613169, 'sdev': 1.764061389558677}
# {'name': 'Admission_Deposit', 'mean': 4880.749392346391, 'var': 1181082.6254792996, 'sdev': 1086.776253641613}

# %%
## functions to feed to barplot
def mean(x):
    return np.mean(x)

def median(x):
    return np.median(x)

def std(x):
    return np.std(x)

# %%
## Encoding data
df_copy2 = health_care.copy()
target = df_copy2['Stay']
target_enc = encoder.fit_transform(target)

# %%
## Estimate of length of stay
target_estimate = 10* (target_enc) + 5
# Adding the estimate to the dataframe
df_copy2['Stay Estimate'] = target_estimate

# %%
## Using only Features with limited classes for the plot
elements_to_remove = ['case_id', 'patientid', 'Admission_Deposit', 'Stay', 'Stay Estimate']
column_features = [ column for column in df_copy2.columns if column not in elements_to_remove]
print(column_features)
# Out:
# ['Hospital_code', 'Hospital_type_code', 'City_Code_Hospital', 'Hospital_region_code', 'Available Extra Rooms in Hospital', 'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade', 'City_Code_Patient', 'Type of Admission', 'Severity of Illness', 'Visitors with Patient', 'Age']

# %%
# Mean Analysis
#We study the relationship between the mean of stay and each feature
for feature in column_features :
    order = pd.unique(df_copy2[feature])
    order.sort()
    ax = sns.barplot(x=feature, y="Stay Estimate", data=df_copy2,order=order, estimator=mean)
    ax.set_title(f'Means of {feature} classes') 
    plt.show();

# %%
#Median Analysis
for feature in column_features :
    order = pd.unique(df_copy2[feature])
    order.sort()
    ax = sns.barplot(x=feature, y="Stay Estimate", data=df_copy2,order=order, estimator=median)
    ax.set_title(f'Medians of {feature} classes') 
    plt.show();

# %%
#Analysis of Std
for feature in column_features :
    order = pd.unique(df_copy2[feature])
    order.sort()
    ax = sns.barplot(x=feature, y="Stay Estimate", data=df_copy2,order=order, estimator=std)
    ax.set_title(f'Stds of {feature} classes') 
    plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3'></a>
# ## Part 3 - Preparing our data

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.1'></a>
# ### Missing Values

# %%
#checking for missing values
health_care.isnull().values.any()
# Out:
# True

# %%
#Checking number of NANs for each column, in order to understand how many missing values there are in a dataframe.
print("# of NaN in each columns:", health_care.isnull().sum(), sep='\n')
# Out:
# # of NaN in each columns:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
#calculates percentage of missing values in the specific feature
def perc_mv(x, y):
    perc = y.isnull().sum() / len(x) * 100
    return perc

# %%
print('Missing value ratios:\nBed Grade: {}\nCity_Code_Patient: {}'.format(
    perc_mv(health_care, health_care['Bed Grade']),
    perc_mv(health_care, health_care['City_Code_Patient'])))
# Out:
# Missing value ratios:
# Bed Grade: 0.035485714644609
# City_Code_Patient: 1.4231969802598936

# %%
#In the code cell below, we use the attribute dtype on df to retrieve the data type for each column.
print (health_care.dtypes)
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %%
#We want to map the name of each Severity of Illness to the corresponding number in ascending order.
health_care['Severity of Illness'] = health_care['Severity of Illness'].map({'Minor':1, 'Moderate': 2, 'Extreme':3})
health_care['Type of Admission'] = health_care['Type of Admission'].map({'Trauma':1, 'Emergency': 2, 'Urgent':3})
# health_care

# %%
#dropping features
elements_to_remove = ['case_id', 'City_Code_Hospital', 'City_Code_Patient', 'patientid', 'Bed Grade', 'Admission_Deposit']
health_care = health_care.drop(elements_to_remove, axis=1)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.2'></a>
# ### Enconding, Shuffling, Scaling

# %%
#using LabelEncoder to change and transform the object format of 
le = LabelEncoder()
for col in ['Hospital_type_code', 'Hospital_region_code','Ward_Type', 'Ward_Facility_Code', 'Department', 'Age', 'Stay']:
    health_care[col]= health_care[col].astype('str')
    health_care[col]= le.fit_transform(health_care[col])
print (health_care.dtypes)
# Out:
# Hospital_code                        int64
# Hospital_type_code                   int32
# Hospital_region_code                 int32
# Available Extra Rooms in Hospital    int64
# Department                           int32
# Ward_Type                            int32
# Ward_Facility_Code                   int32
# Type of Admission                    int64
# Severity of Illness                  int64
# Visitors with Patient                int64
# Age                                  int32
# Stay                                 int32
# dtype: object

# %%
# # Function to hot encode (forthe column with name : name for dataframe df
# def encode_text_dummy(df, name):
#     dummies = pd.get_dummies(df[name])
#     for x in dummies.columns:
#         dummy_name = f"{name}-{x}"
#         df[dummy_name] = dummies[x]
#     df.drop(name, axis=1, inplace=True) ## inplace to make changed on the original df

# %%
# # Columns where we use Label Encoding
# le_string_columns = ['Severity of Illness', 'Age' ]
# # Columns where we use One Hot Encoding
# dummies_string_columns = ['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type', 'Ward_Facility_Code']
# encoder = LabelEncoder()

# ## label_encoded data
# Xe = health_care.drop(['Stay'], axis=1)
# Xe['Severity of Illness']= Xe['Severity of Illness'].map({'Minor': 0,  'Moderate': 1,'Extreme': 2})
# Xe['Age'] = encoder.fit_transform(Xe['Age'])

# ye = health_care['Stay']
# ye = encoder.fit_transform(ye)

# for column in dummies_string_columns :
#     encode_text_dummy(Xe, column)

# %%
# #Scaling Hot Encoded Data
# scaler = StandardScaler()
# X = Xe.values
# y = ye
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
# for i in range(X_train.shape[1]) :
#     X_train[:,i]= scaler.fit_transform(X_train[:,i].reshape(-1, 1))[:,0]
#     X_test[:,i] = scaler.transform(X_test[:,i].reshape(-1, 1))[:,0]

# %%
#shuffling
health_care= health_care.reindex(np.random.permutation(health_care.index))
health_care.reset_index(inplace=True, drop=True)

# %%
#initialisation
X = health_care.drop(columns = ["Stay"])
y = health_care["Stay"]

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.3'></a>
# ### PCA

# %%
#Principal component analysis
#Choosing the number of components
scaler=StandardScaler()
X_scaler = StandardScaler().fit_transform(X)
pca = PCA().fit(X_scaler)

# %%
#Plotting the Cumulative Summation of the Explained Variance
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Dataset Explained Variance')
plt.show()

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.17298781, 0.30416866, 0.4148431 , 0.51060786, 0.60149156,
#        0.68618983, 0.76989892, 0.84533686, 0.91412017, 0.96105488,
#        1.        ])

# %%
# For our analysis we choose n_components = 8
pca = PCA(n_components=8)
X_pca = pca.fit_transform(X_scaler)
X_pca_with_constant = sm.add_constant(X_pca)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.4'></a>
# ### SMOTE analysis
# Here we will only study imbalance data for our later implementation in Part 4/2

# %%
health_care["Stay"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
smote_health_care = health_care.copy()

# X = np.array(smote_health_care.loc[:, smote_health_care.columns != "Stay"])
y = np.array(smote_health_care.loc[:, smote_health_care.columns == "Stay"]).reshape(-1, 1)

X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 2, shuffle = True, stratify = y)
oversample = SMOTE(random_state = 33)
X_train_SMOTE, y_train_SMOTE = oversample.fit_resample(X_train, y_train)

# %%
# observe that data has been balanced
pd.Series(y_train_SMOTE).value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4/1'></a>
#
# ## Part - 4 Models

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.1'></a>
# ### Score method

# %%
# Score of 1 is perfect. The closer the score to 1 the better
K = 10 # Num of Classes - 1 here

# Classes can be ranked here from 0-10
def score(pred, target):
    error = (np.mean(np.abs(pred-target)))/K
    score = 1 - error
    return score

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.2'></a>
# ### KNN

# %%
# Splitting dataset
y = health_care["Stay"]
X_train, X_test, y_train, y_test = train_test_split(X_pca_with_constant, y, test_size = 0.33, random_state = 2, shuffle = True, stratify = y)

# %%
knn = KNeighborsClassifier(n_neighbors=11) 
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred = knn.predict(X_test)

# %%
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
print(f'Score : %.2f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy: 0.35
# Score : 0.87

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.347642384736166
# Recall: 0.347642384736166

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      0.12      0.15      7789
#            1       0.34      0.44      0.39     25786
#            2       0.38      0.51      0.44     28872
#            3       0.30      0.22      0.26     18203
#            4       0.09      0.00      0.01      3875
#            5       0.36      0.36      0.36     11556
#            6       0.09      0.00      0.00       906
#            7       0.20      0.05      0.07      3384
#            8       0.24      0.10      0.14      1597
#            9       0.20      0.01      0.02       912
#           10       0.49      0.33      0.40      2205
#
#     accuracy                           0.35    105085
#    macro avg       0.26      0.20      0.20    105085
# weighted avg       0.32      0.35      0.32    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.3'></a>
# ### Decision Trees

# %%
tree = DecisionTreeClassifier(criterion='entropy')
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = tree.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.2f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.330
# Score : 0.86

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3299519436646524
# Recall: 0.3299519436646524

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.16      0.17      7789
#            1       0.34      0.41      0.37     25786
#            2       0.38      0.48      0.43     28872
#            3       0.29      0.22      0.25     18203
#            4       0.06      0.02      0.03      3875
#            5       0.35      0.31      0.33     11556
#            6       0.05      0.02      0.02       906
#            7       0.19      0.11      0.14      3384
#            8       0.23      0.19      0.21      1597
#            9       0.13      0.08      0.10       912
#           10       0.41      0.33      0.37      2205
#
#     accuracy                           0.33    105085
#    macro avg       0.24      0.21      0.22    105085
# weighted avg       0.31      0.33      0.32    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.4'></a>
# ### Random Forest

# %%
forest = RandomForestClassifier(n_estimators=60, criterion='entropy')
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=60)

# %%
y_pred = forest.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.347
# Score : 0.8729

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3471570633296855
# Recall: 0.3471570633296855

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.19      0.10      0.13      7789
#            1       0.36      0.38      0.37     25786
#            2       0.39      0.53      0.45     28872
#            3       0.29      0.23      0.26     18203
#            4       0.07      0.02      0.03      3875
#            5       0.36      0.39      0.38     11556
#            6       0.05      0.01      0.02       906
#            7       0.21      0.10      0.14      3384
#            8       0.27      0.18      0.22      1597
#            9       0.18      0.07      0.10       912
#           10       0.45      0.42      0.44      2205
#
#     accuracy                           0.35    105085
#    macro avg       0.26      0.22      0.23    105085
# weighted avg       0.32      0.35      0.33    105085

# %%
#to evaluate the importance of features 
start_time = time.time()
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
elapsed_time = time.time() - start_time

print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to compute the importances: 0.108 seconds

# %%
#The blue bars are the feature importances of the forest, along with their inter-trees variability represented by the error bars.
feature_names = [f"feature {i}" for i in range(X.shape[1])]
forest_importances = pd.Series(importances, index=feature_names)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %%
### Cross Validating to check some results
kf = KFold(10, shuffle=True)
fold = 1

for train_index, validate_index in kf.split(X,y):
    forest.fit(X[train_index], y[train_index])
    ytest = y[validate_index]
    y_pred = forest.predict(X[validate_index])
    print(f'Accuracy : %.4f' % accuracy_score(ytest, y_pred))
    print(f'Score : %.4f' % score(ytest.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.3449
# Score : 0.8730
# Accuracy : 0.3507
# Score : 0.8743
# Accuracy : 0.3523
# Score : 0.8742
# Accuracy : 0.3492
# Score : 0.8741
# Accuracy : 0.3510
# Score : 0.8748
# Accuracy : 0.3535
# Score : 0.8750
# Accuracy : 0.3536
# Score : 0.8751
# Accuracy : 0.3536
# Score : 0.8757
# Accuracy : 0.3562
# Score : 0.8756
# Accuracy : 0.3519
# Score : 0.8749

# %%
accuracy_data = []
score_data = []

for i in range(20,70,4):
    forest = RandomForestClassifier(n_estimators=i, criterion='entropy')
    forest.fit(X_train, y_train)
    y_pred = forest.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    score = 1-(np.mean(np.abs(y_test-y_pred)))/K
    print(f'n_estimators : {i}')
    print(f'Accuracy : %.4f' % accuracy)
    print(f'Score  : %.4f' % score)
    print('--------------')
    accuracy_data.append(accuracy)
    score_data.append(score)
# Out:
# n_estimators : 20
# Accuracy : 0.3435
# Score  : 0.8716
# --------------
# n_estimators : 24
# Accuracy : 0.3439
# Score  : 0.8717
# --------------
# n_estimators : 28
# Accuracy : 0.3466
# Score  : 0.8726
# --------------
# n_estimators : 32
# Accuracy : 0.3455
# Score  : 0.8725
# --------------
# n_estimators : 36
# Accuracy : 0.3480
# Score  : 0.8727
# --------------
# n_estimators : 40
# Accuracy : 0.3461
# Score  : 0.8724
# --------------
# n_estimators : 44
# Accuracy : 0.3454
# Score  : 0.8727
# --------------
# n_estimators : 48
# Accuracy : 0.3477
# Score  : 0.8728
# --------------
# n_estimators : 52
# Accuracy : 0.3470
# Score  : 0.8730
# --------------
# n_estimators : 56
# Accuracy : 0.3479
# Score  : 0.8732
# --------------
# n_estimators : 60
# Accuracy : 0.3473
# Score  : 0.8729
# --------------
# n_estimators : 64
# Accuracy : 0.3470
# Score  : 0.8731
# --------------
# n_estimators : 68
# Accuracy : 0.3477
# Score  : 0.8733
# --------------

# %%
#Plotting accuracy and score with increasing n_estimators
nums = []
for i in range(20,70,4):
    nums.append(i)

fig = plt.figure(figsize=(6,5))
plt.plot(nums, accuracy_data, c='r', label='Accuracy')
plt.plot(nums, score_data, label='Score')
plt.xlabel('Number of Trees')
plt.ylabel('Accuracy and Score')
plt.legend(loc='upper right')
plt.show()

# %%
#Last Model results
y_pred = forest.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test-y_pred))/K
print(f'Score : %.4f' % score)
# Out:
# Accuracy : 0.348
# Score : 0.8733

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3476994813722225
# Recall: 0.3476994813722225

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4.1.5'></a>
# ### Naive Bayes

# %%
smoothing = [1e-3, 1e-2, 1e-1, 1, 10]

for var_smoothing in smoothing :
    model = GaussianNB(var_smoothing=var_smoothing)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f'Smoothing parameter : {var_smoothing}')
    print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
    score = 1-np.mean(np.abs(y_test-y_pred))/K
    print(f'Score : %.4f' % score)
    print('----------------------')
# Out:
# Smoothing parameter : 0.001
# Accuracy : 0.342
# Score : 0.8727
# ----------------------
# Smoothing parameter : 0.01
# Accuracy : 0.341
# Score : 0.8726
# ----------------------
# Smoothing parameter : 0.1
# Accuracy : 0.336
# Score : 0.8710
# ----------------------
# Smoothing parameter : 1
# Accuracy : 0.293
# Score : 0.8568
# ----------------------
# Smoothing parameter : 10
# Accuracy : 0.275
# Score : 0.8514
# ----------------------

# %%
## Keeping smoothing = 1
model = GaussianNB(var_smoothing=1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score)
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.293
# Score : 0.8514
# Precision: 0.29268687253176
# Recall: 0.29268687253176

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.6'></a>
# ### ANN

# %%
nn = Sequential()

#model.add(Dropout(0.1)) #applies to layer before ie input here
nn.add(Dense(32, input_dim=X.shape[1], activation='relu'))
nn.add(Dense(84, activation='relu'))
nn.add(Dense(11, activation='softmax'))

# %%
nn.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-4, patience=5, verbose=1, mode='auto')
nn.fit(X_train,y_train,verbose=1,epochs=50)
pred = nn.predict(X_test)
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
print(f'Score : %.4f' % score)
# Out:
# Epoch 1/50
# 6668/6668 [==============================] - 15s 2ms/step - loss: 11.4227
# Epoch 2/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 3/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 4/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 5/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 6/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 7/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 8/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 9/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 10/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 11/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 12/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 13/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 14/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 15/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 16/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 17/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 18/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 19/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 20/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 21/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 22/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 23/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 24/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 25/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 26/50
# 6668/6668 [==============================] - ETA: 0s - loss: 11.4244 ETA: 0s - l - 12s 2ms/step - loss: 11.4227
# Epoch 27/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 28/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 29/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 30/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 31/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 32/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 11.4227
# Epoch 33/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 11.4227
# Epoch 34/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 35/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 36/50
# 6668/6668 [==============================] - 14s 2ms/step - loss: 11.4227
# Epoch 37/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 38/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 39/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 40/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 41/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 42/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 43/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 44/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Epoch 45/50
# 6668/6668 [==============================] - 14s 2ms/step - loss: 11.4227
# Epoch 46/50
# 6668/6668 [==============================] - 13s 2ms/step - loss: 11.4227
# Epoch 47/50
# 6668/6668 [==============================] - 15s 2ms/step - loss: 11.4227
# Epoch 48/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 11.4227
# Epoch 49/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 11.4227
# Epoch 50/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 11.4227
# Accuracy: 0.29
# Score : 0.8514

# %%
nn.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-4, patience=5, verbose=1, mode='auto')
nn.fit(X_train,y_train,verbose=1,epochs=50)
pred = nn.predict(X_test)
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
print(f'Score : %.4f' % score)
# Out:
# Epoch 1/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.6390
# Epoch 2/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.6079
# Epoch 3/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5984
# Epoch 4/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5910
# Epoch 5/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5863
# Epoch 6/50
# 6668/6668 [==============================] - 9s 1ms/step - loss: 1.5831
# Epoch 7/50
# 6668/6668 [==============================] - 9s 1ms/step - loss: 1.5808
# Epoch 8/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5787
# Epoch 9/50
# 6668/6668 [==============================] - 16s 2ms/step - loss: 1.5774
# Epoch 10/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5759
# Epoch 11/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5750
# Epoch 12/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5736
# Epoch 13/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5726
# Epoch 14/50
# 6668/6668 [==============================] - 9s 1ms/step - loss: 1.5719
# Epoch 15/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5711
# Epoch 16/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5705
# Epoch 17/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5701
# Epoch 18/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5691:
# Epoch 19/50
# 6668/6668 [==============================] - 9s 1ms/step - loss: 1.5686
# Epoch 20/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 1.5684
# Epoch 21/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5677
# Epoch 22/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5674
# Epoch 23/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5671
# Epoch 24/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5666
# Epoch 25/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 1.5663
# Epoch 26/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5660
# Epoch 27/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5656
# Epoch 28/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5654
# Epoch 29/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5654
# Epoch 30/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5649: 0s - loss: 1.
# Epoch 31/50
# 6668/6668 [==============================] - 12s 2ms/step - loss: 1.5646
# Epoch 32/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5648
# Epoch 33/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5642
# Epoch 34/50
# 6668/6668 [==============================] - 9s 1ms/step - loss: 1.5642
# Epoch 35/50
# 6668/6668 [==============================] - 9s 1ms/step - loss: 1.5639
# Epoch 36/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5642
# Epoch 37/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5639
# Epoch 38/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5634
# Epoch 39/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5636
# Epoch 40/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5632
# Epoch 41/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5627
# Epoch 42/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5629
# Epoch 43/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5626
# Epoch 44/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5627
# Epoch 45/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5625
# Epoch 46/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5626
# Epoch 47/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5624
# Epoch 48/50
# 6668/6668 [==============================] - 11s 2ms/step - loss: 1.5620: - ETA: 2s - lo - E
# Epoch 49/50
# 6668/6668 [==============================] - 10s 2ms/step - loss: 1.5620
# Epoch 50/50
# 6668/6668 [==============================] - 10s 1ms/step - loss: 1.5615
# Accuracy: 0.25
# Score : 0.8514

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.2913546176904411
# Recall: 0.2913546176904411

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4/2'></a>
# ### Application of models with SMOTE
# Here we are applying SMOTE on imbalanced data.
#
#
# We are reintroducing smote again and splitting our balanced data, so that proper X_test is chosen, since we have already X_test from the previous analysis.

# %%
smote_health_care = health_care.copy()
# X = np.array(smote_health_care.loc[:, smote_health_care.columns != "Stay"])
y = np.array(smote_health_care.loc[:, smote_health_care.columns == "Stay"]).reshape(-1, 1)

X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 2, shuffle = True, stratify = y)
oversample = SMOTE(random_state = 33)
X_train_SMOTE, y_train_SMOTE = oversample.fit_resample(X_train, y_train)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.1'></a>
# ### KNN with SMOTE

# %%
#with Smote
knn = KNeighborsClassifier(n_neighbors=11) 
knn.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred = knn.predict(X_test)

# %%
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.25

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.24732359518485036
# Recall: 0.24732359518485036

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.2'></a>
# ### Decision Tree with SMOTE

# %%
#with SMOTE
tree.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = tree.predict(X_test)

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.290
# Precision: 0.29015558833325406
# Recall: 0.29015558833325406

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.27      0.21      7789
#            1       0.34      0.33      0.34     25786
#            2       0.40      0.37      0.38     28872
#            3       0.27      0.19      0.22     18203
#            4       0.07      0.10      0.08      3875
#            5       0.34      0.29      0.31     11556
#            6       0.02      0.04      0.03       906
#            7       0.14      0.16      0.15      3384
#            8       0.19      0.23      0.21      1597
#            9       0.07      0.11      0.08       912
#           10       0.32      0.37      0.34      2205
#
#     accuracy                           0.29    105085
#    macro avg       0.21      0.22      0.21    105085
# weighted avg       0.31      0.29      0.30    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.3'></a>
# ### Random Forest with SMOTE

# %%
forest = RandomForestClassifier(n_estimators=60, criterion='entropy')
forest.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=60)

# %%
y_pred = forest.predict(X_test)

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.297
# Precision: 0.2972736356283009
# Recall: 0.2972736356283009

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.27      0.21      7789
#            1       0.36      0.31      0.33     25786
#            2       0.40      0.39      0.39     28872
#            3       0.26      0.19      0.22     18203
#            4       0.07      0.11      0.08      3875
#            5       0.35      0.33      0.34     11556
#            6       0.02      0.04      0.03       906
#            7       0.15      0.18      0.16      3384
#            8       0.21      0.31      0.25      1597
#            9       0.08      0.13      0.10       912
#           10       0.33      0.43      0.38      2205
#
#     accuracy                           0.30    105085
#    macro avg       0.22      0.25      0.23    105085
# weighted avg       0.31      0.30      0.30    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.4'></a>
# ### Naive Bayes with SMOTE

# %%
## Keeping smoothing = 1
model = GaussianNB(var_smoothing=1)
model.fit(X_train_SMOTE, y_train_SMOTE)
y_pred = model.predict(X_test)

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.195
# Precision: 0.19455678736261123
# Recall: 0.19455678736261123

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.64      0.22      7789
#            1       0.38      0.12      0.18     25786
#            2       0.43      0.23      0.30     28872
#            3       0.26      0.01      0.03     18203
#            4       0.05      0.14      0.08      3875
#            5       0.34      0.27      0.30     11556
#            6       0.01      0.20      0.02       906
#            7       0.25      0.00      0.01      3384
#            8       0.13      0.69      0.23      1597
#            9       0.05      0.03      0.03       912
#           10       0.50      0.26      0.34      2205
#
#     accuracy                           0.19    105085
#    macro avg       0.23      0.24      0.16    105085
# weighted avg       0.32      0.19      0.19    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.5'></a>
# ### ANN with SMOTE

# %%
nn = Sequential()

#model.add(Dropout(0.1)) #applies to layer before ie input here
nn.add(Dense(12, input_dim=X.shape[1], activation='relu'))
nn.add(Dense(8, activation='relu'))
nn.add(Dense(1, activation='sigmoid'))
nn.add(Dropout(0.2))
nn.add(Dense(1))

# %%
nn.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-4, patience=5, verbose=1, mode='auto')

# %%
nn.fit(X_train_SMOTE,y_train_SMOTE,verbose=1,epochs=20)
pred = nn.predict(X_test)
# Out:
# Epoch 1/20
# 20151/20151 [==============================] - 30s 1ms/step - loss: 7.8674
# Epoch 2/20
# 20151/20151 [==============================] - 28s 1ms/step - loss: 6.7675
# Epoch 3/20
# 20151/20151 [==============================] - 29s 1ms/step - loss: 6.7614
# Epoch 4/20
# 20151/20151 [==============================] - 28s 1ms/step - loss: 6.7388
# Epoch 5/20
# 20151/20151 [==============================] - 29s 1ms/step - loss: 6.7222
# Epoch 6/20
# 20151/20151 [==============================] - 31s 2ms/step - loss: 6.7119
# Epoch 7/20
# 20151/20151 [==============================] - 32s 2ms/step - loss: 6.7110
# Epoch 8/20
# 20151/20151 [==============================] - 29s 1ms/step - loss: 6.7128
# Epoch 9/20
# 20151/20151 [==============================] - 29s 1ms/step - loss: 6.6939
# Epoch 10/20
# 20151/20151 [==============================] - 31s 2ms/step - loss: 6.6889
# Epoch 11/20
# 20151/20151 [==============================] - 31s 2ms/step - loss: 6.7074
# Epoch 12/20
# 20151/20151 [==============================] - 31s 2ms/step - loss: 6.6943
# Epoch 13/20
# 20151/20151 [==============================] - 28s 1ms/step - loss: 6.7071
# Epoch 14/20
# 20151/20151 [==============================] - 29s 1ms/step - loss: 6.6935
# Epoch 15/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 6.6882
# Epoch 16/20
# 20151/20151 [==============================] - 32s 2ms/step - loss: 6.6945
# Epoch 17/20
# 20151/20151 [==============================] - 56s 3ms/step - loss: 6.6901
# Epoch 18/20
# 20151/20151 [==============================] - 43s 2ms/step - loss: 6.6787: 0s - los - ETA: 0s - lo
# Epoch 19/20
# 20151/20151 [==============================] - 41s 2ms/step - loss: 6.6882
# Epoch 20/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 6.6780

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.195
# Precision: 0.19455678736261123
# Recall: 0.19455678736261123

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.64      0.22      7789
#            1       0.38      0.12      0.18     25786
#            2       0.43      0.23      0.30     28872
#            3       0.26      0.01      0.03     18203
#            4       0.05      0.14      0.08      3875
#            5       0.34      0.27      0.30     11556
#            6       0.01      0.20      0.02       906
#            7       0.25      0.00      0.01      3384
#            8       0.13      0.69      0.23      1597
#            9       0.05      0.03      0.03       912
#           10       0.50      0.26      0.34      2205
#
#     accuracy                           0.19    105085
#    macro avg       0.23      0.24      0.16    105085
# weighted avg       0.32      0.19      0.19    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5'></a>
#
# ## Part - 5 Additional Models

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5.1'></a>
# ### Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train, y_train.ravel())
# Out:
# GradientBoostingClassifier()

# %%
y_pred = model.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy : 0.373

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3726887757529619
# Recall: 0.3726887757529619

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5.2'></a>
# ### Cat Boost Classifier

# %%
from catboost import CatBoostClassifier
cb = CatBoostClassifier(iterations=1000)
cb.fit(X_train, y_train)
# Out:
# Learning rate set to 0.104018
# 0:	learn: 2.2551060	total: 491ms	remaining: 8m 10s
# 1:	learn: 2.1553572	total: 806ms	remaining: 6m 42s
# 2:	learn: 2.0775023	total: 1.12s	remaining: 6m 12s
# 3:	learn: 2.0156996	total: 1.45s	remaining: 6m 2s
# 4:	learn: 1.9649069	total: 1.77s	remaining: 5m 51s
# 5:	learn: 1.9247325	total: 2.09s	remaining: 5m 45s
# 6:	learn: 1.8903302	total: 2.41s	remaining: 5m 41s
# 7:	learn: 1.8600678	total: 2.73s	remaining: 5m 39s
# 8:	learn: 1.8350712	total: 3.05s	remaining: 5m 35s
# 9:	learn: 1.8130557	total: 3.39s	remaining: 5m 35s
# 10:	learn: 1.7954925	total: 3.72s	remaining: 5m 34s
# 11:	learn: 1.7789344	total: 4.05s	remaining: 5m 33s
# 12:	learn: 1.7642763	total: 4.37s	remaining: 5m 31s
# 13:	learn: 1.7525248	total: 4.72s	remaining: 5m 32s
# 14:	learn: 1.7415424	total: 5.02s	remaining: 5m 29s
# 15:	learn: 1.7313675	total: 5.36s	remaining: 5m 29s
# 16:	learn: 1.7228898	total: 5.71s	remaining: 5m 30s
# 17:	learn: 1.7152056	total: 6.04s	remaining: 5m 29s
# 18:	learn: 1.7087619	total: 6.38s	remaining: 5m 29s
# 19:	learn: 1.7034117	total: 6.69s	remaining: 5m 27s
# 20:	learn: 1.6978997	total: 7.07s	remaining: 5m 29s
# 21:	learn: 1.6933942	total: 7.41s	remaining: 5m 29s
# 22:	learn: 1.6887056	total: 7.85s	remaining: 5m 33s
# 23:	learn: 1.6845153	total: 8.21s	remaining: 5m 33s
# 24:	learn: 1.6801940	total: 8.54s	remaining: 5m 32s
# 25:	learn: 1.6772243	total: 8.85s	remaining: 5m 31s
# 26:	learn: 1.6743658	total: 9.18s	remaining: 5m 30s
# 27:	learn: 1.6710924	total: 9.5s	remaining: 5m 29s
# 28:	learn: 1.6679403	total: 9.81s	remaining: 5m 28s
# 29:	learn: 1.6656795	total: 10.1s	remaining: 5m 27s
# 30:	learn: 1.6629904	total: 10.4s	remaining: 5m 26s
# 31:	learn: 1.6605032	total: 10.8s	remaining: 5m 25s
# 32:	learn: 1.6585373	total: 11.1s	remaining: 5m 23s
# 33:	learn: 1.6567710	total: 11.4s	remaining: 5m 22s
# 34:	learn: 1.6548675	total: 11.7s	remaining: 5m 22s
# 35:	learn: 1.6529385	total: 12s	remaining: 5m 21s
# 36:	learn: 1.6513628	total: 12.3s	remaining: 5m 20s
# 37:	learn: 1.6498752	total: 12.6s	remaining: 5m 19s
# 966:	learn: 1.4912452	total: 5m 9s	remaining: 10.6s
# 967:	learn: 1.4910906	total: 5m 9s	remaining: 10.2s
# 968:	learn: 1.4910305	total: 5m 10s	remaining: 9.92s
# 969:	learn: 1.4909341	total: 5m 10s	remaining: 9.6s
# 970:	learn: 1.4908156	total: 5m 10s	remaining: 9.28s
# 971:	learn: 1.4907319	total: 5m 10s	remaining: 8.96s
# 972:	learn: 1.4906482	total: 5m 11s	remaining: 8.64s
# 973:	learn: 1.4905390	total: 5m 11s	remaining: 8.31s
# 974:	learn: 1.4904676	total: 5m 11s	remaining: 8s
# 975:	learn: 1.4903737	total: 5m 12s	remaining: 7.67s
# 976:	learn: 1.4903162	total: 5m 12s	remaining: 7.36s
# 977:	learn: 1.4901811	total: 5m 12s	remaining: 7.04s
# 978:	learn: 1.4901286	total: 5m 13s	remaining: 6.71s
# 979:	learn: 1.4900545	total: 5m 13s	remaining: 6.39s
# 980:	learn: 1.4899550	total: 5m 13s	remaining: 6.07s
# 981:	learn: 1.4898898	total: 5m 13s	remaining: 5.75s
# 982:	learn: 1.4898044	total: 5m 14s	remaining: 5.43s
# 983:	learn: 1.4897419	total: 5m 14s	remaining: 5.12s
# 984:	learn: 1.4896616	total: 5m 14s	remaining: 4.79s
# 985:	learn: 1.4896104	total: 5m 15s	remaining: 4.47s
# 986:	learn: 1.4895417	total: 5m 15s	remaining: 4.16s
# 987:	learn: 1.4894876	total: 5m 15s	remaining: 3.83s
# 988:	learn: 1.4893553	total: 5m 16s	remaining: 3.52s
# 989:	learn: 1.4892434	total: 5m 16s	remaining: 3.2s
# 990:	learn: 1.4891603	total: 5m 16s	remaining: 2.88s
# 991:	learn: 1.4891103	total: 5m 17s	remaining: 2.56s
# 992:	learn: 1.4890437	total: 5m 17s	remaining: 2.24s
# 993:	learn: 1.4889427	total: 5m 17s	remaining: 1.92s
# 994:	learn: 1.4888687	total: 5m 17s	remaining: 1.6s
# 995:	learn: 1.4887727	total: 5m 18s	remaining: 1.28s
# 996:	learn: 1.4887106	total: 5m 18s	remaining: 959ms
# 997:	learn: 1.4886396	total: 5m 18s	remaining: 639ms
# 998:	learn: 1.4885639	total: 5m 19s	remaining: 320ms
# 999:	learn: 1.4885020	total: 5m 19s	remaining: 0us

# %%
y_pred = cb.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy : 0.384

# %%
y_pred = y_pred.flatten()
y_pred.shape
# Out:
# (105085,)

# %%
y_diff = np.abs(y_test.ravel()-y_pred.ravel())

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5.3'></a>
# ### XGB BOOST Classifier

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# [19:19:21] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
y_pred = xgb.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test.ravel()-y_pred.ravel()))/K
print(f'Score : %.4f' % score)
# Out:
# Accuracy : 0.374
# Score : 0.8829

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
