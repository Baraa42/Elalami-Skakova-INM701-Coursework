# %% [markdown]
# # Health Care Dataset - INM701 Coursework
# Postgraduate students:
# - Tamila Skakova
# - Elbaraa Elalami

# %% [markdown]
# ## Content:
# - **[Part 1](#part1)- Importing the data set, packages used**
# - **[Part 2](#part2)- Exploratory data analysis**
# - [Part 2.1](#part2.1)- Analysis of the features
# - [Part 2.2](#part2.2)- Analysis of the Target
# - [Part 2.3](#part2.3)- Statistical analysis of the dataset
# - **[Part 3](#part3) -  Preparing our data**
# - [Part 3.1](#part3.1) -  Missing Values
# - [Part 3.2](#part3.2) -  Enconding, Shuffling, Scaling
# - [Part 3.3](#part3.3) -  Multicollinearity
# - [Part 3.4](#part3.4) -  SMOTE Analysis
# - **[Part 4/1](#part4/1) -  Models**
# - [Part 4.1.1](#part4.1.1) -  Score method
# - [Part 4.1.2](#part4.1.2) -  KNN
# - [Part 4.1.3](#part4.1.3) -  Decision tree model
# - [Part 4.1.4](#part4.1.4) -  Random Forest
# - [Part 4.1.5](#part4.1.5) -  Naive Bayes
# - [Part 4.1.6](#part4.1.6) -  ANN
# - **[Part 4/2](#part4/2) -  Models with SMOTE**
# - [Part 4.2.1](#part4.2.1) -  KNN
# - [Part 4.2.2](#part4.2.2) -  Decision tree model
# - [Part 4.2.3](#part4.2.3) -  Random Forest
# - [Part 4.2.4](#part4.2.4) -  Naive Bayes
# - [Part 4.2.5](#part4.2.5) -  ANN
# - **[Part 5](#part5) -  Additional Models**
# - [Part 5.1](#part5.1) -  Gradient Boost Classifier
# - [Part 5.2](#part5.2) -  CatBoost Classifier
# - [Part 5.2](#part5.2) -  XGB BOOST Classifier

# %% [markdown]
# ## Description of features in the dataframe:
#
# - `Column`	Description
# - `case_id`	Case_ID registered in Hospital
# - `Hospital_code`	Unique code for the Hospital
# - `Hospital_type_code`	Unique code for the type of Hospital
# - `City_Code_Hospital` City Code of the Hospital
# - `Hospital_region_code`	Region Code of the Hospital
# - `Available Extra Rooms in Hospital`	Number of Extra rooms available in the Hospital
# - `Department`	Department overlooking the case
# - `Ward_Type`	Code for the Ward type
# - `Ward_Facility_Code`	Code for the Ward Facility
# - `Bed Grade`	Condition of Bed in the Ward
# - `patientid`	Unique Patient Id
# - `City_Code_Patient`	City Code for the patient
# - `Type of Admission`	Admission Type registered by the Hospital
# - `Severity of Illness`	Severity of the illness recorded at the time of admission
# - `Visitors with Patient`	Number of Visitors with the patient
# - `Age`	Age of the patient
# - `Admission_Deposit`	Deposit at the Admission Time
# - `Stay`	Stay Days by the patient, the length of stay - 11 different classes ranging from 0-10 days to more than 100 days.

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part1'></a>
#
# ## Part 1 -  Importing the data set, packages used

# %%
import os
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
import io
import requests
# %matplotlib inline

# %%
path = "healthcare"

filename_read = os.path.join(path, "train_data.csv")
health_care = pd.read_csv(filename_read, na_values=['NA', '?'])

# print(health_care.shape)
# print(health_care.columns)

# %%
health_care.head(10)
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
# 5        6             23                  a                   6
# 6        7             32                  f                   9
# 7        8             23                  a                   6
# 8        9              1                  d                  10
# 9       10             10                  e                   1
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
# 5                    X                                  2    anesthesia
# 6                    Y                                  1  radiotherapy
# 7                    X                                  4  radiotherapy
# 8                    Y                                  2    gynecology
# 9                    X                                  2    gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
# 5         S                  F        2.0      31397                7.0
# 6         S                  B        3.0      31397                7.0
# 7         Q                  F        3.0      31397                7.0
# 8         R                  B        4.0      31397                7.0
# 9         S                  E        3.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
# 5            Trauma             Extreme                      2  51-60
# 6         Emergency             Extreme                      2  51-60
# 7            Trauma             Extreme                      2  51-60
# 8            Trauma             Extreme                      2  51-60
# 9            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50
# 5             4449.0  11-20
# 6             6167.0   0-10
# 7             5571.0  41-50
# 8             7223.0  51-60
# 9             6056.0  31-40

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2'></a>
# ## Part 2- Exploratory data analysis (EDA)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2.1'></a>
# ### Analysis of the features

# %%
#sorting by Stay for better representation in the visualisations
health_care = health_care.sort_values(by = "Stay", ascending = True)
# To make sure we consider all the correct features to make an accurate prediction, it may be useful to create some plots to have a better understanding of our data and relationship between them and the output feature. For that we have used Python data visualisation library seaborn. We begin by visualising the length of stays by age of patients admitted to hospitals, type of admissions, severity of illness, available extra rooms in hospitals,  etc., by using a countplot(), that shows the counts of observations in each categorical bin using bars.

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Age", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Age", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Hospital_region_code", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Hospital_region_code", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (20,4))
#plot title
plt.title("Available Extra Rooms in Hospital", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Available Extra Rooms in Hospital", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Type of Admission", fontdict = {'fontsize': 15})
ax = sns.countplot(x = "Type of Admission", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,4))
#plot title
plt.title("Severity of Illness", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Severity of Illness", hue = 'Stay', data = health_care)

# %%
#plot size
plt.figure(figsize = (15,8))
#plot title
plt.title("Department", fontdict = {'fontsize':15})
ax = sns.countplot(x = "Department", hue = 'Stay', data = health_care)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2.2'></a>
# ### Analysis of the Target

# %%
## Checking target
#creating a copy of df to have an original for further manipulation
health_care_copy = health_care.copy()

# %%
#number of unique element for each feature
encoder = LabelEncoder()
health_care_copy['Stay_cat'] = encoder.fit_transform(health_care_copy['Stay'])
n = len(health_care_copy['Stay_cat'])
l = []
for i in range(len(np.unique(health_care_copy['Stay_cat']))):
    k = len(health_care[health_care_copy['Stay_cat']==i])
    #print(f'N {10*i} and {10*(i+1)} is : {k}')
    print(f'{i}- {k}  : {100*k/n:.2f}%')
# Out:
# 0- 23604  : 7.41%
# 1- 78139  : 24.54%
# 2- 87491  : 27.48%
# 3- 55159  : 17.32%
# 4- 11743  : 3.69%
# 5- 35018  : 11.00%
# 6- 2744  : 0.86%
# 7- 10254  : 3.22%
# 8- 4838  : 1.52%
# 9- 2765  : 0.87%
# 10- 6683  : 2.10%

# %%
#Visualisation of Target categories
fig, ax1 = plt.subplots()
labels = np.unique(health_care['Stay'])
labels[-1] = '100+'

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:6]
plt.pie(health_care.groupby('Stay').size(), labels = labels,colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(20, 15.5)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.title('Percentage of occurence of each category')
plt.show()

# %%
#Histogram plot
h = health_care['Stay'].sort_values()
h[h=='More than 100 Days'] = '100+'
plt.figure(figsize = (8,8))
plt.hist(h, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)

plt.xlabel('LOS')
plt.ylabel('Occurence')
plt.title('Histogram of LOS')

plt.grid(True)
plt.show()

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part2.3'></a>
# ### Statistical analysis of the dataset

# %%
#statistical analysis of each feature
df_copy = health_care.copy()
df_copy = df_copy.select_dtypes(include=["int","float"])
headers = list(df_copy.columns.values)
fields = []
for field in headers:
    fields.append({
        "name":field,
        "mean":health_care[field].mean(),
        "var":health_care[field].var(),
        "sdev":health_care[field].std()
    })
for field in fields:
    print(field)
# Out:
# {'name': 'case_id', 'mean': 159219.5, 'var': 8450256523.45631, 'sdev': 91925.27684731937}
# {'name': 'Hospital_code', 'mean': 18.318840716246175, 'var': 74.54172342795815, 'sdev': 8.633754885793211}
# {'name': 'City_Code_Hospital', 'mean': 4.771716943329627, 'var': 9.625725626972837, 'sdev': 3.10253535466928}
# {'name': 'Available Extra Rooms in Hospital', 'mean': 3.1976271676119055, 'var': 1.3646244848651312, 'sdev': 1.1681714278585704}
# {'name': 'Bed Grade', 'mean': 2.625806958297338, 'var': 0.7623835960744886, 'sdev': 0.8731458045907846}
# {'name': 'patientid', 'mean': 65747.57947229916, 'var': 1442475571.9882042, 'sdev': 37979.93644002323}
# {'name': 'City_Code_Patient', 'mean': 7.251858836721821, 'var': 22.51754524576123, 'sdev': 4.745265561142098}
# {'name': 'Visitors with Patient', 'mean': 3.2840992595104854, 'var': 3.11191258613169, 'sdev': 1.764061389558677}
# {'name': 'Admission_Deposit', 'mean': 4880.749392346391, 'var': 1181082.6254792996, 'sdev': 1086.776253641613}

# %%
## functions to feed to barplot
def mean(x):
    return np.mean(x)

def median(x):
    return np.median(x)

def std(x):
    return np.std(x)

# %%
## Encoding data
df_copy2 = health_care.copy()
target = df_copy2['Stay']
target_enc = encoder.fit_transform(target)

# %%
## Estimate of length of stay
target_estimate = 10* (target_enc) + 5
# Adding the estimate to the dataframe
df_copy2['Stay Estimate'] = target_estimate

# %%
## Using only Features with limited classes for the plot
elements_to_remove = ['case_id', 'patientid', 'Admission_Deposit', 'Stay', 'Stay Estimate']
column_features = [ column for column in df_copy.columns if column not in elements_to_remove]
print(column_features)
# Out:
# ['Hospital_code', 'City_Code_Hospital', 'Available Extra Rooms in Hospital', 'Bed Grade', 'City_Code_Patient', 'Visitors with Patient']

# %%
# Mean Analysis
#We study the relationship between the mean of stay and each feature
for feature in column_features :
    order = pd.unique(df_copy2[feature])
    order.sort()
    ax = sns.barplot(x=feature, y="Stay Estimate", data=df_copy2,order=order, estimator=mean)
    ax.set_title(f'Means of {feature} classes') 
    plt.show();

# %%
#Median Analysis
for feature in column_features :
    order = pd.unique(df_copy2[feature])
    order.sort()
    ax = sns.barplot(x=feature, y="Stay Estimate", data=df_copy2,order=order, estimator=median)
    ax.set_title(f'Medians of {feature} classes') 
    plt.show();

# %%
#Analysis of Std
for feature in column_features :
    order = pd.unique(df_copy2[feature])
    order.sort()
    ax = sns.barplot(x=feature, y="Stay Estimate", data=df_copy2,order=order, estimator=std)
    ax.set_title(f'Stds of {feature} classes') 
    plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3'></a>
# ## Part 3 - Preparing our data

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.1'></a>
# ### Missing Values

# %%
#checking for missing values
health_care.isnull().values.any()
# Out:
# True

# %%
#Checking number of NANs for each column, in order to understand how many missing values there are in a dataframe.
print("# of NaN in each columns:", health_care.isnull().sum(), sep='\n')
# Out:
# # of NaN in each columns:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
#calculates percentage of missing values in the specific feature
def perc_mv(x, y):
    perc = y.isnull().sum() / len(x) * 100
    return perc

# %%
print('Missing value ratios:\nBed Grade: {}\nCity_Code_Patient: {}'.format(
    perc_mv(health_care, health_care['Bed Grade']),
    perc_mv(health_care, health_care['City_Code_Patient'])))
# Out:
# Missing value ratios:
# Bed Grade: 0.035485714644609
# City_Code_Patient: 1.4231969802598936

# %%
#In the code cell below, we use the attribute dtype on df to retrieve the data type for each column.
print (health_care.dtypes)
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %%
#We want to map the name of each Severity of Illness to the corresponding number in ascending order.
health_care['Severity of Illness'] = health_care['Severity of Illness'].map({'Minor':1, 'Moderate': 2, 'Extreme':3})
health_care['Type of Admission'] = health_care['Type of Admission'].map({'Trauma':1, 'Emergency': 2, 'Urgent':3})
# health_care

# %%
#dropping features
elements_to_remove = ['case_id', 'City_Code_Hospital', 'City_Code_Patient', 'patientid', 'Bed Grade', 'Admission_Deposit']
health_care = health_care.drop(elements_to_remove, axis=1)

# %%
# #uniting the predictors 
# #playing with the parameters
# health_care["Stay"] = health_care["Stay"].map({'0-10':'0-20', 
#                              '11-20':'0-20', 
#                              '21-30':'21-30', 
#                              '31-40':'21-30', 
#                              '41-50':'31-40', 
#                              '51-60':'31-40',
#                              '61-70':"more than 60 Days",  
#                              '71-80':"more than 60 Days", 
#                              '81-90':"more than 60 Days", 
#                              '91 - 100':"more than 60 Days", 
#                              'More than 100 Days' :"more than 60 Days"})

# # df.iloc[np.random.permutation(len(df))]

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.2'></a>
# ### Enconding, Shuffling, Scaling

# %%
#using LabelEncoder to change and transform the object format of 
le = LabelEncoder()
for col in ['Hospital_type_code', 'Hospital_region_code','Ward_Type', 'Ward_Facility_Code', 'Department', 'Age', 'Stay']:
    health_care[col]= health_care[col].astype('str')
    health_care[col]= le.fit_transform(health_care[col])
print (health_care.dtypes)
# Out:
# Hospital_code                        int64
# Hospital_type_code                   int32
# Hospital_region_code                 int32
# Available Extra Rooms in Hospital    int64
# Department                           int32
# Ward_Type                            int32
# Ward_Facility_Code                   int32
# Type of Admission                    int64
# Severity of Illness                  int64
# Visitors with Patient                int64
# Age                                  int32
# Stay                                 int32
# dtype: object

# %%
# # Function to hot encode the column with name : name for dataframe df
# def encode_text_dummy(df, name):
#     dummies = pd.get_dummies(df[name])
#     for x in dummies.columns:
#         dummy_name = f"{name}-{x}"
#         df[dummy_name] = dummies[x]
#     df.drop(name, axis=1, inplace=True) ## inplace to make changed on the original df

# %%
# ohEncoder = OneHotEncoder()

# Xe = health_care.drop(columns = ["Stay"])
# ye = health_care["Stay"]

# #hot encoding
# ## Pre processing these columns
# dummies_string_columns = ['Hospital_region_code', 'Department', 'Ward_Type', 'Ward_Facility_Code',  'Type of Admission']
# for column in dummies_string_columns :
#     encode_text_dummy(Xe, column)
    
# ## label_encoded data
# Xe['Age'] = encoder.fit_transform(Xe['Age'])
# ye = ohEncoder.fit_transform(ye)

# %%
# #Scaling Hot Encoded Data
# scaler = StandardScaler()
# X = X.values
# y = y
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
# for i in range(X_train.shape[1]) :
#     X_train[:,i]= scaler.fit_transform(X_train[:,i].reshape(-1, 1))[:,0]
#     X_test[:,i] = scaler.transform(X_test[:,i].reshape(-1, 1))[:,0]

# %%
#shuffling
health_care= health_care.reindex(np.random.permutation(health_care.index))
health_care.reset_index(inplace=True, drop=True)

# %%
#initialisation
X = health_care.drop(columns = ["Stay"])
y = health_care["Stay"]

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.3'></a>
# ### Multicollinearity

# %%
# Heatmap
fig, ax = plt.subplots(figsize=(10,10))        
sns.heatmap(health_care.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#OLS
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   Stay   R-squared (uncentered):                   0.754
# Model:                            OLS   Adj. R-squared (uncentered):              0.754
# Method:                 Least Squares   F-statistic:                          8.876e+04
# Date:                Sun, 19 Dec 2021   Prob (F-statistic):                        0.00
# Time:                        14:00:41   Log-Likelihood:                     -6.2289e+05
# No. Observations:              318438   AIC:                                  1.246e+06
# Df Residuals:                  318427   BIC:                                  1.246e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Hospital_code                         0.0024      0.000      6.805      0.000       0.002       0.003
# Hospital_type_code                    0.0350      0.002     16.479      0.000       0.031       0.039
# Hospital_region_code                  0.0132      0.005      2.822      0.005       0.004       0.022
# Available Extra Rooms in Hospital    -0.2043      0.003    -79.085      0.000      -0.209      -0.199
# Department                            0.0301      0.005      5.922      0.000       0.020       0.040
# Ward_Type                             0.4550      0.004    115.845      0.000       0.447       0.463
# Ward_Facility_Code                    0.0145      0.002      7.539      0.000       0.011       0.018
# Type of Admission                    -0.2359      0.004    -58.086      0.000      -0.244      -0.228
# Severity of Illness                   0.2550      0.004     57.854      0.000       0.246       0.264
# Visitors with Patient                 0.6687      0.002    390.861      0.000       0.665       0.672
# Age                                   0.0033      0.002      2.057      0.040       0.000       0.006
# ==============================================================================
# Omnibus:                    53536.263   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           116648.854
# Skew:                           0.991   Prob(JB):                         0.00
# Kurtosis:                       5.205   Cond. No.                         38.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#VIF
X_VIF = health_care
data = pd.DataFrame()
data["feature"] = X_VIF.columns
data["VIF"] = [variance_inflation_factor(X_VIF.values, i) for i in range(len(X_VIF.columns))]
print(data)
# Out:
#                               feature        VIF
# 0                       Hospital_code   5.557224
# 1                  Hospital_type_code   1.933881
# 2                Hospital_region_code   2.781609
# 3   Available Extra Rooms in Hospital   8.577968
# 4                          Department  11.484799
# 5                           Ward_Type   7.369338
# 6                  Ward_Facility_Code   5.527592
# 7                   Type of Admission   6.029047
# 8                 Severity of Illness   8.711826
# 9               Visitors with Patient   6.546418
# 10                                Age   5.639583
# 11                               Stay   4.066131

# %%
#Choosing the number of components
scaler=StandardScaler()
X_scaler = StandardScaler().fit_transform(X)
pca = PCA().fit(X_scaler)

# %%
#Plotting the Cumulative Summation of the Explained Variance
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Dataset Explained Variance')
plt.show()

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.17298781, 0.30416866, 0.4148431 , 0.51060786, 0.60149156,
#        0.68618983, 0.76989892, 0.84533686, 0.91412017, 0.96105488,
#        1.        ])

# %%
# For our analysis we choose n_components = 7
pca = PCA(n_components=7)
X_pca = pca.fit_transform(X_scaler)
X_pca_with_constant = sm.add_constant(X_pca)

# %%
model = sm.OLS(y, X_pca_with_constant)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Stay   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                 2.043e+04
# Date:                Sun, 19 Dec 2021   Prob (F-statistic):               0.00
# Time:                        14:00:51   Log-Likelihood:            -6.3656e+05
# No. Observations:              318438   AIC:                         1.273e+06
# Df Residuals:                  318430   BIC:                         1.273e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6986      0.003    852.550      0.000       2.692       2.705
# x1            -0.1126      0.002    -49.080      0.000      -0.117      -0.108
# x2            -0.1615      0.003    -61.283      0.000      -0.167      -0.156
# x3             0.6324      0.003    220.437      0.000       0.627       0.638
# x4            -0.1803      0.003    -58.461      0.000      -0.186      -0.174
# x5            -0.0572      0.003    -18.055      0.000      -0.063      -0.051
# x6             0.8228      0.003    250.919      0.000       0.816       0.829
# x7             0.4838      0.003    146.683      0.000       0.477       0.490
# ==============================================================================
# Omnibus:                    49980.476   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94830.136
# Skew:                           0.987   Prob(JB):                         0.00
# Kurtosis:                       4.804   Cond. No.                         1.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part3.4'></a>
# ### SMOTE analysis
# Here we will study imbalance data

# %%
health_care["Stay"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
smote_health_care = health_care.copy()

# X = np.array(smote_health_care.loc[:, smote_health_care.columns != "Stay"])
y = np.array(smote_health_care.loc[:, smote_health_care.columns == "Stay"]).reshape(-1, 1)

X = scaler.fit_transform(X_pca_with_constant)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 2, shuffle = True, stratify = y)
oversample = SMOTE(random_state = 33)
X_train_SMOTE, y_train_SMOTE = oversample.fit_resample(X_train, y_train)

# %%
# observe that data has been balanced
pd.Series(y_train_SMOTE).value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4/1'></a>
#
# ## Part - 4 Models

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.1'></a>
# ### Score method

# %%
# Score of 1 is perfect. The closer the score to 1 the better
K = 10 # Num of Classes - 1 here

# Classes can be ranked here from 0-10
def score(pred, target):
    error = (np.mean(np.abs(pred-target)))/K
    score = 1 - error
    return score

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.2'></a>
# ### KNN

# %%
# Splitting dataset
y = health_care["Stay"]
X_train, X_test, y_train, y_test = train_test_split(X_pca_with_constant, y, test_size = 0.33, random_state = 2, shuffle = True, stratify = y)

# %%
knn = KNeighborsClassifier(n_neighbors=3) 
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
print(f'Score : %.2f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy: 0.30
# Score : 0.86

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.2961697673312081
# Recall: 0.2961697673312081

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.26      0.18      7789
#            1       0.30      0.41      0.35     25786
#            2       0.37      0.36      0.37     28872
#            3       0.26      0.20      0.23     18203
#            4       0.05      0.01      0.02      3875
#            5       0.35      0.27      0.31     11556
#            6       0.07      0.01      0.01       906
#            7       0.18      0.07      0.10      3384
#            8       0.28      0.13      0.17      1597
#            9       0.15      0.03      0.05       912
#           10       0.53      0.30      0.38      2205
#
#     accuracy                           0.30    105085
#    macro avg       0.24      0.19      0.20    105085
# weighted avg       0.30      0.30      0.29    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.3'></a>
# ### Decision Trees

# %%
tree = DecisionTreeClassifier(criterion='entropy')
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = tree.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.2f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.328
# Score : 0.86

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.32764904601037254
# Recall: 0.32764904601037254

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.16      0.15      0.16      7789
#            1       0.34      0.41      0.37     25786
#            2       0.39      0.48      0.43     28872
#            3       0.28      0.21      0.24     18203
#            4       0.06      0.02      0.03      3875
#            5       0.35      0.32      0.34     11556
#            6       0.04      0.02      0.03       906
#            7       0.18      0.11      0.14      3384
#            8       0.24      0.18      0.21      1597
#            9       0.13      0.08      0.10       912
#           10       0.41      0.34      0.37      2205
#
#     accuracy                           0.33    105085
#    macro avg       0.24      0.21      0.22    105085
# weighted avg       0.31      0.33      0.32    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.4'></a>
# ### Random Forest

# %%
forest = RandomForestClassifier(n_estimators=10, criterion='entropy')
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred = forest.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.338
# Score : 0.8688

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3382595042108769
# Recall: 0.3382595042108769

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.11      0.13      7789
#            1       0.35      0.38      0.37     25786
#            2       0.39      0.52      0.44     28872
#            3       0.27      0.22      0.25     18203
#            4       0.07      0.02      0.03      3875
#            5       0.35      0.37      0.36     11556
#            6       0.05      0.02      0.02       906
#            7       0.20      0.12      0.15      3384
#            8       0.26      0.17      0.21      1597
#            9       0.14      0.06      0.09       912
#           10       0.43      0.38      0.40      2205
#
#     accuracy                           0.34    105085
#    macro avg       0.25      0.22      0.22    105085
# weighted avg       0.32      0.34      0.32    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %%
### Cross Validating to check some results
kf = KFold(5, shuffle=True)
fold = 1

for train_index, validate_index in kf.split(X,y):
    forest.fit(X[train_index], y[train_index])
    ytest = y[validate_index]
    y_pred = forest.predict(X[validate_index])
    print(f'Accuracy : %.4f' % accuracy_score(ytest, y_pred))
    print(f'Score : %.4f' % score(ytest.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.3371
# Score : 0.8683
# Accuracy : 0.3404
# Score : 0.8702
# Accuracy : 0.3383
# Score : 0.8698
# Accuracy : 0.3366
# Score : 0.8690
# Accuracy : 0.3401
# Score : 0.8698

# %%
#Trying Different num of estimators
accuracy_data = []
score_data = []

for i in range(1,2):
    forest = RandomForestClassifier(n_estimators=i, criterion='entropy')
    forest.fit(X_train, y_train)
    y_pred = forest.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    score = 1-np.mean(np.abs(y_test-y_pred))/K
    print(f'Accuracy {i} estimators : %.4f' % accuracy)
    print(f'Score {i} estimators : %.4f' % score)
    accuracy_data.append(accuracy)
    score_data.append(score)
# Out:
# Accuracy 1 estimators : 0.3071
# Score 1 estimators : 0.8556

# %%
# nums = np.arange(1,40)
# fig = plt.figure(figsize=(6,5))
# plt.plot(nums, accuracy_data, c='r', label='Accuracy')
# plt.plot(nums, score_data, label='Score')
# plt.xlabel('Number of Trees')
# plt.ylabel('Accuracy and Score')
# plt.legend(loc='upper right')
# plt.show();

# %%
#Last Model results
y_pred = forest.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test-y_pred))/K
print(f'Score : %.4f' % score)
# Out:
# Accuracy : 0.307
# Score : 0.8556

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3070752248180045
# Recall: 0.3070752248180045

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4.1.5'></a>
# ### Naive Bayes

# %%
smoothing = [1e-3, 1e-2, 1e-1, 1, 10,100]
for i in range(len(smoothing)):
    model = GaussianNB(var_smoothing=smoothing[i])
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print('var_smoothing = ',smoothing[i] )
    print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
    score = 1-(np.mean(np.abs(y_test.ravel()-y_pred.ravel())))/K
    print(f'Score : %.4f' % score)
    print('---------' )
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# var_smoothing =  0.001
# Accuracy : 0.336
# Score : 0.8691
# ---------
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# var_smoothing =  0.01
# Accuracy : 0.336
# Score : 0.8691
# ---------
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# var_smoothing =  0.1
# Accuracy : 0.334
# Score : 0.8686
# ---------
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# var_smoothing =  1
# Accuracy : 0.306
# Score : 0.8595
# ---------
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# var_smoothing =  10
# Accuracy : 0.275
# Score : 0.8517
# ---------
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# var_smoothing =  100
# Accuracy : 0.275
# Score : 0.8514
# ---------

# %%
## Keeping smoothing = 1
model = GaussianNB(var_smoothing=1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score)
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.306
# Score : 0.8514
# Precision: 0.305685873340629
# Recall: 0.305685873340629

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7789
#            1       0.29      0.24      0.26     25786
#            2       0.31      0.83      0.45     28872
#            3       0.27      0.03      0.06     18203
#            4       0.00      0.00      0.00      3875
#            5       0.27      0.07      0.12     11556
#            6       0.00      0.00      0.00       906
#            7       0.00      0.00      0.00      3384
#            8       0.00      0.00      0.00      1597
#            9       0.00      0.00      0.00       912
#           10       0.57      0.23      0.33      2205
#
#     accuracy                           0.31    105085
#    macro avg       0.15      0.13      0.11    105085
# weighted avg       0.24      0.31      0.22    105085
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.1.6'></a>
# ### ANN

# %%
nn = Sequential()

#model.add(Dropout(0.1)) #applies to layer before ie input here
nn.add(Dense(12, input_dim=X.shape[1], activation='relu'))
nn.add(Dense(8, activation='relu'))
nn.add(Dense(1, activation='sigmoid'))
nn.add(Dropout(0.2))
nn.add(Dense(1))

# %%
nn.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-4, patience=5, verbose=1, mode='auto')
nn.fit(X_train,y_train,verbose=2,epochs=20)
pred = nn.predict(X_test)
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
print(f'Score : %.4f' % score)
# Out:
# Epoch 1/20
# 6668/6668 - 9s - loss: 5.6993 - 9s/epoch - 1ms/step
# Epoch 2/20
# 6668/6668 - 8s - loss: 3.9344 - 8s/epoch - 1ms/step
# Epoch 3/20
# 6668/6668 - 8s - loss: 3.8776 - 8s/epoch - 1ms/step
# Epoch 4/20
# 6668/6668 - 8s - loss: 3.8536 - 8s/epoch - 1ms/step
# Epoch 5/20
# 6668/6668 - 8s - loss: 3.8442 - 8s/epoch - 1ms/step
# Epoch 6/20
# 6668/6668 - 8s - loss: 3.8310 - 8s/epoch - 1ms/step
# Epoch 7/20
# 6668/6668 - 8s - loss: 3.8254 - 8s/epoch - 1ms/step
# Epoch 8/20
# 6668/6668 - 8s - loss: 3.8281 - 8s/epoch - 1ms/step
# Epoch 9/20
# 6668/6668 - 8s - loss: 3.8166 - 8s/epoch - 1ms/step
# Epoch 10/20
# 6668/6668 - 8s - loss: 3.8209 - 8s/epoch - 1ms/step
# Epoch 11/20
# 6668/6668 - 8s - loss: 3.8178 - 8s/epoch - 1ms/step
# Epoch 12/20
# 6668/6668 - 8s - loss: 3.8143 - 8s/epoch - 1ms/step
# Epoch 13/20
# 6668/6668 - 8s - loss: 3.8068 - 8s/epoch - 1ms/step
# Epoch 14/20
# 6668/6668 - 8s - loss: 3.8054 - 8s/epoch - 1ms/step
# Epoch 15/20
# 6668/6668 - 8s - loss: 3.8039 - 8s/epoch - 1ms/step
# Epoch 16/20
# 6668/6668 - 8s - loss: 3.8073 - 8s/epoch - 1ms/step
# Epoch 17/20
# 6668/6668 - 8s - loss: 3.8017 - 8s/epoch - 1ms/step
# Epoch 18/20
# 6668/6668 - 8s - loss: 3.7998 - 8s/epoch - 1ms/step
# Epoch 19/20
# 6668/6668 - 8s - loss: 3.7989 - 8s/epoch - 1ms/step
# Epoch 20/20
# 6668/6668 - 8s - loss: 3.7943 - 8s/epoch - 1ms/step
# Accuracy: 0.29
# Score : 0.8514

# %%
# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
nn.summary()
# Out:
# Final score (RMSE): 1.8467335496440245
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
#  dropout (Dropout)           (None, 1)                 0
#
#  dense_3 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 223
# Trainable params: 223
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # compile the keras model
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# # fit the keras model on the dataset
# model.fit(X, y, epochs=150, batch_size=10)
# # evaluate the keras model
# accuracy = model.evaluate(X, y)
# print('Accuracy: %.2f' % (accuracy*100))

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.2920873578531665
# Recall: 0.2920873578531665

# %%
#calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7789
#            1       0.28      0.18      0.22     25786
#            2       0.29      0.88      0.44     28872
#            3       0.12      0.00      0.01     18203
#            4       0.00      0.00      0.00      3875
#            5       0.16      0.02      0.03     11556
#            6       0.00      0.00      0.00       906
#            7       0.00      0.00      0.00      3384
#            8       0.00      0.00      0.00      1597
#            9       0.00      0.00      0.00       912
#           10       0.60      0.18      0.28      2205
#
#     accuracy                           0.29    105085
#    macro avg       0.13      0.11      0.09    105085
# weighted avg       0.20      0.29      0.19    105085
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4/2'></a>
# ### Application of models with SMOTE
# Here we are applying SMOTE for imbalanced data.
#
#
# We are reintroducing smote again and splitting our balanced data, so that our program does not pick X_test from the original data.

# %%
smote_health_care = health_care.copy()
# X = np.array(smote_health_care.loc[:, smote_health_care.columns != "Stay"])
y = np.array(smote_health_care.loc[:, smote_health_care.columns == "Stay"]).reshape(-1, 1)

X = scaler.fit_transform(X_pca_with_constant)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 2, shuffle = True, stratify = y)
oversample = SMOTE(random_state = 33)
X_train_SMOTE, y_train_SMOTE = oversample.fit_resample(X_train, y_train)

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.1'></a>
# ### KNN with SMOTE

# %%
#with Smote
knn = KNeighborsClassifier(n_neighbors=3) 
knn.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
#accuracy
print('Accuracy: %.2f' %accuracy_score(y_test,y_pred))
#score
print(f'Score : %.2f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy: 0.31
# Score : 0.86

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.305685873340629
# Recall: 0.305685873340629

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7789
#            1       0.29      0.24      0.26     25786
#            2       0.31      0.83      0.45     28872
#            3       0.27      0.03      0.06     18203
#            4       0.00      0.00      0.00      3875
#            5       0.27      0.07      0.12     11556
#            6       0.00      0.00      0.00       906
#            7       0.00      0.00      0.00      3384
#            8       0.00      0.00      0.00      1597
#            9       0.00      0.00      0.00       912
#           10       0.57      0.23      0.33      2205
#
#     accuracy                           0.31    105085
#    macro avg       0.15      0.13      0.11    105085
# weighted avg       0.24      0.31      0.22    105085
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.2'></a>
# ### Decision Tree with SMOTE

# %%
#with SMOTE
tree.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = tree.predict(X_test)

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.286
# Score : 0.8427
# Precision: 0.2855402769186849
# Recall: 0.2855402769186849

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.16      0.26      0.20      7789
#            1       0.34      0.34      0.34     25786
#            2       0.39      0.36      0.37     28872
#            3       0.27      0.19      0.22     18203
#            4       0.07      0.10      0.08      3875
#            5       0.33      0.28      0.30     11556
#            6       0.02      0.04      0.03       906
#            7       0.14      0.16      0.15      3384
#            8       0.17      0.22      0.19      1597
#            9       0.07      0.11      0.08       912
#           10       0.31      0.36      0.33      2205
#
#     accuracy                           0.29    105085
#    macro avg       0.21      0.22      0.21    105085
# weighted avg       0.30      0.29      0.29    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.3'></a>
# ### Random Forest with SMOTE

# %%
forest = RandomForestClassifier(n_estimators=10, criterion='entropy')
forest.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred = forest.predict(X_test)

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.290
# Score : 0.8462
# Precision: 0.29001284674311273
# Recall: 0.29001284674311273

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.25      0.20      7789
#            1       0.35      0.30      0.32     25786
#            2       0.39      0.38      0.39     28872
#            3       0.26      0.20      0.23     18203
#            4       0.07      0.11      0.08      3875
#            5       0.33      0.31      0.32     11556
#            6       0.02      0.04      0.03       906
#            7       0.15      0.18      0.16      3384
#            8       0.19      0.26      0.22      1597
#            9       0.08      0.11      0.09       912
#           10       0.34      0.41      0.37      2205
#
#     accuracy                           0.29    105085
#    macro avg       0.21      0.23      0.22    105085
# weighted avg       0.31      0.29      0.30    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.4'></a>
# ### Naive Bayes with SMOTE

# %%
## Keeping smoothing = 1
model = GaussianNB(var_smoothing=1)
model.fit(X_train_SMOTE, y_train_SMOTE)
y_pred = model.predict(X_test)

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.193
# Score : 0.7961
# Precision: 0.19288195270495315
# Recall: 0.19288195270495315

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.60      0.22      7789
#            1       0.37      0.13      0.19     25786
#            2       0.42      0.24      0.31     28872
#            3       0.26      0.01      0.03     18203
#            4       0.05      0.13      0.07      3875
#            5       0.30      0.24      0.27     11556
#            6       0.01      0.20      0.02       906
#            7       0.10      0.01      0.01      3384
#            8       0.12      0.58      0.19      1597
#            9       0.04      0.04      0.04       912
#           10       0.49      0.27      0.34      2205
#
#     accuracy                           0.19    105085
#    macro avg       0.21      0.22      0.15    105085
# weighted avg       0.31      0.19      0.20    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
# <a id='part4.2.5'></a>
# ### ANN with SMOTE

# %%
nn = Sequential()

#model.add(Dropout(0.1)) #applies to layer before ie input here
nn.add(Dense(12, input_dim=X.shape[1], activation='relu'))
nn.add(Dense(8, activation='relu'))
nn.add(Dense(1, activation='sigmoid'))
nn.add(Dropout(0.2))
nn.add(Dense(1))

# %%
nn.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='loss', min_delta=1e-4, patience=5, verbose=1, mode='auto')

# %%
nn.fit(X_train_SMOTE,y_train_SMOTE,verbose=1,epochs=20)
pred = nn.predict(X_test)
# Out:
# Epoch 1/20
# 20151/20151 [==============================] - 33s 2ms/step - loss: 10.7117
# Epoch 2/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.1456
# Epoch 3/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.0941
# Epoch 4/20
# 20151/20151 [==============================] - 33s 2ms/step - loss: 7.0924
# Epoch 5/20
# 20151/20151 [==============================] - 30s 1ms/step - loss: 7.0741
# Epoch 6/20
# 20151/20151 [==============================] - 30s 1ms/step - loss: 7.0648
# Epoch 7/20
# 20151/20151 [==============================] - 30s 1ms/step - loss: 7.0442
# Epoch 8/20
# 20151/20151 [==============================] - 30s 1ms/step - loss: 7.0584
# Epoch 9/20
# 20151/20151 [==============================] - 32s 2ms/step - loss: 7.0672
# Epoch 10/20
# 20151/20151 [==============================] - 33s 2ms/step - loss: 7.0587
# Epoch 11/20
# 20151/20151 [==============================] - 36s 2ms/step - loss: 7.0590: 0
# Epoch 12/20
# 20151/20151 [==============================] - 36s 2ms/step - loss: 7.0545
# Epoch 13/20
# 20151/20151 [==============================] - 35s 2ms/step - loss: 7.0444
# Epoch 14/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.0469
# Epoch 15/20
# 20151/20151 [==============================] - 33s 2ms/step - loss: 7.0299: 0s - loss: 7.029
# Epoch 16/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.0355
# Epoch 17/20
# 20151/20151 [==============================] - 33s 2ms/step - loss: 7.0323
# Epoch 18/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.0375
# Epoch 19/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.0310
# Epoch 20/20
# 20151/20151 [==============================] - 34s 2ms/step - loss: 7.0254: 0s - loss:

# %%
#Accuracy score
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))
# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Accuracy : 0.193
# Score : 0.7961
# Precision: 0.19288195270495315
# Recall: 0.19288195270495315

# %%
# calling classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.13      0.60      0.22      7789
#            1       0.37      0.13      0.19     25786
#            2       0.42      0.24      0.31     28872
#            3       0.26      0.01      0.03     18203
#            4       0.05      0.13      0.07      3875
#            5       0.30      0.24      0.27     11556
#            6       0.01      0.20      0.02       906
#            7       0.10      0.01      0.01      3384
#            8       0.12      0.58      0.19      1597
#            9       0.04      0.04      0.04       912
#           10       0.49      0.27      0.34      2205
#
#     accuracy                           0.19    105085
#    macro avg       0.21      0.22      0.15    105085
# weighted avg       0.31      0.19      0.20    105085

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm )
disp.plot()
plt.show();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5'></a>
#
# ## Part - 5 Additional Models

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5.1'></a>
# ### Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train, y_train)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GradientBoostingClassifier()

# %%
y_pred = model.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Accuracy : 0.365
# Score : 0.8791

# %%
# Model Precision
print("Precision:",precision_score(y_test, y_pred, average='micro'))

# Model Recall
print("Recall:",recall_score(y_test, y_pred, average='micro'))
# Out:
# Precision: 0.3645620212209164
# Recall: 0.3645620212209164

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5.2'></a>
# ### Cat Boost Classifier

# %%
from catboost import CatBoostClassifier
cb = CatBoostClassifier(iterations=1000)
cb.fit(X_train, y_train)
# Out:
# Learning rate set to 0.104018
# 0:	learn: 2.2569225	total: 538ms	remaining: 8m 57s
# 1:	learn: 2.1580242	total: 905ms	remaining: 7m 31s
# 2:	learn: 2.0817779	total: 1.26s	remaining: 6m 58s
# 3:	learn: 2.0216644	total: 1.61s	remaining: 6m 40s
# 4:	learn: 1.9743844	total: 1.98s	remaining: 6m 33s
# 5:	learn: 1.9340015	total: 2.36s	remaining: 6m 31s
# 6:	learn: 1.9008227	total: 2.79s	remaining: 6m 35s
# 7:	learn: 1.8729384	total: 3.17s	remaining: 6m 33s
# 8:	learn: 1.8494418	total: 3.54s	remaining: 6m 29s
# 9:	learn: 1.8282836	total: 3.91s	remaining: 6m 27s
# 10:	learn: 1.8106169	total: 4.31s	remaining: 6m 27s
# 11:	learn: 1.7956633	total: 4.67s	remaining: 6m 24s
# 12:	learn: 1.7823565	total: 5.04s	remaining: 6m 22s
# 13:	learn: 1.7703267	total: 5.42s	remaining: 6m 21s
# 14:	learn: 1.7602857	total: 5.78s	remaining: 6m 19s
# 15:	learn: 1.7514935	total: 6.15s	remaining: 6m 18s
# 16:	learn: 1.7428241	total: 6.52s	remaining: 6m 16s
# 17:	learn: 1.7354377	total: 6.87s	remaining: 6m 14s
# 18:	learn: 1.7289446	total: 7.22s	remaining: 6m 13s
# 19:	learn: 1.7234255	total: 7.57s	remaining: 6m 11s
# 20:	learn: 1.7181689	total: 7.94s	remaining: 6m 9s
# 21:	learn: 1.7137297	total: 8.31s	remaining: 6m 9s
# 22:	learn: 1.7092706	total: 8.7s	remaining: 6m 9s
# 23:	learn: 1.7054404	total: 9.11s	remaining: 6m 10s
# 24:	learn: 1.7017604	total: 9.61s	remaining: 6m 14s
# 25:	learn: 1.6989302	total: 10.1s	remaining: 6m 19s
# 26:	learn: 1.6956796	total: 10.7s	remaining: 6m 23s
# 27:	learn: 1.6932401	total: 11.2s	remaining: 6m 28s
# 28:	learn: 1.6911862	total: 11.7s	remaining: 6m 32s
# 29:	learn: 1.6892494	total: 12.2s	remaining: 6m 33s
# 30:	learn: 1.6875013	total: 12.6s	remaining: 6m 34s
# 31:	learn: 1.6853949	total: 13s	remaining: 6m 34s
# 32:	learn: 1.6837400	total: 13.4s	remaining: 6m 33s
# 33:	learn: 1.6822245	total: 13.8s	remaining: 6m 31s
# 34:	learn: 1.6806300	total: 14.2s	remaining: 6m 31s
# 35:	learn: 1.6791047	total: 14.6s	remaining: 6m 29s
# 36:	learn: 1.6776521	total: 14.9s	remaining: 6m 28s
# 37:	learn: 1.6763964	total: 15.4s	remaining: 6m 28s
# 38:	learn: 1.6746951	total: 15.7s	remaining: 6m 27s
# 39:	learn: 1.6738260	total: 16.1s	remaining: 6m 27s
# 40:	learn: 1.6724460	total: 16.5s	remaining: 6m 26s
# 41:	learn: 1.6710268	total: 17s	remaining: 6m 27s
# 42:	learn: 1.6699640	total: 17.4s	remaining: 6m 27s
# 43:	learn: 1.6689174	total: 17.8s	remaining: 6m 26s
# 44:	learn: 1.6676691	total: 18.1s	remaining: 6m 24s
# 45:	learn: 1.6665205	total: 18.5s	remaining: 6m 24s
# 46:	learn: 1.6656331	total: 18.9s	remaining: 6m 23s
# 47:	learn: 1.6649035	total: 19.4s	remaining: 6m 24s
# 48:	learn: 1.6640259	total: 19.7s	remaining: 6m 23s
# 49:	learn: 1.6631859	total: 20.2s	remaining: 6m 23s
# 50:	learn: 1.6625448	total: 20.5s	remaining: 6m 21s
# 51:	learn: 1.6621144	total: 20.9s	remaining: 6m 20s
# 52:	learn: 1.6611436	total: 21.3s	remaining: 6m 20s
# 53:	learn: 1.6603710	total: 21.6s	remaining: 6m 19s
# 54:	learn: 1.6598075	total: 22s	remaining: 6m 17s
# 55:	learn: 1.6591537	total: 22.4s	remaining: 6m 17s
# 56:	learn: 1.6585180	total: 22.7s	remaining: 6m 16s
# 57:	learn: 1.6578293	total: 23.1s	remaining: 6m 14s
# 58:	learn: 1.6570760	total: 23.4s	remaining: 6m 14s
# 59:	learn: 1.6565880	total: 23.9s	remaining: 6m 14s
# 60:	learn: 1.6559540	total: 24.3s	remaining: 6m 13s
# 61:	learn: 1.6554094	total: 24.6s	remaining: 6m 12s
# 62:	learn: 1.6546225	total: 25s	remaining: 6m 11s
# 63:	learn: 1.6542013	total: 25.4s	remaining: 6m 11s
# 64:	learn: 1.6533965	total: 25.7s	remaining: 6m 10s
# 65:	learn: 1.6526641	total: 26.1s	remaining: 6m 9s
# 66:	learn: 1.6522661	total: 26.5s	remaining: 6m 8s
# 67:	learn: 1.6518113	total: 26.8s	remaining: 6m 7s
# 68:	learn: 1.6511916	total: 27.2s	remaining: 6m 7s
# 69:	learn: 1.6507080	total: 27.6s	remaining: 6m 6s
# 70:	learn: 1.6500899	total: 27.9s	remaining: 6m 5s
# 71:	learn: 1.6497206	total: 28.3s	remaining: 6m 4s
# 72:	learn: 1.6491188	total: 28.7s	remaining: 6m 4s
# 73:	learn: 1.6486453	total: 29.1s	remaining: 6m 4s
# 74:	learn: 1.6483541	total: 29.7s	remaining: 6m 6s
# 75:	learn: 1.6480339	total: 30.2s	remaining: 6m 7s
# 76:	learn: 1.6475346	total: 30.6s	remaining: 6m 7s
# 77:	learn: 1.6471525	total: 31s	remaining: 6m 6s
# 78:	learn: 1.6467060	total: 31.4s	remaining: 6m 6s
# 79:	learn: 1.6460416	total: 31.8s	remaining: 6m 6s
# 80:	learn: 1.6456199	total: 32.2s	remaining: 6m 5s
# 81:	learn: 1.6451895	total: 32.6s	remaining: 6m 4s
# 82:	learn: 1.6449091	total: 33s	remaining: 6m 4s
# 83:	learn: 1.6446546	total: 33.4s	remaining: 6m 4s
# 84:	learn: 1.6442186	total: 33.7s	remaining: 6m 3s
# 85:	learn: 1.6436934	total: 34.1s	remaining: 6m 2s
# 86:	learn: 1.6432581	total: 34.4s	remaining: 6m 1s
# 87:	learn: 1.6429249	total: 34.8s	remaining: 6m
# 88:	learn: 1.6424048	total: 35.1s	remaining: 5m 59s
# 89:	learn: 1.6420450	total: 35.5s	remaining: 5m 58s
# 90:	learn: 1.6416583	total: 35.8s	remaining: 5m 57s
# 91:	learn: 1.6412205	total: 36.2s	remaining: 5m 56s
# 92:	learn: 1.6408199	total: 36.5s	remaining: 5m 56s
# 93:	learn: 1.6405261	total: 36.8s	remaining: 5m 55s
# 94:	learn: 1.6402211	total: 37.2s	remaining: 5m 54s
# 95:	learn: 1.6397606	total: 37.5s	remaining: 5m 53s
# 96:	learn: 1.6393671	total: 37.9s	remaining: 5m 52s
# 97:	learn: 1.6389556	total: 38.2s	remaining: 5m 51s
# 98:	learn: 1.6384798	total: 38.6s	remaining: 5m 50s
# 99:	learn: 1.6379825	total: 38.9s	remaining: 5m 50s
# 100:	learn: 1.6376371	total: 39.3s	remaining: 5m 49s
# 101:	learn: 1.6370446	total: 39.7s	remaining: 5m 49s
# 102:	learn: 1.6365738	total: 40.1s	remaining: 5m 49s
# 103:	learn: 1.6363171	total: 40.5s	remaining: 5m 49s
# 104:	learn: 1.6358171	total: 40.9s	remaining: 5m 48s
# 105:	learn: 1.6352754	total: 41.3s	remaining: 5m 48s
# 106:	learn: 1.6349068	total: 41.6s	remaining: 5m 47s
# 107:	learn: 1.6345775	total: 42s	remaining: 5m 46s
# 108:	learn: 1.6342036	total: 42.3s	remaining: 5m 46s
# 109:	learn: 1.6338163	total: 42.7s	remaining: 5m 45s
# 110:	learn: 1.6335698	total: 43.1s	remaining: 5m 45s
# 111:	learn: 1.6331778	total: 43.8s	remaining: 5m 47s
# 112:	learn: 1.6328431	total: 44.2s	remaining: 5m 46s
# 113:	learn: 1.6325270	total: 44.6s	remaining: 5m 47s
# 114:	learn: 1.6319936	total: 45s	remaining: 5m 46s
# 115:	learn: 1.6318173	total: 45.4s	remaining: 5m 46s
# 116:	learn: 1.6313616	total: 45.8s	remaining: 5m 45s
# 117:	learn: 1.6309691	total: 46.2s	remaining: 5m 45s
# 118:	learn: 1.6307444	total: 46.8s	remaining: 5m 46s
# 119:	learn: 1.6303121	total: 47.6s	remaining: 5m 49s
# 120:	learn: 1.6300852	total: 48.5s	remaining: 5m 51s
# 121:	learn: 1.6298538	total: 49.2s	remaining: 5m 53s
# 122:	learn: 1.6296120	total: 49.9s	remaining: 5m 56s
# 123:	learn: 1.6292845	total: 50.7s	remaining: 5m 58s
# 124:	learn: 1.6290157	total: 51.4s	remaining: 6m
# 125:	learn: 1.6288026	total: 51.9s	remaining: 6m
# 126:	learn: 1.6284394	total: 52.3s	remaining: 5m 59s
# 127:	learn: 1.6280871	total: 52.8s	remaining: 5m 59s
# 128:	learn: 1.6277723	total: 53.2s	remaining: 5m 59s
# 129:	learn: 1.6274555	total: 53.8s	remaining: 6m
# 130:	learn: 1.6272780	total: 54.3s	remaining: 5m 59s
# 131:	learn: 1.6270267	total: 54.6s	remaining: 5m 59s
# 132:	learn: 1.6267849	total: 55s	remaining: 5m 58s
# 133:	learn: 1.6262716	total: 55.3s	remaining: 5m 57s
# 134:	learn: 1.6259615	total: 55.7s	remaining: 5m 56s
# 135:	learn: 1.6258145	total: 56s	remaining: 5m 55s
# 136:	learn: 1.6254998	total: 56.4s	remaining: 5m 55s
# 137:	learn: 1.6251658	total: 56.7s	remaining: 5m 54s
# 138:	learn: 1.6249451	total: 57s	remaining: 5m 53s
# 139:	learn: 1.6246646	total: 57.4s	remaining: 5m 52s
# 140:	learn: 1.6243384	total: 57.7s	remaining: 5m 51s
# 141:	learn: 1.6240498	total: 58.1s	remaining: 5m 51s
# 142:	learn: 1.6237783	total: 58.4s	remaining: 5m 50s
# 143:	learn: 1.6234543	total: 58.8s	remaining: 5m 49s
# 144:	learn: 1.6231653	total: 59.1s	remaining: 5m 48s
# 145:	learn: 1.6229971	total: 59.5s	remaining: 5m 48s
# 146:	learn: 1.6228025	total: 59.8s	remaining: 5m 47s
# 147:	learn: 1.6223529	total: 1m	remaining: 5m 46s
# 148:	learn: 1.6220407	total: 1m	remaining: 5m 46s
# 149:	learn: 1.6218141	total: 1m 1s	remaining: 5m 46s
# 150:	learn: 1.6215433	total: 1m 1s	remaining: 5m 45s
# 151:	learn: 1.6211888	total: 1m 1s	remaining: 5m 45s
# 152:	learn: 1.6208997	total: 1m 2s	remaining: 5m 46s
# 153:	learn: 1.6206605	total: 1m 3s	remaining: 5m 46s
# 154:	learn: 1.6204381	total: 1m 3s	remaining: 5m 46s
# 155:	learn: 1.6202416	total: 1m 4s	remaining: 5m 46s
# 156:	learn: 1.6199309	total: 1m 4s	remaining: 5m 45s
# 157:	learn: 1.6195692	total: 1m 4s	remaining: 5m 45s
# 158:	learn: 1.6193776	total: 1m 5s	remaining: 5m 45s
# 159:	learn: 1.6189415	total: 1m 5s	remaining: 5m 44s
# 160:	learn: 1.6187287	total: 1m 6s	remaining: 5m 44s
# 161:	learn: 1.6185095	total: 1m 6s	remaining: 5m 44s
# 162:	learn: 1.6182962	total: 1m 6s	remaining: 5m 43s
# 163:	learn: 1.6179891	total: 1m 7s	remaining: 5m 42s
# 164:	learn: 1.6177203	total: 1m 7s	remaining: 5m 42s
# 165:	learn: 1.6174492	total: 1m 8s	remaining: 5m 41s
# 166:	learn: 1.6169907	total: 1m 8s	remaining: 5m 41s
# 167:	learn: 1.6167232	total: 1m 8s	remaining: 5m 40s
# 168:	learn: 1.6165170	total: 1m 9s	remaining: 5m 39s
# 169:	learn: 1.6161987	total: 1m 9s	remaining: 5m 39s
# 170:	learn: 1.6159865	total: 1m 9s	remaining: 5m 38s
# 171:	learn: 1.6158265	total: 1m 10s	remaining: 5m 37s
# 172:	learn: 1.6154761	total: 1m 10s	remaining: 5m 37s
# 173:	learn: 1.6152766	total: 1m 10s	remaining: 5m 36s
# 174:	learn: 1.6150846	total: 1m 11s	remaining: 5m 36s
# 175:	learn: 1.6147047	total: 1m 12s	remaining: 5m 37s
# 176:	learn: 1.6145659	total: 1m 12s	remaining: 5m 36s
# 177:	learn: 1.6143395	total: 1m 13s	remaining: 5m 37s
# 178:	learn: 1.6141294	total: 1m 13s	remaining: 5m 37s
# 179:	learn: 1.6138539	total: 1m 14s	remaining: 5m 37s
# 180:	learn: 1.6137012	total: 1m 14s	remaining: 5m 36s
# 181:	learn: 1.6134738	total: 1m 14s	remaining: 5m 36s
# 182:	learn: 1.6131263	total: 1m 15s	remaining: 5m 36s
# 183:	learn: 1.6127011	total: 1m 15s	remaining: 5m 36s
# 184:	learn: 1.6124667	total: 1m 16s	remaining: 5m 35s
# 185:	learn: 1.6120499	total: 1m 16s	remaining: 5m 35s
# 186:	learn: 1.6118404	total: 1m 16s	remaining: 5m 34s
# 187:	learn: 1.6116166	total: 1m 17s	remaining: 5m 33s
# 188:	learn: 1.6113602	total: 1m 17s	remaining: 5m 33s
# 189:	learn: 1.6111853	total: 1m 17s	remaining: 5m 32s
# 190:	learn: 1.6109411	total: 1m 18s	remaining: 5m 32s
# 191:	learn: 1.6107782	total: 1m 18s	remaining: 5m 31s
# 192:	learn: 1.6105758	total: 1m 19s	remaining: 5m 31s
# 193:	learn: 1.6103322	total: 1m 19s	remaining: 5m 30s
# 194:	learn: 1.6101206	total: 1m 20s	remaining: 5m 30s
# 195:	learn: 1.6097485	total: 1m 20s	remaining: 5m 29s
# 196:	learn: 1.6093640	total: 1m 20s	remaining: 5m 29s
# 197:	learn: 1.6091896	total: 1m 21s	remaining: 5m 29s
# 198:	learn: 1.6090621	total: 1m 21s	remaining: 5m 28s
# 199:	learn: 1.6088055	total: 1m 21s	remaining: 5m 27s
# 200:	learn: 1.6086780	total: 1m 22s	remaining: 5m 27s
# 201:	learn: 1.6085415	total: 1m 22s	remaining: 5m 26s
# 202:	learn: 1.6082968	total: 1m 23s	remaining: 5m 26s
# 203:	learn: 1.6080533	total: 1m 23s	remaining: 5m 25s
# 204:	learn: 1.6077712	total: 1m 23s	remaining: 5m 25s
# 205:	learn: 1.6076022	total: 1m 24s	remaining: 5m 24s
# 206:	learn: 1.6072909	total: 1m 24s	remaining: 5m 24s
# 207:	learn: 1.6069060	total: 1m 24s	remaining: 5m 23s
# 208:	learn: 1.6066040	total: 1m 25s	remaining: 5m 23s
# 209:	learn: 1.6064249	total: 1m 25s	remaining: 5m 22s
# 210:	learn: 1.6062295	total: 1m 26s	remaining: 5m 22s
# 211:	learn: 1.6060989	total: 1m 26s	remaining: 5m 21s
# 212:	learn: 1.6059293	total: 1m 26s	remaining: 5m 21s
# 213:	learn: 1.6057700	total: 1m 27s	remaining: 5m 20s
# 214:	learn: 1.6055792	total: 1m 27s	remaining: 5m 19s
# 215:	learn: 1.6053829	total: 1m 27s	remaining: 5m 19s
# 216:	learn: 1.6051822	total: 1m 28s	remaining: 5m 18s
# 217:	learn: 1.6050242	total: 1m 28s	remaining: 5m 17s
# 218:	learn: 1.6047256	total: 1m 29s	remaining: 5m 17s
# 219:	learn: 1.6046243	total: 1m 29s	remaining: 5m 16s
# 220:	learn: 1.6043750	total: 1m 29s	remaining: 5m 16s
# 221:	learn: 1.6042004	total: 1m 30s	remaining: 5m 15s
# 222:	learn: 1.6039557	total: 1m 30s	remaining: 5m 15s
# 223:	learn: 1.6037509	total: 1m 30s	remaining: 5m 14s
# 224:	learn: 1.6035599	total: 1m 31s	remaining: 5m 13s
# 225:	learn: 1.6033164	total: 1m 31s	remaining: 5m 13s
# 226:	learn: 1.6029811	total: 1m 31s	remaining: 5m 12s
# 227:	learn: 1.6026385	total: 1m 32s	remaining: 5m 12s
# 228:	learn: 1.6023889	total: 1m 32s	remaining: 5m 11s
# 229:	learn: 1.6021261	total: 1m 32s	remaining: 5m 11s
# 230:	learn: 1.6019799	total: 1m 33s	remaining: 5m 10s
# 231:	learn: 1.6016689	total: 1m 33s	remaining: 5m 10s
# 232:	learn: 1.6015452	total: 1m 34s	remaining: 5m 9s
# 233:	learn: 1.6013859	total: 1m 34s	remaining: 5m 9s
# 234:	learn: 1.6012535	total: 1m 34s	remaining: 5m 8s
# 235:	learn: 1.6010350	total: 1m 35s	remaining: 5m 8s
# 236:	learn: 1.6008935	total: 1m 35s	remaining: 5m 7s
# 237:	learn: 1.6006776	total: 1m 35s	remaining: 5m 7s
# 238:	learn: 1.6005289	total: 1m 36s	remaining: 5m 6s
# 239:	learn: 1.6003955	total: 1m 36s	remaining: 5m 6s
# 240:	learn: 1.6002315	total: 1m 37s	remaining: 5m 5s
# 241:	learn: 1.5999975	total: 1m 37s	remaining: 5m 5s
# 242:	learn: 1.5997347	total: 1m 37s	remaining: 5m 4s
# 243:	learn: 1.5995156	total: 1m 38s	remaining: 5m 4s
# 244:	learn: 1.5993193	total: 1m 38s	remaining: 5m 4s
# 245:	learn: 1.5990252	total: 1m 39s	remaining: 5m 3s
# 246:	learn: 1.5987523	total: 1m 39s	remaining: 5m 3s
# 247:	learn: 1.5985844	total: 1m 39s	remaining: 5m 2s
# 248:	learn: 1.5982683	total: 1m 40s	remaining: 5m 2s
# 249:	learn: 1.5981830	total: 1m 40s	remaining: 5m 2s
# 250:	learn: 1.5978700	total: 1m 41s	remaining: 5m 1s
# 251:	learn: 1.5977048	total: 1m 41s	remaining: 5m 1s
# 252:	learn: 1.5974385	total: 1m 41s	remaining: 5m
# 253:	learn: 1.5971840	total: 1m 42s	remaining: 5m
# 254:	learn: 1.5969844	total: 1m 42s	remaining: 5m
# 255:	learn: 1.5968017	total: 1m 43s	remaining: 4m 59s
# 256:	learn: 1.5966437	total: 1m 43s	remaining: 4m 59s
# 257:	learn: 1.5964196	total: 1m 43s	remaining: 4m 58s
# 258:	learn: 1.5962445	total: 1m 44s	remaining: 4m 58s
# 259:	learn: 1.5960489	total: 1m 44s	remaining: 4m 57s
# 260:	learn: 1.5959553	total: 1m 45s	remaining: 4m 57s
# 261:	learn: 1.5957768	total: 1m 45s	remaining: 4m 57s
# 262:	learn: 1.5955969	total: 1m 45s	remaining: 4m 57s
# 263:	learn: 1.5954092	total: 1m 46s	remaining: 4m 56s
# 264:	learn: 1.5951615	total: 1m 46s	remaining: 4m 55s
# 265:	learn: 1.5948762	total: 1m 47s	remaining: 4m 55s
# 266:	learn: 1.5945373	total: 1m 47s	remaining: 4m 55s
# 267:	learn: 1.5943492	total: 1m 48s	remaining: 4m 55s
# 268:	learn: 1.5940522	total: 1m 48s	remaining: 4m 54s
# 269:	learn: 1.5939016	total: 1m 48s	remaining: 4m 54s
# 270:	learn: 1.5936836	total: 1m 49s	remaining: 4m 53s
# 271:	learn: 1.5934847	total: 1m 49s	remaining: 4m 53s
# 272:	learn: 1.5933604	total: 1m 49s	remaining: 4m 52s
# 273:	learn: 1.5931981	total: 1m 50s	remaining: 4m 52s
# 274:	learn: 1.5930198	total: 1m 50s	remaining: 4m 51s
# 275:	learn: 1.5929201	total: 1m 51s	remaining: 4m 51s
# 276:	learn: 1.5927947	total: 1m 51s	remaining: 4m 50s
# 277:	learn: 1.5925681	total: 1m 51s	remaining: 4m 50s
# 278:	learn: 1.5923553	total: 1m 52s	remaining: 4m 50s
# 279:	learn: 1.5921520	total: 1m 52s	remaining: 4m 49s
# 280:	learn: 1.5919424	total: 1m 53s	remaining: 4m 49s
# 281:	learn: 1.5918221	total: 1m 53s	remaining: 4m 48s
# 282:	learn: 1.5916812	total: 1m 53s	remaining: 4m 48s
# 283:	learn: 1.5915391	total: 1m 54s	remaining: 4m 47s
# 284:	learn: 1.5913934	total: 1m 54s	remaining: 4m 47s
# 285:	learn: 1.5913000	total: 1m 54s	remaining: 4m 46s
# 286:	learn: 1.5911219	total: 1m 55s	remaining: 4m 46s
# 287:	learn: 1.5909259	total: 1m 55s	remaining: 4m 45s
# 288:	learn: 1.5907158	total: 1m 55s	remaining: 4m 45s
# 289:	learn: 1.5905959	total: 1m 56s	remaining: 4m 44s
# 290:	learn: 1.5904232	total: 1m 56s	remaining: 4m 44s
# 291:	learn: 1.5902173	total: 1m 56s	remaining: 4m 43s
# 292:	learn: 1.5899006	total: 1m 57s	remaining: 4m 43s
# 293:	learn: 1.5897326	total: 1m 57s	remaining: 4m 42s
# 294:	learn: 1.5895807	total: 1m 58s	remaining: 4m 42s
# 295:	learn: 1.5894029	total: 1m 58s	remaining: 4m 41s
# 296:	learn: 1.5892455	total: 1m 58s	remaining: 4m 41s
# 297:	learn: 1.5891406	total: 1m 59s	remaining: 4m 40s
# 298:	learn: 1.5889893	total: 1m 59s	remaining: 4m 40s
# 299:	learn: 1.5888083	total: 1m 59s	remaining: 4m 39s
# 300:	learn: 1.5886584	total: 2m	remaining: 4m 39s
# 301:	learn: 1.5884530	total: 2m	remaining: 4m 38s
# 302:	learn: 1.5881904	total: 2m	remaining: 4m 38s
# 303:	learn: 1.5880742	total: 2m 1s	remaining: 4m 37s
# 304:	learn: 1.5879202	total: 2m 1s	remaining: 4m 37s
# 305:	learn: 1.5877156	total: 2m 2s	remaining: 4m 36s
# 306:	learn: 1.5875020	total: 2m 2s	remaining: 4m 36s
# 307:	learn: 1.5872763	total: 2m 2s	remaining: 4m 35s
# 308:	learn: 1.5870251	total: 2m 3s	remaining: 4m 35s
# 309:	learn: 1.5868409	total: 2m 3s	remaining: 4m 34s
# 310:	learn: 1.5867011	total: 2m 3s	remaining: 4m 34s
# 311:	learn: 1.5866004	total: 2m 4s	remaining: 4m 33s
# 312:	learn: 1.5864295	total: 2m 4s	remaining: 4m 33s
# 313:	learn: 1.5863069	total: 2m 4s	remaining: 4m 32s
# 314:	learn: 1.5862040	total: 2m 5s	remaining: 4m 32s
# 315:	learn: 1.5860849	total: 2m 5s	remaining: 4m 31s
# 316:	learn: 1.5859025	total: 2m 6s	remaining: 4m 31s
# 317:	learn: 1.5856779	total: 2m 6s	remaining: 4m 31s
# 318:	learn: 1.5855520	total: 2m 6s	remaining: 4m 30s
# 319:	learn: 1.5854111	total: 2m 7s	remaining: 4m 30s
# 320:	learn: 1.5852259	total: 2m 7s	remaining: 4m 30s
# 321:	learn: 1.5850861	total: 2m 8s	remaining: 4m 29s
# 322:	learn: 1.5849869	total: 2m 8s	remaining: 4m 29s
# 323:	learn: 1.5848656	total: 2m 8s	remaining: 4m 29s
# 324:	learn: 1.5847022	total: 2m 9s	remaining: 4m 28s
# 325:	learn: 1.5845179	total: 2m 9s	remaining: 4m 28s
# 326:	learn: 1.5842966	total: 2m 10s	remaining: 4m 28s
# 327:	learn: 1.5841426	total: 2m 10s	remaining: 4m 27s
# 328:	learn: 1.5840282	total: 2m 11s	remaining: 4m 27s
# 329:	learn: 1.5838620	total: 2m 11s	remaining: 4m 26s
# 330:	learn: 1.5837127	total: 2m 11s	remaining: 4m 26s
# 331:	learn: 1.5836150	total: 2m 12s	remaining: 4m 26s
# 332:	learn: 1.5834166	total: 2m 12s	remaining: 4m 25s
# 333:	learn: 1.5832308	total: 2m 12s	remaining: 4m 25s
# 334:	learn: 1.5831260	total: 2m 13s	remaining: 4m 24s
# 335:	learn: 1.5828710	total: 2m 13s	remaining: 4m 24s
# 336:	learn: 1.5826569	total: 2m 14s	remaining: 4m 23s
# 337:	learn: 1.5825338	total: 2m 14s	remaining: 4m 23s
# 338:	learn: 1.5824130	total: 2m 14s	remaining: 4m 22s
# 339:	learn: 1.5822516	total: 2m 15s	remaining: 4m 22s
# 340:	learn: 1.5821060	total: 2m 15s	remaining: 4m 21s
# 341:	learn: 1.5819414	total: 2m 15s	remaining: 4m 21s
# 342:	learn: 1.5818451	total: 2m 16s	remaining: 4m 20s
# 343:	learn: 1.5816892	total: 2m 16s	remaining: 4m 20s
# 344:	learn: 1.5814593	total: 2m 16s	remaining: 4m 19s
# 345:	learn: 1.5813313	total: 2m 17s	remaining: 4m 19s
# 346:	learn: 1.5812306	total: 2m 17s	remaining: 4m 18s
# 347:	learn: 1.5810879	total: 2m 17s	remaining: 4m 18s
# 348:	learn: 1.5809426	total: 2m 18s	remaining: 4m 17s
# 349:	learn: 1.5807841	total: 2m 18s	remaining: 4m 17s
# 350:	learn: 1.5806306	total: 2m 18s	remaining: 4m 16s
# 351:	learn: 1.5804472	total: 2m 19s	remaining: 4m 16s
# 352:	learn: 1.5803632	total: 2m 19s	remaining: 4m 15s
# 353:	learn: 1.5802058	total: 2m 19s	remaining: 4m 15s
# 354:	learn: 1.5800688	total: 2m 20s	remaining: 4m 14s
# 355:	learn: 1.5799011	total: 2m 20s	remaining: 4m 14s
# 356:	learn: 1.5797564	total: 2m 20s	remaining: 4m 13s
# 357:	learn: 1.5795916	total: 2m 21s	remaining: 4m 13s
# 358:	learn: 1.5794444	total: 2m 21s	remaining: 4m 12s
# 359:	learn: 1.5793741	total: 2m 21s	remaining: 4m 12s
# 360:	learn: 1.5792174	total: 2m 22s	remaining: 4m 11s
# 361:	learn: 1.5790394	total: 2m 22s	remaining: 4m 11s
# 362:	learn: 1.5789222	total: 2m 23s	remaining: 4m 11s
# 363:	learn: 1.5788024	total: 2m 23s	remaining: 4m 10s
# 364:	learn: 1.5786958	total: 2m 23s	remaining: 4m 10s
# 365:	learn: 1.5785724	total: 2m 24s	remaining: 4m 9s
# 366:	learn: 1.5784280	total: 2m 24s	remaining: 4m 9s
# 367:	learn: 1.5782615	total: 2m 24s	remaining: 4m 8s
# 368:	learn: 1.5780500	total: 2m 25s	remaining: 4m 8s
# 369:	learn: 1.5779048	total: 2m 25s	remaining: 4m 8s
# 370:	learn: 1.5778009	total: 2m 26s	remaining: 4m 7s
# 371:	learn: 1.5776686	total: 2m 26s	remaining: 4m 7s
# 372:	learn: 1.5775480	total: 2m 26s	remaining: 4m 6s
# 373:	learn: 1.5774213	total: 2m 27s	remaining: 4m 6s
# 374:	learn: 1.5772995	total: 2m 27s	remaining: 4m 5s
# 375:	learn: 1.5770855	total: 2m 27s	remaining: 4m 5s
# 376:	learn: 1.5770186	total: 2m 28s	remaining: 4m 4s
# 377:	learn: 1.5768456	total: 2m 28s	remaining: 4m 4s
# 378:	learn: 1.5767258	total: 2m 28s	remaining: 4m 4s
# 379:	learn: 1.5765964	total: 2m 29s	remaining: 4m 3s
# 380:	learn: 1.5764422	total: 2m 29s	remaining: 4m 3s
# 381:	learn: 1.5763334	total: 2m 30s	remaining: 4m 2s
# 382:	learn: 1.5762387	total: 2m 30s	remaining: 4m 2s
# 383:	learn: 1.5761137	total: 2m 30s	remaining: 4m 1s
# 384:	learn: 1.5759698	total: 2m 31s	remaining: 4m 1s
# 385:	learn: 1.5757931	total: 2m 31s	remaining: 4m 1s
# 386:	learn: 1.5756830	total: 2m 31s	remaining: 4m
# 387:	learn: 1.5754611	total: 2m 32s	remaining: 4m
# 388:	learn: 1.5752986	total: 2m 32s	remaining: 3m 59s
# 389:	learn: 1.5751405	total: 2m 33s	remaining: 3m 59s
# 390:	learn: 1.5749312	total: 2m 33s	remaining: 3m 59s
# 391:	learn: 1.5748072	total: 2m 33s	remaining: 3m 58s
# 392:	learn: 1.5746135	total: 2m 34s	remaining: 3m 58s
# 393:	learn: 1.5744511	total: 2m 34s	remaining: 3m 57s
# 394:	learn: 1.5743791	total: 2m 35s	remaining: 3m 57s
# 395:	learn: 1.5742405	total: 2m 35s	remaining: 3m 57s
# 396:	learn: 1.5740667	total: 2m 35s	remaining: 3m 56s
# 397:	learn: 1.5739545	total: 2m 36s	remaining: 3m 56s
# 398:	learn: 1.5738293	total: 2m 36s	remaining: 3m 55s
# 399:	learn: 1.5736537	total: 2m 36s	remaining: 3m 55s
# 400:	learn: 1.5735167	total: 2m 37s	remaining: 3m 54s
# 401:	learn: 1.5733436	total: 2m 37s	remaining: 3m 54s
# 402:	learn: 1.5732242	total: 2m 37s	remaining: 3m 53s
# 403:	learn: 1.5731132	total: 2m 38s	remaining: 3m 53s
# 404:	learn: 1.5730135	total: 2m 38s	remaining: 3m 53s
# 405:	learn: 1.5729191	total: 2m 39s	remaining: 3m 52s
# 406:	learn: 1.5727920	total: 2m 39s	remaining: 3m 52s
# 407:	learn: 1.5726823	total: 2m 40s	remaining: 3m 52s
# 408:	learn: 1.5725982	total: 2m 40s	remaining: 3m 51s
# 409:	learn: 1.5724358	total: 2m 41s	remaining: 3m 51s
# 410:	learn: 1.5723281	total: 2m 41s	remaining: 3m 51s
# 411:	learn: 1.5721830	total: 2m 41s	remaining: 3m 51s
# 412:	learn: 1.5720805	total: 2m 42s	remaining: 3m 50s
# 413:	learn: 1.5719165	total: 2m 42s	remaining: 3m 50s
# 414:	learn: 1.5717616	total: 2m 43s	remaining: 3m 50s
# 415:	learn: 1.5716139	total: 2m 43s	remaining: 3m 49s
# 416:	learn: 1.5714651	total: 2m 44s	remaining: 3m 49s
# 417:	learn: 1.5713181	total: 2m 44s	remaining: 3m 48s
# 418:	learn: 1.5711949	total: 2m 44s	remaining: 3m 48s
# 419:	learn: 1.5711023	total: 2m 45s	remaining: 3m 48s
# 420:	learn: 1.5710077	total: 2m 45s	remaining: 3m 47s
# 421:	learn: 1.5708966	total: 2m 46s	remaining: 3m 47s
# 422:	learn: 1.5707279	total: 2m 46s	remaining: 3m 47s
# 423:	learn: 1.5706269	total: 2m 46s	remaining: 3m 46s
# 424:	learn: 1.5704868	total: 2m 47s	remaining: 3m 46s
# 425:	learn: 1.5702902	total: 2m 47s	remaining: 3m 45s
# 426:	learn: 1.5701392	total: 2m 47s	remaining: 3m 45s
# 427:	learn: 1.5699995	total: 2m 48s	remaining: 3m 44s
# 428:	learn: 1.5699198	total: 2m 48s	remaining: 3m 44s
# 429:	learn: 1.5698357	total: 2m 48s	remaining: 3m 43s
# 430:	learn: 1.5697549	total: 2m 49s	remaining: 3m 43s
# 431:	learn: 1.5696300	total: 2m 49s	remaining: 3m 43s
# 432:	learn: 1.5695040	total: 2m 50s	remaining: 3m 42s
# 433:	learn: 1.5693900	total: 2m 50s	remaining: 3m 42s
# 434:	learn: 1.5692469	total: 2m 50s	remaining: 3m 41s
# 435:	learn: 1.5691077	total: 2m 51s	remaining: 3m 41s
# 436:	learn: 1.5689317	total: 2m 51s	remaining: 3m 41s
# 437:	learn: 1.5688330	total: 2m 51s	remaining: 3m 40s
# 438:	learn: 1.5686612	total: 2m 52s	remaining: 3m 40s
# 439:	learn: 1.5685202	total: 2m 52s	remaining: 3m 39s
# 440:	learn: 1.5683804	total: 2m 52s	remaining: 3m 39s
# 441:	learn: 1.5682158	total: 2m 53s	remaining: 3m 38s
# 442:	learn: 1.5680621	total: 2m 53s	remaining: 3m 38s
# 443:	learn: 1.5679391	total: 2m 54s	remaining: 3m 37s
# 444:	learn: 1.5678298	total: 2m 54s	remaining: 3m 37s
# 445:	learn: 1.5677241	total: 2m 54s	remaining: 3m 37s
# 446:	learn: 1.5676153	total: 2m 55s	remaining: 3m 36s
# 447:	learn: 1.5675537	total: 2m 55s	remaining: 3m 36s
# 448:	learn: 1.5673454	total: 2m 56s	remaining: 3m 36s
# 449:	learn: 1.5672500	total: 2m 56s	remaining: 3m 35s
# 450:	learn: 1.5671732	total: 2m 56s	remaining: 3m 35s
# 451:	learn: 1.5669916	total: 2m 57s	remaining: 3m 34s
# 452:	learn: 1.5668286	total: 2m 57s	remaining: 3m 34s
# 453:	learn: 1.5667039	total: 2m 57s	remaining: 3m 34s
# 454:	learn: 1.5665858	total: 2m 58s	remaining: 3m 33s
# 455:	learn: 1.5664700	total: 2m 58s	remaining: 3m 33s
# 456:	learn: 1.5662752	total: 2m 59s	remaining: 3m 32s
# 457:	learn: 1.5661669	total: 2m 59s	remaining: 3m 32s
# 458:	learn: 1.5660705	total: 2m 59s	remaining: 3m 31s
# 459:	learn: 1.5659072	total: 3m	remaining: 3m 31s
# 460:	learn: 1.5657686	total: 3m	remaining: 3m 30s
# 461:	learn: 1.5656519	total: 3m	remaining: 3m 30s
# 462:	learn: 1.5655592	total: 3m 1s	remaining: 3m 30s
# 463:	learn: 1.5653465	total: 3m 1s	remaining: 3m 29s
# 464:	learn: 1.5652207	total: 3m 1s	remaining: 3m 29s
# 465:	learn: 1.5650820	total: 3m 2s	remaining: 3m 28s
# 466:	learn: 1.5649780	total: 3m 2s	remaining: 3m 28s
# 467:	learn: 1.5648765	total: 3m 2s	remaining: 3m 27s
# 468:	learn: 1.5647820	total: 3m 3s	remaining: 3m 27s
# 469:	learn: 1.5646634	total: 3m 3s	remaining: 3m 27s
# 470:	learn: 1.5644889	total: 3m 3s	remaining: 3m 26s
# 471:	learn: 1.5643960	total: 3m 4s	remaining: 3m 26s
# 472:	learn: 1.5642082	total: 3m 4s	remaining: 3m 25s
# 473:	learn: 1.5640991	total: 3m 5s	remaining: 3m 25s
# 474:	learn: 1.5639592	total: 3m 5s	remaining: 3m 24s
# 475:	learn: 1.5638405	total: 3m 5s	remaining: 3m 24s
# 476:	learn: 1.5636976	total: 3m 6s	remaining: 3m 24s
# 477:	learn: 1.5635648	total: 3m 6s	remaining: 3m 23s
# 478:	learn: 1.5634121	total: 3m 6s	remaining: 3m 23s
# 479:	learn: 1.5631680	total: 3m 7s	remaining: 3m 22s
# 480:	learn: 1.5630697	total: 3m 7s	remaining: 3m 22s
# 481:	learn: 1.5629856	total: 3m 7s	remaining: 3m 21s
# 482:	learn: 1.5628508	total: 3m 8s	remaining: 3m 21s
# 483:	learn: 1.5627662	total: 3m 8s	remaining: 3m 21s
# 484:	learn: 1.5626547	total: 3m 9s	remaining: 3m 20s
# 485:	learn: 1.5625347	total: 3m 9s	remaining: 3m 20s
# 486:	learn: 1.5624256	total: 3m 9s	remaining: 3m 19s
# 487:	learn: 1.5623221	total: 3m 10s	remaining: 3m 19s
# 488:	learn: 1.5622264	total: 3m 10s	remaining: 3m 19s
# 489:	learn: 1.5621232	total: 3m 11s	remaining: 3m 19s
# 490:	learn: 1.5619967	total: 3m 11s	remaining: 3m 18s
# 491:	learn: 1.5618293	total: 3m 12s	remaining: 3m 18s
# 492:	learn: 1.5617404	total: 3m 12s	remaining: 3m 17s
# 493:	learn: 1.5616177	total: 3m 12s	remaining: 3m 17s
# 494:	learn: 1.5615036	total: 3m 13s	remaining: 3m 17s
# 495:	learn: 1.5613866	total: 3m 13s	remaining: 3m 16s
# 496:	learn: 1.5612071	total: 3m 14s	remaining: 3m 16s
# 497:	learn: 1.5611167	total: 3m 14s	remaining: 3m 16s
# 498:	learn: 1.5609522	total: 3m 14s	remaining: 3m 15s
# 499:	learn: 1.5608259	total: 3m 15s	remaining: 3m 15s
# 500:	learn: 1.5606786	total: 3m 15s	remaining: 3m 14s
# 501:	learn: 1.5605393	total: 3m 15s	remaining: 3m 14s
# 502:	learn: 1.5604670	total: 3m 16s	remaining: 3m 13s
# 503:	learn: 1.5603718	total: 3m 16s	remaining: 3m 13s
# 504:	learn: 1.5602489	total: 3m 16s	remaining: 3m 13s
# 505:	learn: 1.5601216	total: 3m 17s	remaining: 3m 12s
# 506:	learn: 1.5599961	total: 3m 17s	remaining: 3m 12s
# 507:	learn: 1.5598865	total: 3m 18s	remaining: 3m 11s
# 508:	learn: 1.5597718	total: 3m 18s	remaining: 3m 11s
# 509:	learn: 1.5596304	total: 3m 18s	remaining: 3m 11s
# 510:	learn: 1.5595305	total: 3m 19s	remaining: 3m 10s
# 511:	learn: 1.5594284	total: 3m 19s	remaining: 3m 10s
# 512:	learn: 1.5593524	total: 3m 19s	remaining: 3m 9s
# 513:	learn: 1.5592622	total: 3m 20s	remaining: 3m 9s
# 514:	learn: 1.5590777	total: 3m 20s	remaining: 3m 8s
# 515:	learn: 1.5589030	total: 3m 20s	remaining: 3m 8s
# 516:	learn: 1.5588225	total: 3m 21s	remaining: 3m 8s
# 517:	learn: 1.5587083	total: 3m 21s	remaining: 3m 7s
# 518:	learn: 1.5585686	total: 3m 21s	remaining: 3m 7s
# 519:	learn: 1.5584551	total: 3m 22s	remaining: 3m 6s
# 520:	learn: 1.5583394	total: 3m 22s	remaining: 3m 6s
# 521:	learn: 1.5582291	total: 3m 23s	remaining: 3m 5s
# 522:	learn: 1.5581096	total: 3m 23s	remaining: 3m 5s
# 523:	learn: 1.5580130	total: 3m 23s	remaining: 3m 5s
# 524:	learn: 1.5578683	total: 3m 24s	remaining: 3m 4s
# 525:	learn: 1.5577393	total: 3m 24s	remaining: 3m 4s
# 526:	learn: 1.5576243	total: 3m 24s	remaining: 3m 3s
# 527:	learn: 1.5575051	total: 3m 25s	remaining: 3m 3s
# 528:	learn: 1.5573721	total: 3m 25s	remaining: 3m 3s
# 529:	learn: 1.5572716	total: 3m 26s	remaining: 3m 2s
# 530:	learn: 1.5570970	total: 3m 26s	remaining: 3m 2s
# 531:	learn: 1.5570035	total: 3m 27s	remaining: 3m 2s
# 532:	learn: 1.5568959	total: 3m 27s	remaining: 3m 1s
# 533:	learn: 1.5567814	total: 3m 27s	remaining: 3m 1s
# 534:	learn: 1.5566642	total: 3m 28s	remaining: 3m 1s
# 535:	learn: 1.5565356	total: 3m 28s	remaining: 3m
# 536:	learn: 1.5564171	total: 3m 29s	remaining: 3m
# 537:	learn: 1.5562607	total: 3m 29s	remaining: 3m
# 538:	learn: 1.5561412	total: 3m 30s	remaining: 2m 59s
# 539:	learn: 1.5560181	total: 3m 30s	remaining: 2m 59s
# 540:	learn: 1.5558654	total: 3m 31s	remaining: 2m 59s
# 541:	learn: 1.5557631	total: 3m 31s	remaining: 2m 58s
# 542:	learn: 1.5556485	total: 3m 31s	remaining: 2m 58s
# 543:	learn: 1.5555056	total: 3m 32s	remaining: 2m 58s
# 544:	learn: 1.5554198	total: 3m 32s	remaining: 2m 57s
# 545:	learn: 1.5551785	total: 3m 33s	remaining: 2m 57s
# 546:	learn: 1.5550062	total: 3m 33s	remaining: 2m 56s
# 547:	learn: 1.5549188	total: 3m 33s	remaining: 2m 56s
# 548:	learn: 1.5548296	total: 3m 34s	remaining: 2m 56s
# 549:	learn: 1.5547249	total: 3m 34s	remaining: 2m 55s
# 550:	learn: 1.5546338	total: 3m 35s	remaining: 2m 55s
# 551:	learn: 1.5545236	total: 3m 35s	remaining: 2m 55s
# 552:	learn: 1.5543943	total: 3m 36s	remaining: 2m 54s
# 553:	learn: 1.5542959	total: 3m 36s	remaining: 2m 54s
# 554:	learn: 1.5542265	total: 3m 36s	remaining: 2m 53s
# 555:	learn: 1.5541253	total: 3m 37s	remaining: 2m 53s
# 556:	learn: 1.5539422	total: 3m 37s	remaining: 2m 53s
# 557:	learn: 1.5538659	total: 3m 37s	remaining: 2m 52s
# 558:	learn: 1.5537366	total: 3m 38s	remaining: 2m 52s
# 559:	learn: 1.5535835	total: 3m 38s	remaining: 2m 51s
# 560:	learn: 1.5534625	total: 3m 39s	remaining: 2m 51s
# 561:	learn: 1.5533594	total: 3m 39s	remaining: 2m 51s
# 562:	learn: 1.5532880	total: 3m 39s	remaining: 2m 50s
# 563:	learn: 1.5531888	total: 3m 40s	remaining: 2m 50s
# 564:	learn: 1.5530573	total: 3m 40s	remaining: 2m 50s
# 565:	learn: 1.5529329	total: 3m 41s	remaining: 2m 49s
# 566:	learn: 1.5528430	total: 3m 41s	remaining: 2m 49s
# 567:	learn: 1.5526880	total: 3m 42s	remaining: 2m 49s
# 568:	learn: 1.5525856	total: 3m 42s	remaining: 2m 48s
# 569:	learn: 1.5525047	total: 3m 43s	remaining: 2m 48s
# 570:	learn: 1.5524225	total: 3m 43s	remaining: 2m 47s
# 571:	learn: 1.5523235	total: 3m 44s	remaining: 2m 47s
# 572:	learn: 1.5522022	total: 3m 44s	remaining: 2m 47s
# 573:	learn: 1.5521248	total: 3m 44s	remaining: 2m 46s
# 574:	learn: 1.5520286	total: 3m 45s	remaining: 2m 46s
# 575:	learn: 1.5519160	total: 3m 45s	remaining: 2m 46s
# 576:	learn: 1.5517612	total: 3m 46s	remaining: 2m 45s
# 577:	learn: 1.5516514	total: 3m 46s	remaining: 2m 45s
# 578:	learn: 1.5515823	total: 3m 46s	remaining: 2m 44s
# 579:	learn: 1.5514460	total: 3m 47s	remaining: 2m 44s
# 580:	learn: 1.5513573	total: 3m 47s	remaining: 2m 44s
# 581:	learn: 1.5512695	total: 3m 47s	remaining: 2m 43s
# 582:	learn: 1.5511689	total: 3m 48s	remaining: 2m 43s
# 583:	learn: 1.5509870	total: 3m 48s	remaining: 2m 42s
# 584:	learn: 1.5508866	total: 3m 49s	remaining: 2m 42s
# 585:	learn: 1.5507566	total: 3m 49s	remaining: 2m 42s
# 586:	learn: 1.5506533	total: 3m 49s	remaining: 2m 41s
# 587:	learn: 1.5505530	total: 3m 50s	remaining: 2m 41s
# 588:	learn: 1.5504418	total: 3m 50s	remaining: 2m 40s
# 589:	learn: 1.5503434	total: 3m 50s	remaining: 2m 40s
# 590:	learn: 1.5501555	total: 3m 51s	remaining: 2m 40s
# 591:	learn: 1.5500573	total: 3m 51s	remaining: 2m 39s
# 592:	learn: 1.5499482	total: 3m 51s	remaining: 2m 39s
# 593:	learn: 1.5498575	total: 3m 52s	remaining: 2m 38s
# 594:	learn: 1.5497591	total: 3m 52s	remaining: 2m 38s
# 595:	learn: 1.5496753	total: 3m 52s	remaining: 2m 37s
# 596:	learn: 1.5495001	total: 3m 53s	remaining: 2m 37s
# 597:	learn: 1.5493774	total: 3m 53s	remaining: 2m 37s
# 598:	learn: 1.5492794	total: 3m 54s	remaining: 2m 36s
# 599:	learn: 1.5491736	total: 3m 54s	remaining: 2m 36s
# 600:	learn: 1.5491011	total: 3m 54s	remaining: 2m 35s
# 601:	learn: 1.5490108	total: 3m 55s	remaining: 2m 35s
# 602:	learn: 1.5489077	total: 3m 55s	remaining: 2m 35s
# 603:	learn: 1.5488248	total: 3m 55s	remaining: 2m 34s
# 604:	learn: 1.5487334	total: 3m 56s	remaining: 2m 34s
# 605:	learn: 1.5486704	total: 3m 56s	remaining: 2m 33s
# 606:	learn: 1.5485417	total: 3m 56s	remaining: 2m 33s
# 607:	learn: 1.5484838	total: 3m 57s	remaining: 2m 32s
# 608:	learn: 1.5482925	total: 3m 57s	remaining: 2m 32s
# 609:	learn: 1.5482109	total: 3m 57s	remaining: 2m 32s
# 610:	learn: 1.5481090	total: 3m 58s	remaining: 2m 31s
# 611:	learn: 1.5480067	total: 3m 58s	remaining: 2m 31s
# 612:	learn: 1.5478886	total: 3m 59s	remaining: 2m 30s
# 613:	learn: 1.5477903	total: 3m 59s	remaining: 2m 30s
# 614:	learn: 1.5476959	total: 3m 59s	remaining: 2m 30s
# 615:	learn: 1.5476011	total: 4m	remaining: 2m 29s
# 616:	learn: 1.5475102	total: 4m	remaining: 2m 29s
# 617:	learn: 1.5473296	total: 4m 1s	remaining: 2m 28s
# 618:	learn: 1.5471998	total: 4m 1s	remaining: 2m 28s
# 619:	learn: 1.5471181	total: 4m 1s	remaining: 2m 28s
# 620:	learn: 1.5470053	total: 4m 2s	remaining: 2m 27s
# 621:	learn: 1.5469191	total: 4m 2s	remaining: 2m 27s
# 622:	learn: 1.5468498	total: 4m 2s	remaining: 2m 26s
# 623:	learn: 1.5467643	total: 4m 3s	remaining: 2m 26s
# 624:	learn: 1.5466485	total: 4m 3s	remaining: 2m 26s
# 625:	learn: 1.5464906	total: 4m 3s	remaining: 2m 25s
# 626:	learn: 1.5463654	total: 4m 4s	remaining: 2m 25s
# 627:	learn: 1.5461374	total: 4m 4s	remaining: 2m 24s
# 628:	learn: 1.5459612	total: 4m 4s	remaining: 2m 24s
# 629:	learn: 1.5458561	total: 4m 5s	remaining: 2m 24s
# 630:	learn: 1.5457459	total: 4m 5s	remaining: 2m 23s
# 631:	learn: 1.5455546	total: 4m 5s	remaining: 2m 23s
# 632:	learn: 1.5454715	total: 4m 6s	remaining: 2m 22s
# 633:	learn: 1.5452977	total: 4m 6s	remaining: 2m 22s
# 634:	learn: 1.5451922	total: 4m 7s	remaining: 2m 21s
# 635:	learn: 1.5450427	total: 4m 7s	remaining: 2m 21s
# 636:	learn: 1.5449108	total: 4m 7s	remaining: 2m 21s
# 637:	learn: 1.5448104	total: 4m 8s	remaining: 2m 20s
# 638:	learn: 1.5447395	total: 4m 8s	remaining: 2m 20s
# 639:	learn: 1.5446572	total: 4m 8s	remaining: 2m 19s
# 640:	learn: 1.5445210	total: 4m 9s	remaining: 2m 19s
# 641:	learn: 1.5443686	total: 4m 9s	remaining: 2m 19s
# 642:	learn: 1.5442548	total: 4m 9s	remaining: 2m 18s
# 643:	learn: 1.5441230	total: 4m 10s	remaining: 2m 18s
# 644:	learn: 1.5440573	total: 4m 10s	remaining: 2m 17s
# 645:	learn: 1.5439563	total: 4m 10s	remaining: 2m 17s
# 646:	learn: 1.5438849	total: 4m 11s	remaining: 2m 17s
# 647:	learn: 1.5437757	total: 4m 11s	remaining: 2m 16s
# 648:	learn: 1.5436941	total: 4m 11s	remaining: 2m 16s
# 649:	learn: 1.5435485	total: 4m 12s	remaining: 2m 15s
# 650:	learn: 1.5434465	total: 4m 12s	remaining: 2m 15s
# 651:	learn: 1.5433190	total: 4m 13s	remaining: 2m 15s
# 652:	learn: 1.5432655	total: 4m 13s	remaining: 2m 14s
# 653:	learn: 1.5431937	total: 4m 13s	remaining: 2m 14s
# 654:	learn: 1.5430120	total: 4m 14s	remaining: 2m 13s
# 655:	learn: 1.5429304	total: 4m 14s	remaining: 2m 13s
# 656:	learn: 1.5428421	total: 4m 15s	remaining: 2m 13s
# 657:	learn: 1.5427325	total: 4m 15s	remaining: 2m 12s
# 658:	learn: 1.5426412	total: 4m 15s	remaining: 2m 12s
# 659:	learn: 1.5425356	total: 4m 16s	remaining: 2m 12s
# 660:	learn: 1.5424152	total: 4m 16s	remaining: 2m 11s
# 661:	learn: 1.5423484	total: 4m 17s	remaining: 2m 11s
# 662:	learn: 1.5422439	total: 4m 17s	remaining: 2m 10s
# 663:	learn: 1.5421581	total: 4m 17s	remaining: 2m 10s
# 664:	learn: 1.5420682	total: 4m 18s	remaining: 2m 10s
# 665:	learn: 1.5419528	total: 4m 18s	remaining: 2m 9s
# 666:	learn: 1.5418527	total: 4m 18s	remaining: 2m 9s
# 667:	learn: 1.5416977	total: 4m 19s	remaining: 2m 8s
# 668:	learn: 1.5415999	total: 4m 19s	remaining: 2m 8s
# 669:	learn: 1.5414548	total: 4m 19s	remaining: 2m 8s
# 670:	learn: 1.5413717	total: 4m 20s	remaining: 2m 7s
# 671:	learn: 1.5412982	total: 4m 20s	remaining: 2m 7s
# 672:	learn: 1.5412176	total: 4m 21s	remaining: 2m 6s
# 673:	learn: 1.5411318	total: 4m 21s	remaining: 2m 6s
# 674:	learn: 1.5409994	total: 4m 21s	remaining: 2m 6s
# 675:	learn: 1.5408893	total: 4m 22s	remaining: 2m 5s
# 676:	learn: 1.5407816	total: 4m 22s	remaining: 2m 5s
# 677:	learn: 1.5406396	total: 4m 22s	remaining: 2m 4s
# 678:	learn: 1.5405068	total: 4m 23s	remaining: 2m 4s
# 679:	learn: 1.5404070	total: 4m 23s	remaining: 2m 4s
# 680:	learn: 1.5402986	total: 4m 23s	remaining: 2m 3s
# 681:	learn: 1.5402196	total: 4m 24s	remaining: 2m 3s
# 682:	learn: 1.5401449	total: 4m 24s	remaining: 2m 2s
# 683:	learn: 1.5400628	total: 4m 24s	remaining: 2m 2s
# 684:	learn: 1.5399844	total: 4m 25s	remaining: 2m 2s
# 685:	learn: 1.5398773	total: 4m 25s	remaining: 2m 1s
# 686:	learn: 1.5397710	total: 4m 26s	remaining: 2m 1s
# 687:	learn: 1.5396170	total: 4m 26s	remaining: 2m
# 688:	learn: 1.5395218	total: 4m 26s	remaining: 2m
# 689:	learn: 1.5394217	total: 4m 27s	remaining: 1m 59s
# 690:	learn: 1.5392930	total: 4m 27s	remaining: 1m 59s
# 691:	learn: 1.5392205	total: 4m 27s	remaining: 1m 59s
# 692:	learn: 1.5391453	total: 4m 28s	remaining: 1m 58s
# 693:	learn: 1.5390706	total: 4m 28s	remaining: 1m 58s
# 694:	learn: 1.5389831	total: 4m 28s	remaining: 1m 57s
# 695:	learn: 1.5388822	total: 4m 29s	remaining: 1m 57s
# 696:	learn: 1.5387803	total: 4m 29s	remaining: 1m 57s
# 697:	learn: 1.5387103	total: 4m 29s	remaining: 1m 56s
# 698:	learn: 1.5385968	total: 4m 30s	remaining: 1m 56s
# 699:	learn: 1.5385334	total: 4m 30s	remaining: 1m 56s
# 700:	learn: 1.5384500	total: 4m 31s	remaining: 1m 55s
# 701:	learn: 1.5383735	total: 4m 31s	remaining: 1m 55s
# 702:	learn: 1.5383189	total: 4m 32s	remaining: 1m 54s
# 703:	learn: 1.5382319	total: 4m 32s	remaining: 1m 54s
# 704:	learn: 1.5381636	total: 4m 32s	remaining: 1m 54s
# 705:	learn: 1.5380705	total: 4m 33s	remaining: 1m 53s
# 706:	learn: 1.5379969	total: 4m 33s	remaining: 1m 53s
# 707:	learn: 1.5379327	total: 4m 34s	remaining: 1m 53s
# 708:	learn: 1.5378797	total: 4m 34s	remaining: 1m 52s
# 709:	learn: 1.5377840	total: 4m 34s	remaining: 1m 52s
# 710:	learn: 1.5377336	total: 4m 35s	remaining: 1m 51s
# 711:	learn: 1.5375724	total: 4m 35s	remaining: 1m 51s
# 712:	learn: 1.5374700	total: 4m 35s	remaining: 1m 51s
# 713:	learn: 1.5373986	total: 4m 36s	remaining: 1m 50s
# 714:	learn: 1.5372693	total: 4m 36s	remaining: 1m 50s
# 715:	learn: 1.5371426	total: 4m 36s	remaining: 1m 49s
# 716:	learn: 1.5370779	total: 4m 37s	remaining: 1m 49s
# 717:	learn: 1.5369980	total: 4m 37s	remaining: 1m 49s
# 718:	learn: 1.5369020	total: 4m 38s	remaining: 1m 48s
# 719:	learn: 1.5368101	total: 4m 38s	remaining: 1m 48s
# 720:	learn: 1.5367145	total: 4m 38s	remaining: 1m 47s
# 721:	learn: 1.5366206	total: 4m 39s	remaining: 1m 47s
# 722:	learn: 1.5364992	total: 4m 39s	remaining: 1m 47s
# 723:	learn: 1.5363978	total: 4m 39s	remaining: 1m 46s
# 724:	learn: 1.5363271	total: 4m 40s	remaining: 1m 46s
# 725:	learn: 1.5362497	total: 4m 40s	remaining: 1m 45s
# 726:	learn: 1.5361684	total: 4m 40s	remaining: 1m 45s
# 727:	learn: 1.5360246	total: 4m 41s	remaining: 1m 45s
# 728:	learn: 1.5359247	total: 4m 41s	remaining: 1m 44s
# 729:	learn: 1.5358428	total: 4m 42s	remaining: 1m 44s
# 730:	learn: 1.5357038	total: 4m 42s	remaining: 1m 43s
# 731:	learn: 1.5356128	total: 4m 42s	remaining: 1m 43s
# 732:	learn: 1.5355573	total: 4m 43s	remaining: 1m 43s
# 733:	learn: 1.5354266	total: 4m 43s	remaining: 1m 42s
# 734:	learn: 1.5353310	total: 4m 43s	remaining: 1m 42s
# 735:	learn: 1.5352548	total: 4m 44s	remaining: 1m 42s
# 736:	learn: 1.5351950	total: 4m 44s	remaining: 1m 41s
# 737:	learn: 1.5351187	total: 4m 45s	remaining: 1m 41s
# 738:	learn: 1.5349377	total: 4m 45s	remaining: 1m 40s
# 739:	learn: 1.5348516	total: 4m 45s	remaining: 1m 40s
# 740:	learn: 1.5347384	total: 4m 46s	remaining: 1m 40s
# 741:	learn: 1.5346348	total: 4m 46s	remaining: 1m 39s
# 742:	learn: 1.5345587	total: 4m 47s	remaining: 1m 39s
# 743:	learn: 1.5344537	total: 4m 47s	remaining: 1m 38s
# 744:	learn: 1.5343421	total: 4m 47s	remaining: 1m 38s
# 745:	learn: 1.5342461	total: 4m 48s	remaining: 1m 38s
# 746:	learn: 1.5340961	total: 4m 48s	remaining: 1m 37s
# 747:	learn: 1.5340312	total: 4m 49s	remaining: 1m 37s
# 748:	learn: 1.5339320	total: 4m 49s	remaining: 1m 37s
# 749:	learn: 1.5338152	total: 4m 50s	remaining: 1m 36s
# 750:	learn: 1.5337090	total: 4m 50s	remaining: 1m 36s
# 751:	learn: 1.5336196	total: 4m 50s	remaining: 1m 35s
# 752:	learn: 1.5335057	total: 4m 51s	remaining: 1m 35s
# 753:	learn: 1.5333917	total: 4m 51s	remaining: 1m 35s
# 754:	learn: 1.5333216	total: 4m 52s	remaining: 1m 34s
# 755:	learn: 1.5332349	total: 4m 52s	remaining: 1m 34s
# 756:	learn: 1.5331049	total: 4m 52s	remaining: 1m 33s
# 757:	learn: 1.5329939	total: 4m 53s	remaining: 1m 33s
# 758:	learn: 1.5328935	total: 4m 53s	remaining: 1m 33s
# 759:	learn: 1.5327952	total: 4m 53s	remaining: 1m 32s
# 760:	learn: 1.5327287	total: 4m 54s	remaining: 1m 32s
# 761:	learn: 1.5325886	total: 4m 54s	remaining: 1m 32s
# 762:	learn: 1.5325131	total: 4m 55s	remaining: 1m 31s
# 763:	learn: 1.5324053	total: 4m 55s	remaining: 1m 31s
# 764:	learn: 1.5323305	total: 4m 55s	remaining: 1m 30s
# 765:	learn: 1.5322207	total: 4m 56s	remaining: 1m 30s
# 766:	learn: 1.5321436	total: 4m 56s	remaining: 1m 30s
# 767:	learn: 1.5320772	total: 4m 56s	remaining: 1m 29s
# 768:	learn: 1.5319986	total: 4m 57s	remaining: 1m 29s
# 769:	learn: 1.5319207	total: 4m 57s	remaining: 1m 28s
# 770:	learn: 1.5318380	total: 4m 57s	remaining: 1m 28s
# 771:	learn: 1.5317788	total: 4m 58s	remaining: 1m 28s
# 772:	learn: 1.5317056	total: 4m 58s	remaining: 1m 27s
# 773:	learn: 1.5315919	total: 4m 58s	remaining: 1m 27s
# 774:	learn: 1.5315138	total: 4m 59s	remaining: 1m 26s
# 775:	learn: 1.5314125	total: 4m 59s	remaining: 1m 26s
# 776:	learn: 1.5313195	total: 4m 59s	remaining: 1m 26s
# 777:	learn: 1.5312413	total: 5m	remaining: 1m 25s
# 778:	learn: 1.5311749	total: 5m	remaining: 1m 25s
# 779:	learn: 1.5310872	total: 5m 1s	remaining: 1m 24s
# 780:	learn: 1.5309925	total: 5m 1s	remaining: 1m 24s
# 781:	learn: 1.5309101	total: 5m 1s	remaining: 1m 24s
# 782:	learn: 1.5308433	total: 5m 2s	remaining: 1m 23s
# 783:	learn: 1.5307259	total: 5m 2s	remaining: 1m 23s
# 784:	learn: 1.5306503	total: 5m 2s	remaining: 1m 22s
# 785:	learn: 1.5305408	total: 5m 3s	remaining: 1m 22s
# 786:	learn: 1.5304904	total: 5m 3s	remaining: 1m 22s
# 787:	learn: 1.5303957	total: 5m 4s	remaining: 1m 21s
# 788:	learn: 1.5303186	total: 5m 4s	remaining: 1m 21s
# 789:	learn: 1.5302226	total: 5m 4s	remaining: 1m 21s
# 790:	learn: 1.5301132	total: 5m 5s	remaining: 1m 20s
# 791:	learn: 1.5299592	total: 5m 5s	remaining: 1m 20s
# 792:	learn: 1.5299190	total: 5m 5s	remaining: 1m 19s
# 793:	learn: 1.5298103	total: 5m 6s	remaining: 1m 19s
# 794:	learn: 1.5297000	total: 5m 6s	remaining: 1m 19s
# 795:	learn: 1.5295989	total: 5m 7s	remaining: 1m 18s
# 796:	learn: 1.5294890	total: 5m 7s	remaining: 1m 18s
# 797:	learn: 1.5294030	total: 5m 7s	remaining: 1m 17s
# 798:	learn: 1.5293539	total: 5m 8s	remaining: 1m 17s
# 799:	learn: 1.5292736	total: 5m 8s	remaining: 1m 17s
# 800:	learn: 1.5291969	total: 5m 8s	remaining: 1m 16s
# 801:	learn: 1.5290944	total: 5m 9s	remaining: 1m 16s
# 802:	learn: 1.5290089	total: 5m 9s	remaining: 1m 15s
# 803:	learn: 1.5288991	total: 5m 10s	remaining: 1m 15s
# 804:	learn: 1.5288294	total: 5m 10s	remaining: 1m 15s
# 805:	learn: 1.5287364	total: 5m 10s	remaining: 1m 14s
# 806:	learn: 1.5286806	total: 5m 11s	remaining: 1m 14s
# 807:	learn: 1.5285516	total: 5m 11s	remaining: 1m 14s
# 808:	learn: 1.5284859	total: 5m 11s	remaining: 1m 13s
# 809:	learn: 1.5283320	total: 5m 12s	remaining: 1m 13s
# 810:	learn: 1.5282643	total: 5m 12s	remaining: 1m 12s
# 811:	learn: 1.5281757	total: 5m 13s	remaining: 1m 12s
# 812:	learn: 1.5281100	total: 5m 13s	remaining: 1m 12s
# 813:	learn: 1.5280116	total: 5m 13s	remaining: 1m 11s
# 814:	learn: 1.5278952	total: 5m 14s	remaining: 1m 11s
# 815:	learn: 1.5278201	total: 5m 14s	remaining: 1m 10s
# 816:	learn: 1.5277141	total: 5m 14s	remaining: 1m 10s
# 817:	learn: 1.5276069	total: 5m 15s	remaining: 1m 10s
# 818:	learn: 1.5275225	total: 5m 15s	remaining: 1m 9s
# 819:	learn: 1.5274414	total: 5m 16s	remaining: 1m 9s
# 820:	learn: 1.5273369	total: 5m 16s	remaining: 1m 8s
# 821:	learn: 1.5272222	total: 5m 16s	remaining: 1m 8s
# 822:	learn: 1.5271420	total: 5m 17s	remaining: 1m 8s
# 823:	learn: 1.5270925	total: 5m 17s	remaining: 1m 7s
# 824:	learn: 1.5270271	total: 5m 17s	remaining: 1m 7s
# 825:	learn: 1.5269560	total: 5m 18s	remaining: 1m 7s
# 826:	learn: 1.5268922	total: 5m 18s	remaining: 1m 6s
# 827:	learn: 1.5268443	total: 5m 19s	remaining: 1m 6s
# 828:	learn: 1.5267773	total: 5m 19s	remaining: 1m 5s
# 829:	learn: 1.5266624	total: 5m 20s	remaining: 1m 5s
# 830:	learn: 1.5266145	total: 5m 20s	remaining: 1m 5s
# 831:	learn: 1.5265232	total: 5m 20s	remaining: 1m 4s
# 832:	learn: 1.5264147	total: 5m 21s	remaining: 1m 4s
# 833:	learn: 1.5263234	total: 5m 21s	remaining: 1m 4s
# 834:	learn: 1.5262589	total: 5m 21s	remaining: 1m 3s
# 835:	learn: 1.5260848	total: 5m 22s	remaining: 1m 3s
# 836:	learn: 1.5259942	total: 5m 22s	remaining: 1m 2s
# 837:	learn: 1.5259044	total: 5m 23s	remaining: 1m 2s
# 838:	learn: 1.5258380	total: 5m 23s	remaining: 1m 2s
# 839:	learn: 1.5257843	total: 5m 23s	remaining: 1m 1s
# 840:	learn: 1.5256690	total: 5m 24s	remaining: 1m 1s
# 841:	learn: 1.5255661	total: 5m 24s	remaining: 1m
# 842:	learn: 1.5254661	total: 5m 24s	remaining: 1m
# 843:	learn: 1.5253556	total: 5m 25s	remaining: 1m
# 844:	learn: 1.5252900	total: 5m 25s	remaining: 59.7s
# 845:	learn: 1.5251950	total: 5m 26s	remaining: 59.3s
# 846:	learn: 1.5250875	total: 5m 26s	remaining: 59s
# 847:	learn: 1.5250092	total: 5m 26s	remaining: 58.6s
# 848:	learn: 1.5249517	total: 5m 27s	remaining: 58.2s
# 849:	learn: 1.5248881	total: 5m 27s	remaining: 57.8s
# 850:	learn: 1.5247814	total: 5m 27s	remaining: 57.4s
# 851:	learn: 1.5247251	total: 5m 28s	remaining: 57s
# 852:	learn: 1.5246426	total: 5m 28s	remaining: 56.6s
# 853:	learn: 1.5245751	total: 5m 28s	remaining: 56.2s
# 854:	learn: 1.5244845	total: 5m 29s	remaining: 55.8s
# 855:	learn: 1.5244078	total: 5m 29s	remaining: 55.4s
# 856:	learn: 1.5242844	total: 5m 29s	remaining: 55.1s
# 857:	learn: 1.5242269	total: 5m 30s	remaining: 54.7s
# 858:	learn: 1.5241380	total: 5m 30s	remaining: 54.3s
# 859:	learn: 1.5240418	total: 5m 31s	remaining: 53.9s
# 860:	learn: 1.5239386	total: 5m 31s	remaining: 53.5s
# 861:	learn: 1.5238648	total: 5m 31s	remaining: 53.1s
# 862:	learn: 1.5237857	total: 5m 32s	remaining: 52.7s
# 863:	learn: 1.5237305	total: 5m 32s	remaining: 52.3s
# 864:	learn: 1.5236371	total: 5m 32s	remaining: 51.9s
# 865:	learn: 1.5235408	total: 5m 33s	remaining: 51.5s
# 866:	learn: 1.5234534	total: 5m 33s	remaining: 51.2s
# 867:	learn: 1.5233365	total: 5m 33s	remaining: 50.8s
# 868:	learn: 1.5232371	total: 5m 34s	remaining: 50.4s
# 869:	learn: 1.5231372	total: 5m 34s	remaining: 50s
# 870:	learn: 1.5230569	total: 5m 35s	remaining: 49.6s
# 871:	learn: 1.5229537	total: 5m 35s	remaining: 49.2s
# 872:	learn: 1.5228978	total: 5m 35s	remaining: 48.9s
# 873:	learn: 1.5228403	total: 5m 36s	remaining: 48.5s
# 874:	learn: 1.5227516	total: 5m 36s	remaining: 48.1s
# 875:	learn: 1.5226592	total: 5m 36s	remaining: 47.7s
# 876:	learn: 1.5225769	total: 5m 37s	remaining: 47.3s
# 877:	learn: 1.5224635	total: 5m 37s	remaining: 46.9s
# 878:	learn: 1.5223522	total: 5m 38s	remaining: 46.5s
# 879:	learn: 1.5221756	total: 5m 38s	remaining: 46.2s
# 880:	learn: 1.5221148	total: 5m 38s	remaining: 45.8s
# 881:	learn: 1.5220459	total: 5m 39s	remaining: 45.4s
# 882:	learn: 1.5219601	total: 5m 39s	remaining: 45s
# 883:	learn: 1.5219007	total: 5m 39s	remaining: 44.6s
# 884:	learn: 1.5218055	total: 5m 40s	remaining: 44.2s
# 885:	learn: 1.5216870	total: 5m 40s	remaining: 43.8s
# 886:	learn: 1.5215868	total: 5m 40s	remaining: 43.4s
# 887:	learn: 1.5214919	total: 5m 41s	remaining: 43s
# 888:	learn: 1.5213827	total: 5m 41s	remaining: 42.7s
# 889:	learn: 1.5212462	total: 5m 42s	remaining: 42.3s
# 890:	learn: 1.5211724	total: 5m 42s	remaining: 41.9s
# 891:	learn: 1.5210828	total: 5m 42s	remaining: 41.5s
# 892:	learn: 1.5210113	total: 5m 43s	remaining: 41.1s
# 893:	learn: 1.5208827	total: 5m 43s	remaining: 40.7s
# 894:	learn: 1.5207766	total: 5m 43s	remaining: 40.3s
# 895:	learn: 1.5206687	total: 5m 44s	remaining: 39.9s
# 896:	learn: 1.5205804	total: 5m 44s	remaining: 39.6s
# 897:	learn: 1.5205150	total: 5m 44s	remaining: 39.2s
# 898:	learn: 1.5204043	total: 5m 45s	remaining: 38.8s
# 899:	learn: 1.5202920	total: 5m 45s	remaining: 38.4s
# 900:	learn: 1.5202124	total: 5m 45s	remaining: 38s
# 901:	learn: 1.5201300	total: 5m 46s	remaining: 37.6s
# 902:	learn: 1.5200819	total: 5m 46s	remaining: 37.2s
# 903:	learn: 1.5200469	total: 5m 46s	remaining: 36.8s
# 904:	learn: 1.5199573	total: 5m 47s	remaining: 36.5s
# 905:	learn: 1.5199057	total: 5m 47s	remaining: 36.1s
# 906:	learn: 1.5197805	total: 5m 48s	remaining: 35.7s
# 907:	learn: 1.5197153	total: 5m 48s	remaining: 35.3s
# 908:	learn: 1.5196187	total: 5m 48s	remaining: 34.9s
# 909:	learn: 1.5194963	total: 5m 49s	remaining: 34.5s
# 910:	learn: 1.5194417	total: 5m 49s	remaining: 34.1s
# 911:	learn: 1.5193504	total: 5m 49s	remaining: 33.8s
# 912:	learn: 1.5192890	total: 5m 50s	remaining: 33.4s
# 913:	learn: 1.5191578	total: 5m 50s	remaining: 33s
# 914:	learn: 1.5190720	total: 5m 50s	remaining: 32.6s
# 915:	learn: 1.5189702	total: 5m 51s	remaining: 32.2s
# 916:	learn: 1.5189088	total: 5m 51s	remaining: 31.8s
# 917:	learn: 1.5188053	total: 5m 52s	remaining: 31.5s
# 918:	learn: 1.5187357	total: 5m 52s	remaining: 31.1s
# 919:	learn: 1.5186609	total: 5m 52s	remaining: 30.7s
# 920:	learn: 1.5186033	total: 5m 53s	remaining: 30.3s
# 921:	learn: 1.5185072	total: 5m 53s	remaining: 29.9s
# 922:	learn: 1.5184288	total: 5m 54s	remaining: 29.5s
# 923:	learn: 1.5183590	total: 5m 54s	remaining: 29.1s
# 924:	learn: 1.5182593	total: 5m 54s	remaining: 28.8s
# 925:	learn: 1.5181925	total: 5m 55s	remaining: 28.4s
# 926:	learn: 1.5181116	total: 5m 55s	remaining: 28s
# 927:	learn: 1.5179984	total: 5m 55s	remaining: 27.6s
# 928:	learn: 1.5179193	total: 5m 56s	remaining: 27.2s
# 929:	learn: 1.5178658	total: 5m 56s	remaining: 26.8s
# 930:	learn: 1.5177985	total: 5m 56s	remaining: 26.4s
# 931:	learn: 1.5177178	total: 5m 57s	remaining: 26.1s
# 932:	learn: 1.5176067	total: 5m 57s	remaining: 25.7s
# 933:	learn: 1.5175039	total: 5m 57s	remaining: 25.3s
# 934:	learn: 1.5174076	total: 5m 58s	remaining: 24.9s
# 935:	learn: 1.5173455	total: 5m 58s	remaining: 24.5s
# 936:	learn: 1.5171790	total: 5m 58s	remaining: 24.1s
# 937:	learn: 1.5170862	total: 5m 59s	remaining: 23.8s
# 938:	learn: 1.5170101	total: 5m 59s	remaining: 23.4s
# 939:	learn: 1.5169474	total: 6m	remaining: 23s
# 940:	learn: 1.5168559	total: 6m	remaining: 22.6s
# 941:	learn: 1.5167844	total: 6m	remaining: 22.2s
# 942:	learn: 1.5166767	total: 6m 1s	remaining: 21.8s
# 943:	learn: 1.5165790	total: 6m 1s	remaining: 21.4s
# 944:	learn: 1.5165184	total: 6m 1s	remaining: 21.1s
# 945:	learn: 1.5164573	total: 6m 2s	remaining: 20.7s
# 946:	learn: 1.5163718	total: 6m 2s	remaining: 20.3s
# 947:	learn: 1.5162846	total: 6m 2s	remaining: 19.9s
# 948:	learn: 1.5161467	total: 6m 3s	remaining: 19.5s
# 949:	learn: 1.5160622	total: 6m 3s	remaining: 19.1s
# 950:	learn: 1.5159988	total: 6m 4s	remaining: 18.8s
# 951:	learn: 1.5159240	total: 6m 4s	remaining: 18.4s
# 952:	learn: 1.5158358	total: 6m 4s	remaining: 18s
# 953:	learn: 1.5157455	total: 6m 5s	remaining: 17.6s
# 954:	learn: 1.5156636	total: 6m 5s	remaining: 17.2s
# 955:	learn: 1.5155884	total: 6m 5s	remaining: 16.8s
# 956:	learn: 1.5154420	total: 6m 6s	remaining: 16.5s
# 957:	learn: 1.5153201	total: 6m 6s	remaining: 16.1s
# 958:	learn: 1.5152218	total: 6m 7s	remaining: 15.7s
# 959:	learn: 1.5151457	total: 6m 7s	remaining: 15.3s
# 960:	learn: 1.5151009	total: 6m 7s	remaining: 14.9s
# 961:	learn: 1.5150227	total: 6m 8s	remaining: 14.5s
# 962:	learn: 1.5149115	total: 6m 8s	remaining: 14.2s
# 963:	learn: 1.5148135	total: 6m 9s	remaining: 13.8s
# 964:	learn: 1.5147560	total: 6m 9s	remaining: 13.4s
# 965:	learn: 1.5146699	total: 6m 9s	remaining: 13s
# 966:	learn: 1.5146022	total: 6m 10s	remaining: 12.6s
# 967:	learn: 1.5145050	total: 6m 10s	remaining: 12.3s
# 968:	learn: 1.5144237	total: 6m 11s	remaining: 11.9s
# 969:	learn: 1.5143367	total: 6m 11s	remaining: 11.5s
# 970:	learn: 1.5141885	total: 6m 11s	remaining: 11.1s
# 971:	learn: 1.5141286	total: 6m 12s	remaining: 10.7s
# 972:	learn: 1.5140457	total: 6m 12s	remaining: 10.3s
# 973:	learn: 1.5139176	total: 6m 12s	remaining: 9.95s
# 974:	learn: 1.5138840	total: 6m 13s	remaining: 9.57s
# 975:	learn: 1.5138196	total: 6m 13s	remaining: 9.18s
# 976:	learn: 1.5137381	total: 6m 13s	remaining: 8.8s
# 977:	learn: 1.5136652	total: 6m 14s	remaining: 8.42s
# 978:	learn: 1.5135411	total: 6m 14s	remaining: 8.03s
# 979:	learn: 1.5134620	total: 6m 14s	remaining: 7.65s
# 980:	learn: 1.5133688	total: 6m 15s	remaining: 7.27s
# 981:	learn: 1.5133080	total: 6m 15s	remaining: 6.88s
# 982:	learn: 1.5132279	total: 6m 15s	remaining: 6.5s
# 983:	learn: 1.5131381	total: 6m 16s	remaining: 6.12s
# 984:	learn: 1.5130719	total: 6m 16s	remaining: 5.74s
# 985:	learn: 1.5129658	total: 6m 17s	remaining: 5.35s
# 986:	learn: 1.5128896	total: 6m 17s	remaining: 4.97s
# 987:	learn: 1.5127878	total: 6m 17s	remaining: 4.59s
# 988:	learn: 1.5126996	total: 6m 18s	remaining: 4.21s
# 989:	learn: 1.5125940	total: 6m 18s	remaining: 3.82s
# 990:	learn: 1.5124891	total: 6m 18s	remaining: 3.44s
# 991:	learn: 1.5123518	total: 6m 19s	remaining: 3.06s
# 992:	learn: 1.5122531	total: 6m 19s	remaining: 2.67s
# 993:	learn: 1.5122069	total: 6m 19s	remaining: 2.29s
# 994:	learn: 1.5121134	total: 6m 20s	remaining: 1.91s
# 995:	learn: 1.5120261	total: 6m 20s	remaining: 1.53s
# 996:	learn: 1.5119434	total: 6m 20s	remaining: 1.15s
# 997:	learn: 1.5118910	total: 6m 21s	remaining: 764ms
# 998:	learn: 1.5118268	total: 6m 21s	remaining: 382ms
# 999:	learn: 1.5117436	total: 6m 22s	remaining: 0us

# %%
y_pred = cb.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy : 0.380

# %%
y_pred = y_pred.flatten()
y_pred.shape
# Out:
# (105085,)

# %%
y_diff = np.abs(y_test.ravel()-y_pred.ravel())

# %%
print(f'Score : %.4f' % score(y_test.ravel(), y_pred.ravel()))
# Out:
# Score : 0.8847

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5.3'></a>
# ### XGB BOOST Classifier

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [15:05:30] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
y_pred = xgb.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test.ravel()-y_pred.ravel()))/K
print(f'Score : %.4f' % score)
# Out:
# Accuracy : 0.374
# Score : 0.8825

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
