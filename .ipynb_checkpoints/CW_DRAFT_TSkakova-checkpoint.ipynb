# %%
import os
# import sys
import pandas as pd
import numpy as np
# import sklearn as sk
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from tensorflow import keras

# %%
path = "healthcare"

filename_read = os.path.join(path, "train_data.csv")
df = pd.read_csv(filename_read, na_values=['NA', '?'])

# print(df[0:5])
print(df.shape)
print(df.columns)
# Out:
# (318438, 18)
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
df.drop(df.columns[0:5],axis=1, inplace=True)
df
# Out:
#         Available Extra Rooms in Hospital    Department Ward_Type  \
# 0                                       3  radiotherapy         R
# 1                                       2  radiotherapy         S
# 2                                       2    anesthesia         S
# 3                                       2  radiotherapy         R
# 4                                       2  radiotherapy         S
# ...                                   ...           ...       ...
# 318433                                  3  radiotherapy         Q
# 318434                                  2    anesthesia         Q
# 318435                                  3    gynecology         R
# 318436                                  3    anesthesia         Q
# 318437                                  5    gynecology         Q
#
#        Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0                       F        2.0      31397                7.0
# ...

# %%
df.drop(df.columns[2:7], axis=1, inplace=True)
df
# Out:
#         Available Extra Rooms in Hospital    Department Type of Admission  \
# 0                                       3  radiotherapy         Emergency
# 1                                       2  radiotherapy            Trauma
# 2                                       2    anesthesia            Trauma
# 3                                       2  radiotherapy            Trauma
# 4                                       2  radiotherapy            Trauma
# ...                                   ...           ...               ...
# 318433                                  3  radiotherapy         Emergency
# 318434                                  2    anesthesia            Urgent
# 318435                                  3    gynecology         Emergency
# 318436                                  3    anesthesia            Trauma
# 318437                                  5    gynecology         Emergency
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit  \
# ...

# %%
# df.drop([4,6])
# print(df.columns)

# %%
#manipulations on a copy to have an original for further manipulation
new_df = df.copy()
new_df = new_df.select_dtypes(include=["int","float"])

headers = list(new_df.columns.values)

# %%
fields = []

# %%
for field in headers:
    fields.append({
        "name":field,
        "mean":df[field].mean(),
        "var":df[field].var(),
        "sdev":df[field].std()
    })

# %%
for field in fields:
    print(field)
# Out:
# {'name': 'Available Extra Rooms in Hospital', 'mean': 3.1976271676119055, 'var': 1.364624484865746, 'sdev': 1.1681714278588335}
# {'name': 'Visitors with Patient', 'mean': 3.2840992595104854, 'var': 3.1119125861261314, 'sdev': 1.7640613895571013}
# {'name': 'Admission_Deposit', 'mean': 4880.749392346391, 'var': 1181082.625479292, 'sdev': 1086.7762536416094}

# %%
#shuffling
df= df.reindex(np.random.permutation(df.index))
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#         Available Extra Rooms in Hospital    Department Type of Admission  \
# 0                                       2    gynecology            Trauma
# 1                                       2    gynecology         Emergency
# 2                                       3    gynecology            Trauma
# 3                                       4  radiotherapy         Emergency
# 4                                       2    gynecology         Emergency
# ...                                   ...           ...               ...
# 318433                                  3    gynecology            Urgent
# 318434                                  1    anesthesia         Emergency
# 318435                                  2    anesthesia         Emergency
# 318436                                  2  radiotherapy            Trauma
# 318437                                  6  radiotherapy            Trauma
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit  \
# ...

# %%
#missing values
df.isnull().values.any()
# Out:
# False
