# %% [markdown]
# ## Content:
# - **[Part 1](#part1)- Importing the data set, packages used**
# - **[Part 2](#part2)- Preprocessing Data**
# - **[Part 3](#part3) -  Decision Trees**
# - **[Part 4](#part4) -  Random Forest**
# - **[Part 5](#part5) -  Naive Bayes**
# - **[Part 6](#part6) - Gradient Boost Classifier**
# - **[Part 7](#part6) - Cat Boost Classifier**
# - **[Part 8](#part6) - XGB Boost Classifier**

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part1'></a>
#
# # Part 1 -  Importing the data set

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
# %matplotlib inline

# %%
random.seed(0)

# %%
# Loading Dataset
df = pd.read_csv("healthcare/train_data.csv", na_values=['NA', '?'])

# %%
# Dropping na values for 
df = df.dropna()

# %%
# Dropping case_id
df.drop(['case_id'], axis=1, inplace=True)

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part2'></a>
#
# # Part 2 -  Preprocessing Data

# %% [markdown]
# ### Hot encoded Data

# %%
# Function to hot encode the column with name : name for dataframe df
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = f"{name}-{x}"
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder 
# Columns where we use Label Encoding
le_string_columns = ['Severity of Illness', 'Age' ]
# Columns where we use One Hot Encoding
dummies_string_columns = ['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type', 'Ward_Facility_Code',  'Type of Admission']
encoder = LabelEncoder()

## label_encoded data
Xe = df.drop(['Stay'], axis=1)
Xe['Severity of Illness']= Xe['Severity of Illness'].map({'Minor': 0,  'Moderate': 1,'Extreme': 2})
Xe['Age'] = encoder.fit_transform(Xe['Age'])

ye = df['Stay']
ye = encoder.fit_transform(ye)

for column in dummies_string_columns :
    encode_text_dummy(Xe, column)

# %% [markdown]
# ### Scaling and Splitting Data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
scaler = StandardScaler()
X = Xe.values
y = ye
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
for i in range(X_train.shape[1]) :
    X_train[:,i]= scaler.fit_transform(X_train[:,i].reshape(-1, 1))[:,0]
    X_test[:,i] = scaler.transform(X_test[:,i].reshape(-1, 1))[:,0]

# %% [markdown]
# ### Scoring

# %%
K = 10 # Num of Classes 
# Classes can be ranked here from 0-10
def score(pred, target):
    error = (np.mean(np.abs(pred-target)))/K
    score = 1 - error
    return score

# %% [markdown]
# # Models
#
# We start by base models, models used here are that are most adapted to the nature of the problem :
# - Decision Tree
# - Random Forest
# - Naive Bayes
# - XGBoost

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part3'></a>
#
# # Part 3 -  Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
# Instantiating and fitting the data
tree = DecisionTreeClassifier(criterion='entropy')
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = tree.predict(X_test)

acc = accuracy_score(y_test, y_pred)
score = score(y_test, y_pred)

print('Accuracy : %.3f' % acc)
print('Score : %.3f' % score)
# Out:
# Accuracy : 0.299
# Score : 0.850

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# Decision Trees appear to give reasonnable results. We still have lot of confusion especially between close categories.

# %% [markdown]
# ## Decision tree with gini criterion

# %%
# Instantiating and fitting the data
tree = DecisionTreeClassifier(criterion='gini')
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = tree.predict(X_test)

acc = accuracy_score(y_test, y_pred)
score = 1 - (np.mean(np.abs(y_pred-y_test)))/K

print('Accuracy : %.3f' % acc)
print('Score : %.3f' % score)
# Out:
# Accuracy : 0.301
# Score : 0.851

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# We get same result, Dataset is large enough to avoid using cross validation but we give it a try anyways

# %%
kf = KFold(5, shuffle=True)
tree = DecisionTreeClassifier(criterion='entropy')
fold = 0 
for train_index, validate_index in kf.split(X,y):
    tree.fit(X[train_index], y[train_index])
    y_test_v = y[validate_index]
    y_pred = tree.predict(X[validate_index])
    score = 1 - (np.mean(np.abs(y_pred-y_test_v)))/K
    fold += 1
    print(f'Results after fold {fold}')
    print(f'Accuracy : %.4f' % accuracy_score(y_test_v, y_pred))
    print(f'Score : %.4f' % score)
    print('---------------------')
# Out:
# Results after fold 1
# Accuracy : 0.3004
# Score : 0.8513
# ---------------------
# Results after fold 2
# Accuracy : 0.2993
# Score : 0.8504
# ---------------------
# Results after fold 3
# Accuracy : 0.3001
# Score : 0.8517
# ---------------------
# Results after fold 4
# Accuracy : 0.3006
# Score : 0.8509
# ---------------------
# Results after fold 5
# Accuracy : 0.2960
# Score : 0.8508
# ---------------------

# %% [markdown]
# Results are consisting, now let's move to other algorithms and see if we can improve

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part4'></a>
#
# # Part 4 -  Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Instantiating and fitting the data
forest = RandomForestClassifier(n_estimators=10, criterion='entropy')
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred = forest.predict(X_test)
score = 1 - (np.mean(np.abs(y_pred-y_test)))/K
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# Accuracy : 0.364
# Score : 0.8770

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# Both accuracy and score are better, we are going to try with different n_estimators

# %%
accuracy_data = []
score_data = []

for i in range(20,70,4):
    forest = RandomForestClassifier(n_estimators=i, criterion='entropy')
    forest.fit(X_train, y_train)
    y_pred = forest.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    score = 1-np.mean(np.abs(y_test-y_pred))/K
    print(f'n_estimators : {i}')
    print(f'Accuracy : %.4f' % accuracy)
    print(f'Score  : %.4f' % score)
    print('--------------')
    accuracy_data.append(accuracy)
    score_data.append(score)
# Out:
# n_estimators : 20
# Accuracy : 0.3815
# Score  : 0.8831
# --------------
# n_estimators : 24
# Accuracy : 0.3839
# Score  : 0.8840
# --------------
# n_estimators : 28
# Accuracy : 0.3881
# Score  : 0.8853
# --------------
# n_estimators : 32
# Accuracy : 0.3897
# Score  : 0.8855
# --------------
# n_estimators : 36
# Accuracy : 0.3891
# Score  : 0.8856
# --------------
# n_estimators : 40
# Accuracy : 0.3914
# Score  : 0.8860
# --------------
# n_estimators : 44
# Accuracy : 0.3931
# Score  : 0.8868
# --------------
# n_estimators : 48
# Accuracy : 0.3928
# Score  : 0.8867
# --------------
# n_estimators : 52
# Accuracy : 0.3932
# Score  : 0.8871
# --------------
# n_estimators : 56
# Accuracy : 0.3933
# Score  : 0.8871
# --------------
# n_estimators : 60
# Accuracy : 0.3950
# Score  : 0.8876
# --------------
# n_estimators : 64
# Accuracy : 0.3956
# Score  : 0.8878
# --------------
# n_estimators : 68
# Accuracy : 0.3960
# Score  : 0.8879
# --------------

# %% [markdown]
# ## Plotting accuracy and score with increasing n_estimators

# %%
nums = []
for i in range(20,70,4):
    nums.append(i)

fig = plt.figure(figsize=(6,5))
plt.plot(nums, accuracy_data, c='r', label='Accuracy')
plt.plot(nums, score_data, label='Score')
plt.xlabel('Number of Trees')
plt.ylabel('Accuracy and Score')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Looks like we reached the maximum of accuracy/score at around n_estimators = 60, we will keep this one and move forward

# %% [markdown]
# ## Random Forest n_estimators = 60

# %%
# Instantiating and fitting the data
forest = RandomForestClassifier(n_estimators=60, criterion='entropy')
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=60)

# %%
y_pred = forest.predict(X_test)
score = 1 - (np.mean(np.abs(y_pred-y_test)))/K
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
print(f'Score : %.4f' % score)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# Accuracy : 0.398
# Score : 0.8877

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# ## Plotting Histograms to compare

# %%
labels = np.unique(df['Stay'])
labels[-1] = '100+'

fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(8, 8)
ax1.grid(True)
ax1.hist(y_test, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)
ax1.set_title('Histogram of LOS of True labels')
ax1.set_xlabel('LOS')
ax1.set_ylabel('Occurence')

ax2.grid(True)
ax2.hist(y_pred, bins=11, label=labels, density=True, facecolor='b', alpha=0.75)
ax2.set_title('Histogram of LOS of Predicted labels')
ax2.set_xlabel('LOS')



plt.show()

# %%
labels = np.unique(df['Stay'])
labels[-1] = '100+'

plt.figure(figsize = (10,10))

plt.hist(y_test, bins=11, label=labels, density=True, facecolor='g', alpha=0.5)
plt.hist(y_pred, bins=11, label=labels, density=True, facecolor='b', alpha=0.5)
plt.title('Histogram of LOS of True and Predicted labels')
plt.xlabel('LOS')
plt.ylabel('Occurence')
plt.legend()
plt.grid(True)



plt.show()

# %% [markdown]
# The model reproduce the distribution of the data well enough, but we can see that it predicts categories 1 and 2, more than it should while predicting categories 0 and 3 less. It also neglects categories 6, 7 ...10.

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part5'></a>
#
# # Part 5 -  Naive Bayes

# %% [markdown]
# ## Base Model for Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB(var_smoothing=1)
model.fit(X_train, y_train)
# Out:
# GaussianNB(var_smoothing=1)

# %%
y_pred = model.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test-y_pred))/K
print(f'Score : %.4f' % score)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# Accuracy : 0.329
# Score : 0.8590

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %% [markdown]
# ## Testing different smoothing values

# %%
smoothing = [1e-3, 1e-2, 1e-1, 1, 10]

for var_smoothing in smoothing :
    model = GaussianNB(var_smoothing=var_smoothing)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f'Smoothing parameter : {var_smoothing}')
    print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
    score = 1-np.mean(np.abs(y_test-y_pred))/K
    print(f'Score : %.4f' % score)
    print('----------------------')
# Out:
# Smoothing parameter : 0.001
# Accuracy : 0.184
# Score : 0.7743
# ----------------------
# Smoothing parameter : 0.01
# Accuracy : 0.241
# Score : 0.8057
# ----------------------
# Smoothing parameter : 0.1
# Accuracy : 0.280
# Score : 0.8315
# ----------------------
# Smoothing parameter : 1
# Accuracy : 0.329
# Score : 0.8590
# ----------------------
# Smoothing parameter : 10
# Accuracy : 0.287
# Score : 0.8524
# ----------------------

# %% [markdown]
# We can see that we get best results when the smoothing parameter is in the order of 1, let try different values to see if we can get something different

# %%
smoothing = [0.5, 1, 2, 3, 5]

for var_smoothing in smoothing :
    model = GaussianNB(var_smoothing=var_smoothing)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f'Smoothing parameter : {var_smoothing}')
    print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
    score = 1-np.mean(np.abs(y_test-y_pred))/K
    print(f'Score : %.4f' % score)
    print('----------------------')
# Out:
# Smoothing parameter : 0.5
# Accuracy : 0.319
# Score : 0.8538
# ----------------------
# Smoothing parameter : 1
# Accuracy : 0.329
# Score : 0.8590
# ----------------------
# Smoothing parameter : 2
# Accuracy : 0.311
# Score : 0.8522
# ----------------------
# Smoothing parameter : 3
# Accuracy : 0.303
# Score : 0.8493
# ----------------------
# Smoothing parameter : 5
# Accuracy : 0.304
# Score : 0.8531
# ----------------------

# %% [markdown]
# It seems like our base model might be the best choice when choosing Naive Bayes, let's see how the histogram looks like

# %%
model = GaussianNB(var_smoothing=1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(16, 8)
ax1.grid(True)
ax1.hist(y_test, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)
ax1.set_title('Histogram of LOS of True labels')
ax1.set_xlabel('LOS')
ax1.set_ylabel('Occurence')

ax2.grid(True)
ax2.hist(y_pred, bins=11, label=labels, density=True, facecolor='b', alpha=0.75)
ax2.set_title('Histogram of LOS of Predicted labels')
ax2.set_xlabel('LOS')



plt.show()

# %% [markdown]
# Naive Bayes fails to capture the shape of the distribution and seems to be overfitting by assigning lot of samples to categories 2

# %% [markdown]
# We try different models not seen in the course that are more powerful to see if we can have better results and compare

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part6'></a>
#
# # Part 6 -  Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = model.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test-y_pred))/K
print(f'Score : %.4f' % score)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# Accuracy : 0.415
# Score : 0.8920

# %%
cm_reduced = cm[:6,:6]

cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(16, 8)
ax1.grid(True)
ax1.hist(y_test, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)
ax1.set_title('Histogram of LOS of True labels')
ax1.set_xlabel('LOS')
ax1.set_ylabel('Occurence')

ax2.grid(True)
ax2.hist(y_pred, bins=11, label=labels, density=True, facecolor='b', alpha=0.75)
ax2.set_title('Histogram of LOS of Predicted labels')
ax2.set_xlabel('LOS')



plt.show()

# %% [markdown]
# The best result we got for Random Forest was : Accuracy : 0.396 , Score : 0.8879
#
# Gradient Boost results are better : Accuracy : 0.415, Score : 0.8920
#
# Nevertheless it stills suffers from the same problem as Random Forest as it fails to capture the distribution of data and overfits by predicting category 2 too often.

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part7'></a>
#
# # Part 7 -  Cat Boost Classifier

# %%
from catboost import CatBoostClassifier
cb = CatBoostClassifier(iterations=1000)
cb.fit(X_train, y_train)
# Out:
# Learning rate set to 0.104539
# 0:	learn: 2.2234084	total: 687ms	remaining: 11m 25s
# 1:	learn: 2.1063143	total: 1.27s	remaining: 10m 33s
# 2:	learn: 2.0204817	total: 1.85s	remaining: 10m 14s
# 3:	learn: 1.9529196	total: 2.4s	remaining: 9m 58s
# 4:	learn: 1.8960600	total: 2.96s	remaining: 9m 49s
# 5:	learn: 1.8534948	total: 3.49s	remaining: 9m 38s
# 6:	learn: 1.8154044	total: 4.07s	remaining: 9m 37s
# 7:	learn: 1.7823440	total: 4.64s	remaining: 9m 34s
# 8:	learn: 1.7539753	total: 5.18s	remaining: 9m 30s
# 9:	learn: 1.7296449	total: 5.75s	remaining: 9m 29s
# 10:	learn: 1.7097871	total: 6.31s	remaining: 9m 27s
# 11:	learn: 1.6934331	total: 6.87s	remaining: 9m 26s
# 12:	learn: 1.6766603	total: 7.45s	remaining: 9m 25s
# 13:	learn: 1.6634513	total: 8.04s	remaining: 9m 25s
# 14:	learn: 1.6512975	total: 8.7s	remaining: 9m 31s
# 15:	learn: 1.6413284	total: 9.25s	remaining: 9m 28s
# 16:	learn: 1.6319781	total: 9.8s	remaining: 9m 26s
# 17:	learn: 1.6237897	total: 10.3s	remaining: 9m 23s
# 18:	learn: 1.6165654	total: 11s	remaining: 9m 27s
# 896:	learn: 1.4017130	total: 10m 13s	remaining: 1m 10s
# 897:	learn: 1.4016240	total: 10m 13s	remaining: 1m 9s
# 898:	learn: 1.4015723	total: 10m 14s	remaining: 1m 9s
# 899:	learn: 1.4014705	total: 10m 14s	remaining: 1m 8s
# 900:	learn: 1.4013982	total: 10m 15s	remaining: 1m 7s
# 901:	learn: 1.4012660	total: 10m 15s	remaining: 1m 6s
# 902:	learn: 1.4011307	total: 10m 16s	remaining: 1m 6s
# 903:	learn: 1.4010935	total: 10m 16s	remaining: 1m 5s
# 904:	learn: 1.4009989	total: 10m 17s	remaining: 1m 4s
# 905:	learn: 1.4008695	total: 10m 18s	remaining: 1m 4s
# 906:	learn: 1.4007555	total: 10m 18s	remaining: 1m 3s
# 907:	learn: 1.4006500	total: 10m 19s	remaining: 1m 2s
# 908:	learn: 1.4005165	total: 10m 19s	remaining: 1m 2s
# 909:	learn: 1.4004271	total: 10m 20s	remaining: 1m 1s
# 910:	learn: 1.4003633	total: 10m 21s	remaining: 1m
# 911:	learn: 1.4002499	total: 10m 21s	remaining: 60s
# 912:	learn: 1.4001396	total: 10m 22s	remaining: 59.3s
# 913:	learn: 1.4000361	total: 10m 22s	remaining: 58.6s
# 914:	learn: 1.3999385	total: 10m 23s	remaining: 57.9s
# 915:	learn: 1.3998698	total: 10m 24s	remaining: 57.2s
# 916:	learn: 1.3997751	total: 10m 24s	remaining: 56.5s
# 917:	learn: 1.3996965	total: 10m 25s	remaining: 55.8s
# 918:	learn: 1.3996135	total: 10m 25s	remaining: 55.2s
# 919:	learn: 1.3994631	total: 10m 26s	remaining: 54.5s
# 920:	learn: 1.3993650	total: 10m 26s	remaining: 53.8s
# 921:	learn: 1.3992566	total: 10m 27s	remaining: 53.1s
# 922:	learn: 1.3991563	total: 10m 28s	remaining: 52.4s
# 923:	learn: 1.3990569	total: 10m 28s	remaining: 51.7s
# 924:	learn: 1.3989551	total: 10m 29s	remaining: 51s
# 925:	learn: 1.3988810	total: 10m 29s	remaining: 50.3s
# 926:	learn: 1.3987544	total: 10m 30s	remaining: 49.6s
# 927:	learn: 1.3986130	total: 10m 30s	remaining: 49s
# 928:	learn: 1.3984318	total: 10m 31s	remaining: 48.3s
# 929:	learn: 1.3983160	total: 10m 32s	remaining: 47.6s
# 930:	learn: 1.3982207	total: 10m 32s	remaining: 46.9s
# 931:	learn: 1.3981056	total: 10m 33s	remaining: 46.2s
# 932:	learn: 1.3980134	total: 10m 33s	remaining: 45.5s
# 933:	learn: 1.3979319	total: 10m 34s	remaining: 44.8s
# 934:	learn: 1.3978549	total: 10m 34s	remaining: 44.1s
# 935:	learn: 1.3977358	total: 10m 35s	remaining: 43.5s
# 936:	learn: 1.3976532	total: 10m 36s	remaining: 42.8s
# 937:	learn: 1.3975699	total: 10m 36s	remaining: 42.1s
# 938:	learn: 1.3974834	total: 10m 37s	remaining: 41.4s
# 939:	learn: 1.3973905	total: 10m 38s	remaining: 40.7s
# 986:	learn: 1.3925077	total: 11m 5s	remaining: 8.77s
# 987:	learn: 1.3924044	total: 11m 6s	remaining: 8.09s
# 988:	learn: 1.3922051	total: 11m 6s	remaining: 7.42s
# 989:	learn: 1.3920917	total: 11m 7s	remaining: 6.74s
# 990:	learn: 1.3920035	total: 11m 7s	remaining: 6.07s
# 991:	learn: 1.3919207	total: 11m 8s	remaining: 5.39s
# 992:	learn: 1.3918063	total: 11m 9s	remaining: 4.72s
# 993:	learn: 1.3917117	total: 11m 10s	remaining: 4.04s
# 994:	learn: 1.3916209	total: 11m 11s	remaining: 3.37s
# 995:	learn: 1.3915810	total: 11m 11s	remaining: 2.7s
# 996:	learn: 1.3914999	total: 11m 12s	remaining: 2.02s
# 997:	learn: 1.3914453	total: 11m 13s	remaining: 1.35s
# 998:	learn: 1.3913918	total: 11m 13s	remaining: 674ms
# 999:	learn: 1.3912949	total: 11m 14s	remaining: 0us

# %%
y_pred = cb.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy : 0.428

# %% [markdown]
# There appears to have problems when calculating score directly so we used the step by step method

# %%
y_pred = y_pred.flatten()

# %%
error = np.abs(y_test-y_pred)

# %%
mean_error = np.mean(error)

# %%
K = 10
score = 1-mean_error/K

# %%
print(f'Score : %.4f' % score)
# Out:
# Score : 0.8950

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %%
labels = np.unique(df['Stay'])
labels[-1] = '100+'
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(16, 8)
ax1.grid(True)
ax1.hist(y_test, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)
ax1.set_title('Histogram of LOS of True labels')
ax1.set_xlabel('LOS')
ax1.set_ylabel('Occurence')

ax2.grid(True)
ax2.hist(y_pred, bins=11, label=labels, density=True, facecolor='b', alpha=0.75)
ax2.set_title('Histogram of LOS of Predicted labels')
ax2.set_xlabel('LOS')



plt.show()

# %% [markdown]
# The best result we got for Random Forest was : Accuracy : 0.396 , Score : 0.8879
#
# Gradient Boost results :                       Accuracy : 0.415 , Score : 0.8920
#
# CatBoost results :                             Accuracy : 0.428 , Score : 0.895
#
#
# These results are slightly better but again we have the same problem as before.

# %% [markdown]
# [Back to top](#Content:)
#
#
# <a id='part8'></a>
#
# # Part 8 -  XGB Boost Classifier

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:24:59] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
y_pred = xgb.predict(X_test)
print(f'Accuracy : %.3f' % accuracy_score(y_test, y_pred))
score = 1-np.mean(np.abs(y_test-y_pred))/K
print(f'Score : %.4f' % score)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# Accuracy : 0.426
# Score : 0.8944

# %%
cm_reduced = cm[:6,:6]
cm = confusion_matrix(y_test, y_pred);
disp = ConfusionMatrixDisplay(cm_reduced)
disp.plot();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(16, 8)
ax1.grid(True)
ax1.hist(y_test, bins=11, label=labels, density=True, facecolor='g', alpha=0.75)
ax1.set_title('Histogram of LOS of True labels')
ax1.set_xlabel('LOS')
ax1.set_ylabel('Occurence')

ax2.grid(True)
ax2.hist(y_pred, bins=11, label=labels, density=True, facecolor='b', alpha=0.75)
ax2.set_title('Histogram of LOS of Predicted labels')
ax2.set_xlabel('LOS')



plt.show()

# %% [markdown]
# XGB Boost offers similar results to CatBoost, with the same issues

# %% [markdown]
# # Conclusion

# %% [markdown]
# We Have tried different models with different paramaters on the dataset, the results so far are not bad since most confusion happens between categories that are very close. In fact in our problem we have categories that are very close to each other which adds a layer of difficulty to the problem if we want to use accuracy as a metric. On the other hand the score method that measures how wrong the predictions are by taking into account the distance between categories gives descent results. We are now going to try classification with ANN and regression as well.
